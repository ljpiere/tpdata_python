# %% [markdown]
# # <span style="color: #1F1DB5;">SPRINT 2 – Python básico continuación

# %% [markdown]
# # <span style="color: #1F1DB5;">Notebook 3 – Intro a Git: Qué es, para qué sirve y comandos básicos

# %% [markdown]
# ## <span style="color: #2826DE;">Objetivos de Aprendizaje
#
# Al finalizar la sesión, podrás:
#
# - Comprender qué es el **control de versiones** y por qué es fundamental para DA/DS
#
# - Conocer los **conceptos clave de Git**: repositorio, commit, rama, tag, remoto
#
# - Aplicar los **comandos básicos**: `init`, `status`, `add`, `commit`
#
# - Entender la diferencia entre **Git** (herramienta) y **GitHub** (servicio)
#
# - Subir tu primer repositorio a **GitHub**

# %% [markdown]
# ### <span style="color: #2772F2;">Agenda (2 horas)
# |Bloque |	Actividad |	Duración|
# |----------|----------|----------|
# |1	|Introducción + Pregunta guía	|10 mins|
# |2	|Qué es Git y control de versiones	|20 mins|
# |3	|Conceptos clave: repo, commit, rama, remoto	|20 mins|
# |4	|Comandos básicos: init, add, commit, status	|30 mins|
# |5	|GitHub: subir un repositorio	|20 mins|
# |6	|Actividad práctica – Breakout Rooms	|15 mins|
# |7	|Tips y buenas prácticas	|5 mins|
# |8	|Cierre y Kahoot	|5 mins|

# %% [markdown]
# ## <span style="color: #2826DE;">❓ Pregunta Guía
#
# ### ¿Cómo colaboran los equipos de datos y cómo **protegen su trabajo**?

# %% [markdown]
# ## <span style="color: #2826DE;">¿Qué es Git y control de versiones? (20 mins)

# %% [markdown]
# ### <span style="color: #2772F2;">El problema sin control de versiones
#
# ¿Alguna vez has tenido archivos como estos?
#
# ```
# analisis_final.py
# analisis_final_v2.py
# analisis_final_v2_corregido.py
# analisis_final_ESTE_SI.py
# analisis_final_ESTE_SI_de_verdad.py
# ```
#
# **Git resuelve este problema** guardando el historial completo de cambios de forma organizada.

# %% [markdown]
# ### Preguntas:
#
# - **¿Has tenido este problema de versiones de archivos antes? ¿Cómo lo resolviste?**
#
# - **¿Qué información perderías si solo guardas la última versión de un archivo?**

# %% [markdown]
# ### <span style="color: #2772F2;">¿Qué es el control de versiones?
#
# Es un sistema que **registra los cambios** en archivos a lo largo del tiempo, permitiendo:
#
# - **Volver a versiones anteriores** si algo sale mal
# - **Colaborar** con otros sin sobrescribir el trabajo de nadie
# - **Ver quién cambió qué** y cuándo
# - **Experimentar** en ramas separadas sin afectar el código principal
#
# ### <span style="color: #2772F2;">Git vs otros sistemas
#
# | Sistema | Tipo | Estado |
# |---|---|---|
# | **Git** | Distribuido | ✅ Estándar de la industria |
# | SVN | Centralizado | Obsoleto |
# | Mercurial | Distribuido | Poco usado |
#
# **Git ganó** porque es rápido, distribuido (cada copia es un backup completo) y tiene GitHub.

# %% [markdown]
# ### <span style="color: #2772F2;">Por qué Git es fundamental para DA/DS
#
# - **Reproducibilidad**: puedes volver exactamente al estado del código cuando generaste un resultado
# - **Colaboración**: trabajar en equipo sin conflictos
# - **Portafolio**: GitHub es tu CV técnico
# - **Entrevistas**: si no sabes Git, pierdes puntos
#
# > **"Un Data Scientist sin Git es como un chef sin recetas escritas."**

# %% [markdown]
# ### Preguntas:
#
# - **¿Por qué crees que Git se convirtió en el estándar de la industria y no SVN o Mercurial?**
#
# - **¿Qué significa que Git sea "distribuido"? ¿Qué ventaja tiene eso?**
#
# - **¿Cómo te ayuda Git a demostrar tu trabajo en una entrevista de trabajo?**

# %% [markdown]
# ## <span style="color: #2826DE;">Conceptos clave de Git (20 mins)

# %% [markdown]
# ### <span style="color: #2772F2;">Glosario esencial
#
# | Concepto | Definición | Analogía |
# |---|---|---|
# | **Repositorio (repo)** | Carpeta con historial de cambios | Carpeta de proyecto con memoria |
# | **Commit** | Foto del estado del proyecto en un momento | Guardar partida en un videojuego |
# | **Rama (branch)** | Línea paralela de desarrollo | Borrador de un documento |
# | **Remoto (remote)** | Copia del repo en un servidor | Backup en la nube |
# | **Origin** | Nombre por defecto del remoto principal | El servidor de GitHub |
# | **Tag** | Etiqueta en un commit específico | Marcar una versión como v1.0 |
#
# ### <span style="color: #2772F2;">Los 3 estados de un archivo en Git
#
# ```
# Working Directory  →  Staging Area  →  Local Repository
#    (modificado)         (preparado)        (guardado)
#        git add →              git commit →
# ```

# %% [markdown]
# ### Preguntas:
#
# - **¿Cuál es la diferencia entre el Staging Area y el Local Repository?**
#
# - **¿Por qué necesitamos el Staging Area? ¿No sería más simple ir directo de Working Directory a Repository?**
#
# - **¿Qué analogía usarías para explicarle Git a alguien que nunca ha programado?**

# %% [markdown]
# ## <span style="color: #2826DE;">Comandos básicos de Git (30 mins)

# %% [markdown]
# ### <span style="color: #2772F2;">Configuración inicial (solo una vez)
#
# ```bash
# # Configurar tu identidad
# git config --global user.name "Tu Nombre"
# git config --global user.email "tu@email.com"
#
# # Verificar configuración
# git config --list
# ```

# %% [markdown]
# ### <span style="color: #2772F2;">Flujo básico de trabajo
#
# ```bash
# # 1. Inicializar un repositorio
# git init
#
# # 2. Ver el estado actual
# git status
#
# # 3. Agregar archivos al staging area
# git add archivo.py          # Un archivo específico
# git add .                   # Todos los archivos
#
# # 4. Hacer un commit
# git commit -m "Descripción clara de los cambios"
#
# # 5. Ver el historial
# git log
# git log --oneline           # Versión compacta
# ```

# %% [markdown]
# ### <span style="color: #2772F2;">Demo en vivo: crear tu primer repositorio
#
# Sigue estos pasos en tu terminal:
#
# ```bash
# # Crear una carpeta de proyecto
# mkdir mi_proyecto_ds
# cd mi_proyecto_ds
#
# # Inicializar Git
# git init
#
# # Crear un archivo
# echo "# Mi Proyecto de Data Science" > README.md
#
# # Ver el estado
# git status
#
# # Agregar el archivo
# git add README.md
#
# # Hacer el primer commit
# git commit -m "Primer commit: agregar README"
#
# # Ver el historial
# git log --oneline
# ```

# %% [markdown]
# ### Preguntas:
#
# - **¿Qué pasa si haces `git commit` sin haber hecho `git add` primero?**
#
# - **¿Por qué es importante escribir mensajes de commit descriptivos?**
#
# - **¿Qué diferencia hay entre `git log` y `git log --oneline`?**

# %% [markdown]
# ## <span style="color: #2826DE;">GitHub: subir tu repositorio (20 mins)

# %% [markdown]
# ### <span style="color: #2772F2;">Git vs GitHub
#
# | | Git | GitHub |
# |---|---|---|
# | **Qué es** | Herramienta de control de versiones | Plataforma web para alojar repos |
# | **Dónde vive** | En tu computadora | En la nube |
# | **Alternativas** | Mercurial, SVN | GitLab, Bitbucket |
#
# ### <span style="color: #2772F2;">Pasos para subir a GitHub
#
# ```bash
# # 1. Crear un repositorio en github.com (sin inicializar)
#
# # 2. Conectar tu repo local con GitHub
# git remote add origin https://github.com/tu-usuario/mi-proyecto.git
#
# # 3. Subir los cambios
# git push -u origin main
#
# # 4. Para subir cambios futuros
# git push
# ```
#
# ### <span style="color: #2772F2;">Tu GitHub es tu portafolio
#
# - Sube **todos tus proyectos del bootcamp** a GitHub
# - Escribe buenos **README.md** explicando cada proyecto
# - Los reclutadores **revisan tu GitHub** antes de entrevistarte

# %% [markdown]
# ### Preguntas:
#
# - **¿Cuál es la diferencia entre Git y GitHub?**
#
# - **¿Por qué tu GitHub es tu "CV técnico"?**
#
# - **¿Qué pasaría si dos personas hacen push al mismo repositorio al mismo tiempo?**

# %% [markdown]
# ## <span style="color: #2826DE;">Actividad práctica – Breakout Rooms (15 mins)

# %% [markdown]
# ### <span style="color: #aa0808;">En esta ocasión, quien compartirá resultados será: (Giremos la ruleta)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import random

rules = [
    "El más joven", "El que vive más lejos", "El más alto",
    "El más deportista", "Más experiencia programando",
    "El que durmió más tarde", "Más café hoy",
    "Más cursos terminados", "Username más largo", "Más mascotas"
]

n = len(rules)
angles = np.linspace(0, 2*np.pi, n, endpoint=False)
fig, ax = plt.subplots(figsize=(6,6))
ax.set_aspect("equal")
ax.axis("off")
colors = plt.cm.tab20(np.linspace(0,1,n))

for i, angle in enumerate(angles):
    wedge = plt.matplotlib.patches.Wedge(
        (0,0), 1, np.degrees(angle), np.degrees(angle + 2*np.pi/n), facecolor=colors[i])
    ax.add_patch(wedge)
    x = 0.7*np.cos(angle + np.pi/n)
    y = 0.7*np.sin(angle + np.pi/n)
    ax.text(x, y, rules[i], ha="center", va="center", fontsize=9,
            rotation=np.degrees(angle + np.pi/n))

pointer, = ax.plot([0,0],[0,1.1], lw=4, color="black")
chosen_index = random.randint(0, n-1)
target_angle = 2*np.pi*(5) + angles[chosen_index]
angle = 0

def update(frame):
    global angle
    if angle < target_angle:
        angle += 0.3
    pointer.set_data([0, np.cos(angle)], [0, np.sin(angle)])
    return pointer,

ani = animation.FuncAnimation(fig, update, frames=200, interval=30, blit=True)
plt.show()
print("Elegido:", rules[chosen_index])

# %% [markdown]
# ### Ejercicio – Tu primer repositorio Git
#
# **Objetivo:** Crear un repositorio Git con tu análisis de datos del Sprint 1.
#
# **Pasos:**
#
# 1. Crea una carpeta `sprint1_analisis`
# 2. Inicializa Git: `git init`
# 3. Crea un archivo `README.md` con:
#    - Título del proyecto
#    - Descripción breve
#    - Tu nombre
# 4. Haz tu primer commit: `git commit -m "Primer commit: README"`
# 5. Crea un archivo `analisis.py` con al menos 5 líneas de código Python
# 6. Haz un segundo commit: `git commit -m "Agregar análisis inicial"`
# 7. Verifica el historial: `git log --oneline`
#
# **Bonus:** Sube el repositorio a GitHub

# %% [markdown]
# ## <span style="color: #2826DE;">Tips y buenas prácticas (5 mins)
#
# - **Haz commits frecuentes** — cada vez que termines una tarea pequeña
#
# - **Escribe mensajes descriptivos**: `"Agregar función de limpieza de datos"` no `"cambios"`
#
# - **Nunca hagas commit de secretos** (contraseñas, API keys) — usa `.gitignore`
#
# - **Usa `.gitignore`** para excluir archivos innecesarios (`.venv/`, `__pycache__/`, `*.pyc`)
#
# - **Sube todos tus proyectos del bootcamp** a GitHub — es tu portafolio

# %% [markdown]
# ## <span style="color: #2826DE;">Cierre y Kahoot (5 mins)
#
# Kahoot – Preguntas sugeridas
#
# 1️⃣ ¿Qué hace `git init`?
#
# - Sube el repositorio a GitHub
# - Hace un commit con todos los archivos
# - Descarga un repositorio remoto
# - **Inicializa un repositorio Git local** ✅
#
#
# 2️⃣ ¿Qué hace `git add .`?
#
# - Hace un commit de todos los archivos
# - Sube los archivos a GitHub
# - Descarga cambios del remoto
# - **Agrega todos los archivos al staging area** ✅
#
#
# 3️⃣ ¿Cuál es la diferencia entre Git y GitHub?
#
# - Son exactamente lo mismo
# - GitHub es más antiguo que Git
# - Git es solo para proyectos grandes
# - **Git es la herramienta local, GitHub es el servicio web** ✅
#
#
# 4️⃣ ¿Qué es un commit?
#
# - Un error en el código
# - Una rama del repositorio
# - Un archivo de configuración
# - **Una foto del estado del proyecto en un momento** ✅
#
#
# 5️⃣ ¿Qué comando muestra el historial de commits?
#
# - git status
# - git add
# - git push
# - **git log** ✅
#
#
# 6️⃣ ¿Para qué sirve `.gitignore`?
#
# - Para hacer commits más rápidos
# - Para crear ramas automáticamente
# - Para sincronizar con GitHub
# - **Para excluir archivos del repositorio** ✅
#
#
# 7️⃣ ¿Cuáles son los 3 estados de un archivo en Git?
#
# - Creado, Modificado, Eliminado
# - Local, Remoto, Archivado
# - **Working Directory, Staging Area, Repository** ✅
# - Nuevo, Guardado, Publicado
#
#
# 8️⃣ ¿Qué hace `git push -u origin main`?
#
# - Descarga cambios del repositorio remoto
# - Crea una nueva rama llamada main
# - Elimina el repositorio remoto
# - **Sube los commits locales a GitHub por primera vez** ✅
