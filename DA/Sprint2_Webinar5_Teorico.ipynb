# %% [markdown]
# # Sprint 2 - Webinar 5 (Parte 1 de 2): PivotTables y Visualización (Excel/Google Sheets)
# **Fecha:** 2025-09-16
# **Dataset:** `sp2_w5_almacen_ventas.xlsx` (adjunto)
# **Herramientas:** Excel o Google Sheets (sin Python/pandas)
# **Nivel:** Intermedio
# **Duración total:** 120 minutos

# %% [markdown]
# ## Objetivos de aprendizaje
# - Construir y personalizar PivotTables para agrupar y resumir datos.
# - Filtrar, ordenar y aplicar diferentes cálculos (SUM, COUNT, AVERAGE, MAX, MIN).
# - Interpretar resultados y convertirlos en hallazgos para negocio.
# - Crear gráficos apropiados y usar formato condicional para resaltar valores clave.
# - Diseñar una pestaña-resumen tipo mini dashboard.
# - Usar LLMs (ChatGPT/Claude) como apoyo para agregaciones **con criterio y cautela**.

# %% [markdown]
# ## Agenda (120 min)
# **Introducción**
# - (Opcional) Kahoot de activación: 3-4 preguntas rápidas para diagnosticar conocimientos previos.
# 1) **PivotTables – fundamentos y primera tabla dinámica** (25 min)
# 2) **Filtrado y orden dentro de la PivotTable** (15 min)
# 3) **Cálculos y múltiples métricas** (20 min)
# 4) **Refinar el layout e interpretar resultados** (10 min)
# 5) **AI 🤖 LLMs para filtrar/agregar (con riesgos)** (10 min)
# 6) **Gráficos correctos y narrativa** (15 min)
# 7) **Formato condicional para resaltar** (10 min)
# 8) **Mini dashboard de resumen** (10 min)
# 9) **Comunicar hallazgos en una diapositiva** (5 min)
#
# **Kahoot de repaso (5 min):**
# - Validar aprendizajes clave de la sesión.
# - Q&A y próximos pasos.

# %% [markdown]
# ## Preparación (antes de la clase)
# - Descarga/abre `sp2_w5_almacen_ventas.xlsx` en Excel o súbelo a Google Drive y ábrelo en Sheets.
# - Verifica que las columnas tengan tipos coherentes: fechas, categorías (región, producto), números (unidades, ventas).
# - Crea una pestaña nueva llamada **`Pivot_Trabajo`** y otra **`Resumen`** para el dashboard final.

# %% [markdown]
# # 4. Analyzing Data with PivotTables
# Agrupa y resume datos usando PivotTables y filtros.

# %% [markdown]
# ## 4.1 Building Your First PivotTable (25 min)
# **Objetivo:** Crear una PivotTable desde un dataset limpio, escoger campos de filas/columnas y un valor a resumir.
#
# **Paso a paso (Excel/Sheets):**
# 1. Selecciona toda la tabla de ventas.
# 2. Inserta **Tabla dinámica / PivotTable** en una nueva hoja llamada `Pivot_Trabajo`.
# 3. Arrastra **Región** a **Filas** y **Categoría de producto** a **Columnas**.
# 4. Arrastra **Ventas totales** (o `Total Sales`) a **Valores** (cálculo SUM).
# 5. Ajusta el formato de número (separador de miles, 0 decimales).
#
# **Ejercicio 4.1:** Construye una PivotTable que muestre **ventas totales por región y categoría de producto**.
# **Check rápido:** ¿La suma coincide con el total del dataset?

# %% [markdown]
# ## 4.2 Filtering and Sorting Inside PivotTables (15 min)
# **Objetivo:** Usar filtros integrados, ordenar filas y aplicar filtros por valores.**
#
# **Paso a paso:**
# 1. Usa el filtro de **Fecha** para seleccionar un rango (por ejemplo, últimos 12 meses).
# 2. Ordena **Región** por ventas totales (descendente).
# 3. Aplica **Filtros de valor** en Categoría (p.ej., **Top 3** por ventas).
# 4. (Opcional) Filtra por **Producto** o **Canal** si existen.
#
# **Ejercicio 4.2:** Filtra tu tabla para mostrar **solo las 3 categorías principales por región** basadas en ventas totales.

# %% [markdown]
# ## 4.3 Summarizing Data with Different Calculations (20 min)
# **Objetivo:** Cambiar el cálculo (SUM, COUNT, AVERAGE, MAX, MIN) y usar múltiples campos de valores.**
#
# **Paso a paso:**
# 1. Duplica la PivotTable (copiar/pegar como Pivot, no como valores) para comparar configuraciones.
# 2. En **Valores**, cambia el cálculo de **SUM** a **COUNT** o **AVERAGE**.
# 3. Agrega un segundo campo de **Valores**: por ejemplo, **Unidades vendidas (SUM)** y **Ventas promedio (AVERAGE)**.
# 4. (Opcional) Muestra **% del total** por región y por categoría.
#
# **Ejercicio 4.3:** Modifica tu PivotTable para mostrar **unidades totales vendidas** y **ventas promedio por producto**.

# %% [markdown]
# ## 4.4 Refining the Layout and Interpreting Results (10 min)
# **Objetivo:** Mejorar legibilidad y conectar hallazgos con preguntas de negocio.**
#
# **Paso a paso:**
# 1. Cambia el **diseño de informe** (mostrar en tabular, repetir etiquetas de elementos si conviene).
# 2. **Renombra** campos (p.ej., `Ventas_totales` → `Ventas (COP)`), aplica formato de número.
# 3. **Ajusta el ancho** de columnas y alinea cifras.
# 4. Redacta 2–3 frases que expliquen el patrón principal (región líder, categoría más fuerte, estacionalidad).
#
# **Ejercicio 4.4:** Reorganiza tu PivotTable para destacar patrones clave y escribe un **resumen breve** dirigido a un gerente.

# %% [markdown]
# ## 4.5 AI 🤖 Using LLMs to Filter & Aggregate (10 min)
# **Objetivo:** Probar un LLM gratuito (ChatGPT/Claude) para realizar agregaciones tipo `SUMIF/COUNTIF/AVERAGEIF` en lenguaje natural y discutir riesgos.**
#
# **Instrucciones:**
# 1. Exporta una muestra del dataset (por ejemplo, 5–10 columnas, 200–1,000 filas) como CSV.
# 2. Sube el CSV al LLM **con una petición clara** (ej.: *"Calcula la suma de ventas para la región Norte en 2024"*).
# 3. Pide **mostrar pasos** o la **tabla intermedia** (si el LLM lo permite).
#
# **Riesgos a discutir:**
# - Posible **eliminación automática de nulos** sin avisar.
# - Muestreo/recorte de filas (límites de tokens).
# - Cambios de tipos (fechas a texto).
# - **Reproducibilidad**: documenta el prompt y adjunta resultado.
#
# **Ejercicio 4.5:** Usa un LLM para obtener una agregación **equivalente a SUMIF** y **compara** contra Excel/Sheets.

# %% [markdown]
# # 5. Visualizing and Highlighting Key Insights
# Muestra valores importantes con gráficos y formato condicional.

# %% [markdown]
# ## 5.1 Telling a Story with the Right Chart (15 min)
# **Objetivo:** Crear gráficos desde PivotTables/resúmenes y personalizarlos para lectura clara.**
#
# **Paso a paso:**
# 1. Selecciona tu PivotTable (por mes y región).
# 2. Inserta un **gráfico de columnas** agrupadas (o líneas si comparas meses).
# 3. Agrega **título, etiquetas de ejes y leyenda**, ajusta el formato de números.
# 4. Opcional: añade **etiquetas de datos** (sin saturar) y rota etiquetas de eje si son largas.
#
# **Ejercicio 5.1:** Crea un gráfico que compare **ventas mensuales por región** y mejora títulos/etiquetas.

# %% [markdown]
# ## 5.2 Highlighting Values with Conditional Formatting (10 min)
# **Objetivo:** Resaltar top performers, umbrales y outliers.**
#
# **Paso a paso:**
# 1. En una tabla resumen por **Producto**, aplica **Formato condicional** con **Reglas superiores** (Top 10%, Top 5).
# 2. Crea una regla por **umbral** (p.ej., `Ventas > objetivo`).
# 3. Usa **escalas de color** o **iconos** para semáforos de desempeño.
# 4. Combina con filtros para enfocarte en segmentos clave.
#
# **Ejercicio 5.2:** Resalta productos con ventas **por encima del objetivo** y **marca** los de bajo desempeño.

# %% [markdown]
# ## 5.3 Designing a Simple Summary Dashboard (10 min)
# **Objetivo:** Organizar KPIs y gráficos en una pestaña `Resumen` limpia y reutilizable.**
#
# **Recomendaciones:**
# - 3 **KPIs** (por ejemplo: *Ventas Totales*, *Ticket Promedio*, *Top Región*).
# - 1 **gráfico** principal vinculado a tu Pivot (mensual por región).
# - 1 **sección de insights** con bullets.
# - Usa **alineación, espacios, bordes suaves**; nombra rangos si usas Sheets para reusabilidad.
#
# **Ejercicio 5.3:** Diseña la pestaña **Resumen** con **3 KPIs + 1 gráfico + 1 bloque de insights**.

# %% [markdown]
# ## 5.4 Communicating Insights in a Slide or Report (5 min)
# **Objetivo:** Convertir gráficos/métricas en mensajes claros.**
#
# **Plantilla de comunicación (contexto → hallazgo → implicación):**
# - **Contexto:** *En 2024, comparamos ventas mensuales por región y categoría…*
# - **Hallazgo:** *La región Norte creció 18% y lidera en Electrónica…*
# - **Implicación:** *Enfocar inventario y campañas en Norte/Q2.*
#
# **Ejercicio 5.4:** Escribe **2–3 statements** con la plantilla y **boceta 1 diapositiva** con el takeaway principal.

# %% [markdown]
# ## Evaluación rápida (auto-chequeo)
# - [ ] ¿Tu PivotTable 4.1 muestra ventas por **región x categoría**?
# - [ ] ¿Aplicaste filtros/orden para mostrar **Top 3** categorías por región (4.2)?
# - [ ] ¿Incluiste **dos métricas** (unidades y promedio) en la misma tabla (4.3)?
# - [ ] ¿Refinaste el layout y escribiste un **resumen ejecutivo** (4.4)?
# - [ ] ¿Replicaste una agregación con un **LLM** y comparaste resultados (4.5)?
# - [ ] ¿Creaste un **gráfico** claro con títulos/etiquetas (5.1)?
# - [ ] ¿Aplicaste **formato condicional** para resaltar desempeño (5.2)?
# - [ ] ¿Armastes un **mini dashboard** (5.3)?
# - [ ] ¿Redactaste **2–3 insights** y una **slide** (5.4)?

# %% [markdown]
# ## Rúbrica sugerida (10 pts)
# - PivotTables correctas y filtrado/orden (4 pts).
# - Cálculos múltiples y layout claro (2 pts).
# - Gráfico + formato condicional (2 pts).
# - Dashboard + comunicación de insights (2 pts).

# %% [markdown]
# ## Tips y buenas prácticas
# - Nombra tus campos de forma clara; guarda versiones.
# - Prefiere **tablas** (Ctrl/Cmd+T) como origen de datos para rango dinámico.
# - Documenta filtros aplicados (fecha, región) al exportar.
# - En Sheets, usa **Slicers** para filtros visuales en dashboards.
# - Evita sobrecargar gráficos; menos es más.
# - Con LLMs: pega **muestras**, no toda la base; valida siempre contra Excel/Sheets.

# %% [markdown]
# ## (Opcional) Guía de solución breve
# <details>
# <summary>Ver guía</summary>
#
# **4.1**: Región→Filas, Categoría→Columnas, Ventas→Valores (SUM).
# **4.2**: Filtro por fecha, Ordenar por Ventas desc., Top 3 por valor.
# **4.3**: Añade Unidades (SUM) y Ventas (AVERAGE) en Valores; prueba % del total.
# **4.4**: Diseño tabular, renombrar y formato COP; 2–3 frases de hallazgos.
# **4.5**: Prompt LLM con condición (región=‘Norte’); compara con Excel.
# **5.1**: Gráfico columnas o líneas por mes–región; etiquetas claras.
# **5.2**: Reglas Top/Umbral + semáforos.
# **5.3**: KPIs (SUM Ventas, Promedio Ticket, Top Región) + 1 gráfico.
# **5.4**: Redacción con contexto→hallazgo→implicación; 1 slide.
#
# </details>

# %% [markdown]
# ---
# ## Cierre
#
#
# **Kahoot de repaso (5 min):**
# - Validar aprendizajes clave de la sesión.
# - Q&A y próximos pasos.
#
# ## Siguientes Pasos
#
# - **Participación continua:** asistir a Co-Learning y a Sprint Focus, y usar los canales de Discord para hacer preguntas.
# - **Recordatorios:** la grabación y recursos utilizados, se comparten al finalizar la sesión; en caso de necesitar apoyo adicional, agenda un 1:1.
