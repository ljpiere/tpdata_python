# %% [markdown]
# # Sprint 9 · Webinar 28 · Data Analytics práctico · Student Version
#
# **Mini-proyecto:** Web Scraping (HTML) con **Python** + **pandas** + **EDA básico** + **Nulos/Vacíos** + **Correlación Pearson** + **GitHub**
#
# **Duración sugerida:** 100 minutos
#
# > Usa este notebook como cuaderno de trabajo.
# > La idea no es solo ejecutar, sino **pensar, completar, documentar y justificar** cada paso del mini‑proyecto.
#
# ### Completa antes de iniciar
# - **Fecha:** `____ / ____ / 2026`
# - **Instructor/a:** `____________________________`
# - **Grupo / Cohorte:** `____________________________`
# - **Objetivo personal de la sesión:** `____________________________________________`

# %% [markdown]
# ## Objetivo de la sesión práctica
#
# Al finalizar esta sesión, deberías poder:
#
# 1. Explicar **qué es web scraping** y cuándo conviene usarlo.
# 2. Extraer datos de una página HTML usando `requests` y `BeautifulSoup`.
# 3. Construir un `DataFrame` con `pandas` a partir de datos extraídos de la web.
# 4. Hacer una exploración inicial del dataset con `head()`, `shape()`, `info()` y `describe()`.
# 5. Detectar y tratar **vacíos** y **nulos** con reglas simples.
# 6. Calcular e interpretar una **correlación Pearson**.
# 7. Exportar resultados y dejar el proyecto listo para **publicarlo en GitHub**.
#
# ### Al terminar, responde
# - ¿Qué parte del flujo entendí mejor? `________________________________________`
# - ¿Qué parte necesito repasar? `_____________________________________________`

# %% [markdown]
# ## Agenda sugerida (100 minutos)
#
# | Tiempo | Bloque | Qué haré | Estado / dudas |
# |---:|---|---|---|
# | 0–10 min | Contexto | Qué es scraping, ética y límites | `__` |
# | 10–20 min | Setup | Revisar librerías y entorno | `__` |
# | 20–45 min | Ejercicio 1 | Extraer datos HTML y construir dataset | `__` |
# | 45–65 min | Ejercicio 2 | EDA básico con pandas | `__` |
# | 65–80 min | Ejercicio 3 | Detectar y tratar vacíos/nulos | `__` |
# | 80–90 min | Ejercicio 4 | Calcular e interpretar Pearson | `__` |
# | 90–100 min | Ejercicio 5 | Exportar resultados + checklist GitHub | `__` |
#
# ### Meta de hoy
# Convierte una página HTML en un mini‑proyecto analítico documentado.

# %% [markdown]
# ## ¿Qué es Web Scraping?
#
# **Web scraping** es el proceso de **extraer información de páginas web** y convertirla en datos estructurados para analizarlos.
#
# ### Apuntes guiados
# Completa con tus palabras:
#
# - **¿Cuándo sí conviene hacer scraping?**
#   `__________________________________________________________________________`
#
# - **¿Cuándo sería mejor usar una API en vez de scraping?**
#   `__________________________________________________________________________`
#
# - **Dos riesgos o límites del scraping:**
#   1. `______________________________________________________________`
#   2. `______________________________________________________________`
#
# - **Buenas prácticas éticas y técnicas:**
#   - Revisar `________________________`
#   - Usar `__________________________`
#   - Evitar `________________________`
#   - Documentar `____________________`
#
# ### Sitio de práctica
# Usaremos un sitio pensado para practicar scraping:
#
# - **Scrape This Site (Simple Countries):**
#   `https://www.scrapethissite.com/pages/simple/`

# %% [markdown]
# ## Setup del entorno
#
# Vamos a trabajar con estas librerías:
#
# - `requests`: descargar HTML
# - `BeautifulSoup`: parsear HTML
# - `pandas`: construir y analizar tablas
# - `matplotlib`: gráficos básicos
#
# ### Checklist técnico
# Marca o completa:
#
# - [ ] Abrí el notebook correctamente
# - [ ] Mi entorno reconoce Python
# - [ ] Tengo instaladas las librerías necesarias
# - [ ] Entiendo para qué sirve cada librería
#
# **Si aparece un error técnico, anótalo aquí:**
# `__________________________________________________________________________`

# %%
# Si te falta alguna librería, descomenta y ejecuta solo lo necesario:
# !pip install requests beautifulsoup4 pandas matplotlib

# %%
# 1) Setup del entorno
# Ejecuta esta celda primero y verifica que no falle.
# Si algo falla, registra aquí el error y cómo lo resolviste.

import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 100)

# Mis notas del setup:
# - Librería que no conocía: _________________________________
# - Duda técnica inicial: ___________________________________

# %% [markdown]
# # Ejercicio 1 · Web Scraping de un sitio estructurado (25 min)
#
# En este ejercicio vas a:
#
# 1. Descargar el HTML de una página.
# 2. Encontrar los bloques donde viven los datos.
# 3. Extraer campos relevantes.
# 4. Construir un `DataFrame`.
#
# ### Antes de programar
# Responde:
#
# - **¿Qué información esperas encontrar en la página?**
#   `____________________________________________________________________`
#
# - **¿Qué etiquetas, clases o patrones crees que tocará inspeccionar?**
#   `____________________________________________________________________`
#
# > Sugerencia: antes de scrapear, abre la página e inspecciona su HTML.

# %% [markdown]
# ### 1.1 Función simple para descargar HTML y manejar errores
#
# Completa la función para:
#
# - enviar una solicitud HTTP con `requests`
# - incluir un `User-Agent`
# - validar que la respuesta haya sido exitosa
# - devolver el HTML como texto
#
# **Pregunta guía:**
# ¿Por qué no conviene hacer solicitudes sin `timeout` ni manejo básico de errores?
# `__________________________________________________________________________`

# %%
def fetch_html(url: str, timeout: int = 30) -> str:
    """Descarga el HTML de una página web.

    Parámetros
    ----------
    url : str
        URL de la página a descargar.
    timeout : int
        Tiempo máximo de espera (segundos).

    Retorna
    -------
    str
        Contenido HTML de la página.
    """

    headers = {
        "User-Agent": "Mozilla/5.0 (compatible; TripleTen-DA-Beginner/1.0)"
    }

    # TODO 1: hacer la solicitud HTTP
    # response = ...

    # TODO 2: validar si la respuesta fue exitosa
    # ...

    # TODO 3: retornar el texto HTML
    # return ...

# Nota:
# ¿Qué pasaría si el sitio responde con error 404 o 500?
# _______________________________________________________

# %%
# Espacio opcional para probar la lógica de requests con otra URL sencilla.
# Puedes usarlo para experimentar con:
# - status_code
# - headers
# - raise_for_status()
# - response.text

# Ejemplo sugerido:
# test_url = "https://www.google.com"
# response = requests.get(test_url, headers=headers, timeout=30)
# print(response.status_code)

# Mis hallazgos:
# __________________________________________________________

# %% [markdown]
# ### 1.2 Descargar la página y encontrar los bloques de país
#
# Ahora usa tu función para descargar la página objetivo y guardar el HTML en una variable.
#
# **Antes de ejecutar**, predice:
# - ¿El HTML será corto o largo? `___________________`
# - ¿Crees que el sitio usa HTML simple o muy dinámico? `___________________`

# %%
url = "https://www.scrapethissite.com/pages/simple/"

# TODO: descargar el HTML usando tu función
# html = ...

# Verificación rápida sugerida:
# print(type(html))
# print(len(html))

# %%
# Muestra solo una pequeña parte del HTML para inspección inicial.
# Evita imprimir todo el documento si es demasiado largo.

# TODO:
# print(html[:1000])

# ¿Qué etiquetas o clases empezaste a reconocer?
# ____________________________________________________________

# %%
# TODO: parsear el HTML con BeautifulSoup
# soup = ...

# Pista:
# BeautifulSoup(html, "html.parser")

# %%
# Explora visualmente el objeto soup.
# Puedes mostrarlo, usar prettify() o inspeccionar una parte.

# Ejemplos:
# soup
# print(soup.prettify()[:1500])

# ¿Qué observaste sobre la estructura?
# ____________________________________________________________

# %%
# Cada país está dentro de un bloque con una clase específica.
# TODO: encuentra todos los bloques de país

# country_blocks = ...
# len(country_blocks)

# Pista:
# usa select(".country")

# %%
# Muestra una pequeña parte del contenido encontrado.
# No hace falta imprimir todos los bloques.

# TODO:
# country_blocks[:3]

# ¿Qué subelementos ves dentro de cada bloque?
# - nombre: ______________________
# - capital: _____________________
# - población: ___________________
# - área: ________________________

# %% [markdown]
# Si encontraste una cantidad grande de bloques y cada uno representa un país, vas por buen camino.
#
# ### Pausa de reflexión
# - ¿Cómo supiste que el selector elegido era correcto?
#   `____________________________________________________________________`
# - ¿Qué harías si el HTML no tuviera clases tan claras?
#   `____________________________________________________________________`

# %% [markdown]
# ### 1.3 Extraer datos y construir el DataFrame
#
# Completa el recorrido por `country_blocks` para extraer:
#
# - nombre del país
# - capital
# - población
# - área en km²
#
# Luego convierte la lista final en un `DataFrame`.
#
# **Meta:** obtener una tabla limpia con una fila por país.

# %%
rows = []

for block in country_blocks:
    # TODO: extraer cada campo usando select_one(...).get_text(strip=True)
    # name = ...
    # capital = ...
    # population = ...
    # area = ...

    # TODO: agregar un diccionario a rows
    # rows.append({
    #     "country": ...,
    #     "capital": ...,
    #     "population": ...,
    #     "area_km2": ...,
    # })

# TODO: crear el DataFrame raw
# df_raw = ...

# Verificación sugerida:
# display(df_raw.head())

# ¿Qué columnas quedaron como texto aunque representan números?
# ______________________________________________________________

# %% [markdown]
# ### 1.4 Limpieza inicial: convertir tipos numéricos
#
# En scraping es muy común que valores numéricos lleguen como texto.
#
# Convierte `population` y `area_km2` a tipo numérico.
#
# **Pregunta guía:**
# ¿Por qué `errors="coerce"` puede ser útil en una limpieza inicial?
# `__________________________________________________________________________`

# %%
# TODO: crear una copia de trabajo
# df = ...

# TODO: convertir columnas numéricas
# df["population"] = ...
# df["area_km2"] = ...

# Verificación sugerida:
# df.info()

# Mis observaciones:
# - Columna(s) numérica(s): ________________________________________
# - ¿Aparecieron nulos al convertir?: ______________________________

# %% [markdown]
# ### 1.5 Guardar una copia del dataset (raw)
#
# Guarda una versión del dataset para reutilizarla sin repetir el scraping.
#
# **Pregunta de proyecto:**
# ¿Por qué conviene guardar un CSV intermedio en un flujo analítico?
# `__________________________________________________________________________`

# %%
# TODO: exportar una copia del dataset
# df.to_csv("countries_scraped_raw.csv", index=False)

# Verificación opcional:
# print("Archivo guardado: countries_scraped_raw.csv")

# %% [markdown]
# # Ejercicio 2 · EDA básico con pandas (20 min)
#
# El **EDA** (Exploratory Data Analysis) te ayuda a:
#
# - entender estructura y tipos de datos
# - revisar rangos y distribuciones
# - detectar posibles problemas de calidad
# - encontrar ideas iniciales para el análisis
#
# ### Antes de ejecutar
# ¿Qué esperas del dataset?
#
# - **Número aproximado de filas:** `________________`
# - **Columnas que deberían existir:** `________________`
# - **Variables que podrían tener sesgo o mucha dispersión:** `________________`

# %% [markdown]
# ### 2.1 Vista rápida del dataset
#
# Usa una vista inicial para comprobar si los datos tienen sentido.

# %%
# TODO: mostrar las primeras 10 filas
# display(...)

# ¿Qué columnas entiendes sin dificultad?
# _____________________________________________________________

# %%
# TODO: revisar dimensiones del dataset
# ...

# Completa:
# - Número de filas: __________________
# - Número de columnas: _______________

# %% [markdown]
# ### 2.2 Estadísticas descriptivas
#
# Observa conteos, promedios, desviaciones y rangos para las variables numéricas.

# %%
# TODO: estadísticas descriptivas
# ...

# Responde con base en la salida:
# - ¿Qué variable parece tener más dispersión?
#   __________________________________________
# - ¿Ves valores extremos?
#   __________________________________________

# %% [markdown]
# ### 2.3 Revisar duplicados (si existen)
#
# Comprueba si el scraping dejó filas duplicadas.

# %%
# TODO: contar filas duplicadas
# ...

# Si encontraste duplicados, ¿qué harías?
# _____________________________________________________________

# %% [markdown]
# ### 2.4 Distribuciones simples (histogramas)
#
# Crea histogramas para entender la forma de las variables numéricas.

# %%
# Histograma de población
# TODO: construir el gráfico
# df["population"].plot(kind="hist", bins=30)
# plt.title("Distribución de population")
# plt.xlabel("population")
# plt.show()

# Interpretación:
# ¿La distribución parece simétrica, sesgada o con cola larga?
# ______________________________________________________________

# %%
# Histograma de área
# TODO: construir el gráfico
# df["area_km2"].plot(kind="hist", bins=30)
# plt.title("Distribución de area_km2")
# plt.xlabel("area_km2")
# plt.show()

# Interpretación:
# ¿Qué diferencias notas frente a population?
# ______________________________________________________________

# %% [markdown]
# ### 2.5 Scatter plot (relación visual básica)
#
# Usa un scatter plot para explorar la relación entre área y población.

# %%
# TODO: crear el scatter plot
# df.plot(kind="scatter", x="area_km2", y="population")
# plt.title("Population vs Area (km²)")
# plt.xlabel("area_km2")
# plt.ylabel("population")
# plt.show()

# Observaciones:
# - ¿Ves una relación lineal clara? ______________________________
# - ¿Hay outliers o países muy extremos? _________________________

# %% [markdown]
# # Ejercicio 3 · Vacíos y nulos (20 min)
#
# En datos reales es común encontrar:
#
# - **nulos** (`NaN`): ausencia real del dato
# - **vacíos** (`""`): texto vacío
# - valores “sucios”: espacios, `"N/A"`, `"unknown"`, etc.
#
# Aquí vas a practicar **detección**, **estandarización** y **tratamiento** con reglas simples.

# %% [markdown]
# ### 3.1 Simular vacíos/nulos (solo para la práctica)
#
# Vamos a crear faltantes artificiales para practicar el flujo de limpieza.

# %%
# TODO: crear una copia del dataset
# df_missing = df.copy()

# TODO: simular faltantes
# Sugerencia:
# 1) fija semilla
# 2) elige índices aleatorios
# 3) deja algunos capital = ""
# 4) deja algunos area_km2 = np.nan

# Ayuda opcional:
# np.random.seed(42)
# idx = np.random.choice(df_missing.index, size=10, replace=False)

# Verificación sugerida:
# display(df_missing.loc[idx, ["country", "capital", "area_km2"]].head(10))

# %% [markdown]
# ### 3.2 Detectar nulos (`NaN`) y vacíos (`""`)
#
# No es lo mismo un nulo real que una cadena vacía. Revisa ambas cosas.

# %%
# TODO: contar nulos por columna
# ...

# ¿Qué columnas tienen nulos?
# ______________________________________________________________

# %%
# TODO: contar vacíos en la columna capital
# ...

# Diferencia con tus palabras:
# nulo = _______________________________________________________
# vacío = ______________________________________________________

# %% [markdown]
# ### 3.3 Estandarizar vacíos → nulos
#
# Convierte vacíos en nulos para unificar el tratamiento.

# %%
# TODO: reemplazar "" por np.nan en capital
# ...

# TODO: volver a contar nulos
# ...

# ¿Por qué conviene estandarizar antes de imputar o eliminar?
# ______________________________________________________________

# %% [markdown]
# ### 3.4 Tratar faltantes con reglas simples
#
# Ahora aplica reglas claras y fáciles de explicar.

# %%
# Regla simple 1:
# Para correlación necesitamos population y area_km2.
# Si falta alguna, eliminamos esa fila.

# TODO:
# df_numeric_clean = ...

# Verificación sugerida:
# print("Antes:", df_missing.shape)
# print("Después:", df_numeric_clean.shape)

# ¿Cuántas filas perdiste y por qué?
# ______________________________________________________________

# %%
# Regla simple 2:
# Para capital, si falta, podemos imputar "Unknown".

# TODO:
# df_filled = ...
# df_filled["capital"] = ...

# Verificación sugerida:
# df_filled.isna().sum()

# ¿En qué casos sí usarías esta imputación y en cuáles no?
# ______________________________________________________________

# %% [markdown]
# # Ejercicio 4 · Correlación Pearson (15 min)
#
# La **correlación Pearson** mide la relación lineal entre dos variables numéricas.
#
# - **1** = relación positiva perfecta
# - **0** = sin relación lineal
# - **-1** = relación negativa perfecta
#
# ### Recuerda
# - Correlación **no implica causalidad**.
# - Pearson sirve para relación **lineal**, no para cualquier patrón.

# %% [markdown]
# ### 4.1 Matriz de correlación (pandas)
#
# Calcula la correlación entre `population` y `area_km2`.

# %%
# TODO: calcular la matriz de correlación con método Pearson
# corr = ...
# corr

# Pista:
# df_filled[["population", "area_km2"]].corr(method="pearson")

# %% [markdown]
# ### 4.2 Interpretación rápida (texto)
#
# Extrae el coeficiente y escríbelo con una frase de interpretación.

# %%
# TODO: extraer el coeficiente específico
# coef = ...

# TODO: imprimirlo con formato
# print(f"... {coef:.3f}")

# Interpretación en mis palabras:
# ______________________________________________________________
# ______________________________________________________________

# %% [markdown]
# ### 4.3 Scatter plot para apoyar la interpretación
#
# Acompaña el coeficiente con un gráfico.

# %%
# TODO: crear el scatter plot con los datos limpios
# df_filled.plot(kind="scatter", x="area_km2", y="population")
# plt.title("Population vs Area (km²) - Datos limpios")
# plt.xlabel("area_km2")
# plt.ylabel("population")
# plt.show()

# ¿El gráfico respalda la interpretación del coeficiente?
# ______________________________________________________________

# %% [markdown]
# # Ejercicio 5 · Exportar resultados y publicar en GitHub (10 min)
#
# Un mini‑proyecto publicable debería incluir, como mínimo:
#
# - el notebook
# - una carpeta `data/`
# - archivos exportados
# - un `README.md`
# - instrucciones para reproducir
#
# ### Antes de cerrar
# ¿Qué nombre le pondrías al repositorio?
# `______________________________________________________________`

# %% [markdown]
# ### 5.1 Exportar datasets (raw y limpio)
#
# Guarda una versión raw y una versión limpia.

# %%
import os

# TODO: crear carpeta data
# os.makedirs("data", exist_ok=True)

# TODO: exportar datasets
# df.to_csv("data/countries_raw.csv", index=False)
# df_filled.to_csv("data/countries_clean.csv", index=False)

# Verificación:
# print("Guardado:")
# print("- data/countries_raw.csv")
# print("- data/countries_clean.csv")

# %% [markdown]
# ## README.md (plantilla sugerida)
#
# Completa una plantilla mínima para documentar tu proyecto.

# %%
readme = """# Web Scraping + EDA (Countries)

## Objetivo
Escribe aquí una descripción breve del proyecto:
TODO

## Flujo de trabajo
1. TODO
2. TODO
3. TODO
4. TODO

## Fuente de datos
- https://www.scrapethissite.com/pages/simple/

## Archivos del proyecto
- `notebook.ipynb`
- `data/countries_raw.csv`
- `data/countries_clean.csv`

## Cómo reproducir
```bash
pip install requests beautifulsoup4 pandas matplotlib
```

## Hallazgo principal
TODO
"""

# TODO: guardar el README en disco
# with open("README.md", "w", encoding="utf-8") as f:
#     f.write(readme)

# print("README.md creado")

# %% [markdown]
# ## Paso a paso para subir a GitHub
#
# Marca lo que ya hiciste y anota dudas donde haga falta.

# %% [markdown]
# ### Opción A: GitHub Desktop (más fácil para principiantes)
#
# 1. Crear un repositorio en GitHub.
# 2. Vincular la carpeta local del proyecto.
# 3. Hacer el primer commit.
# 4. Hacer push al repositorio remoto.
#
# **Checklist**
# - [ ] Creé el repo
# - [ ] Añadí la carpeta local
# - [ ] Hice commit
# - [ ] Hice push
#
# ### Opción B: Git por consola
#
# Completa o ejecuta estos pasos cuando estés listo:
#
# ```bash
# git init
# git add .
# git commit -m "Initial commit: scraping + EDA"
# git branch -M main
# git remote add origin <URL_DE_TU_REPO>
# git push -u origin main
# ```
#
# **Anota aquí cualquier error de Git/GitHub:**
# `__________________________________________________________________________`

# %% [markdown]
# # Takeaways
#
# Completa este cierre al final de la sesión.
#
# ### Qué hice hoy
# - [ ] Descargué HTML desde una página web
# - [ ] Encontré elementos con selectores CSS
# - [ ] Construí un dataset en `pandas`
# - [ ] Revisé estructura y distribuciones
# - [ ] Traté vacíos y nulos
# - [ ] Calculé una correlación Pearson
# - [ ] Dejé el proyecto listo para publicar
#
# ### Mis conclusiones
# 1. **Concepto que me quedó claro:**
#    `__________________________________________________________________`
#
# 2. **Error que cometí y cómo lo resolví:**
#    `__________________________________________________________________`
#
# 3. **Hallazgo del análisis que me pareció más útil:**
#    `__________________________________________________________________`
#
# 4. **Próximo paso para mejorar este mini‑proyecto:**
#    `__________________________________________________________________`
#
# ### Ayuda y seguimiento
# Anota aquí qué le preguntarías al docente o qué te gustaría practicar después:
# `__________________________________________________________________________`
#
# ### ¿Necesitas ayuda?
# - `DATA-CO-LEARNING`: revisa los horarios de apoyo en la guía del estudiante.
# - `DA_CONSULTA`: publica dudas de contenido o del proyecto usando el tag correspondiente.
# - `SPRINT FOCUS`: sesiones extra para profundizar temas clave del sprint.
# - `SESIONES 1:1`: agenda con anticipación si necesitas apoyo individual.

# %% [markdown]
# ## Notas finales
#
# Espacio libre para apuntes, comandos, dudas o recordatorios de la sesión.
#
# `____________________________________________________________________________`
#
# `____________________________________________________________________________`
#
# `____________________________________________________________________________`
