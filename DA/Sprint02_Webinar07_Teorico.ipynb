# %% [markdown]
# # Sprint 2 - Webinar 7: PivotTables y Visualización — Student Version
#
# **Fecha:** ____________________
# **Dataset:** `sp2_w5_almacen_ventas.xlsx`
# **Herramientas:** Excel o Google Sheets
# **Nivel:** Intermedio
# **Duración total:** 120 minutos
#
# ---
#
# > 💬 **Pregunta de entrada:** Cuando tienes cientos o miles de filas, ¿qué tipo de preguntas responderías más rápido con una tabla dinámica que con revisión manual?
#
# _Escribe 2 ideas iniciales:_
#
# 1. _______________________________________________
# 2. _______________________________________________
#
# ---
#
# **Meta de la sesión:** construir tablas dinámicas, gráficos y un mini dashboard que te permitan pasar de datos transaccionales a hallazgos de negocio.

# %% [markdown]
# <div style="text-align: center">
#     <img src="https://raw.githubusercontent.com/ljpiere/tpdata_python/main/images/w1s1_2.png" width="350">
# </div>
#
# ### Observación inicial del dataset
# Antes de empezar, anota lo que **crees** que será más útil analizar:
#
# | Elemento | Tu hipótesis inicial |
# |---|---|
# | Región con más ventas | |
# | Producto que más aporta | |
# | Métrica que podría ser más importante | |
# | Riesgo de interpretar mal los datos | |

# %% [markdown]
# ## Objetivos de aprendizaje
#
# Completa la última columna al final de la sesión:
#
# | Objetivo | ¿Lo logré? | En mis palabras |
# |---|---|---|
# | Construir una PivotTable para resumir ventas por dimensiones | ☐ | |
# | Filtrar y ordenar resultados para enfocarme en segmentos relevantes | ☐ | |
# | Incorporar varias métricas en una misma tabla dinámica | ☐ | |
# | Interpretar resultados y redactar hallazgos útiles para negocio | ☐ | |
# | Elegir un gráfico adecuado según la pregunta analítica | ☐ | |
# | Diseñar una pestaña resumen tipo dashboard simple | ☐ | |
# | Usar un LLM como apoyo para ideas o validación, sin depender ciegamente de él | ☐ | |

# %% [markdown]
# ## Agenda (120 min)
#
# | Bloque | Tiempo | Contenido |
# |---|---|---|
# | Setup y reconocimiento del archivo | 10 min | Hojas, columnas y pregunta guía |
# | 4.1 Primera tabla dinámica | 25 min | Ventas por región y producto |
# | 4.2 Filtros y orden | 15 min | Fecha, vendedor y top segmentos |
# | 4.3 Múltiples métricas | 20 min | Ingresos, unidades, ticket promedio, % participación |
# | 4.4 Layout e interpretación | 10 min | Lectura de hallazgos |
# | 4.5 IA como apoyo | 10 min | Cortes, QA y validación |
# | 5.1–5.3 Visualización y dashboard | 25 min | Gráficos, formato condicional y resumen |
# | 5.4 Cierre y comunicación | 5 min | Insights ejecutivos |
#
# > **Producto esperado:** al menos 2 PivotTables, 1–2 gráficos y una hoja `Resumen` o `dashboard`.

# %% [markdown]
# ## Preparación (antes de la clase)
#
# Marca lo que ya verificaste:
#
# - ☐ Abrí el archivo `sp2_w5_almacen_ventas.xlsx`
# - ☐ Identifiqué la hoja `Raw Data`
# - ☐ Confirmé que `Date` se reconoce como fecha
# - ☐ Confirmé que `Units_Sold`, `Unit_Price` y `Total_Sales` son numéricas
# - ☐ Creé las hojas `Pivot_Trabajo` y `Resumen`
#
# ### Reconocimiento rápido del archivo
#
# | Pregunta | Tu respuesta |
# |---|---|
# | ¿Qué columnas tiene `Raw Data`? | |
# | ¿Cuál parece ser una dimensión? | |
# | ¿Cuál parece ser una métrica? | |
# | ¿Qué columna usarías para analizar tendencia en el tiempo? | |
# | ¿Qué columna usarías para segmentar por responsable comercial? | |
#
# > 💬 **Predicción:** ¿qué error sería más peligroso al construir una tabla dinámica: un campo mal tipado, un filtro mal aplicado o una métrica mal interpretada?
# _Tu respuesta:_ _______________________________________________

# %% [markdown]
# # 4. Analyzing Data with PivotTables (Dataset: `sp2_w5_almacen_ventas.xlsx`)
#
# Usaremos la hoja **`Raw Data`** con columnas como:
# - `Date`
# - `Region`
# - `Product`
# - `Units_Sold`
# - `Unit_Price`
# - `Salesperson`
# - `Total_Sales`
#
# ### Marco conceptual
# Completa esta tabla durante la explicación:
#
# | Concepto | ¿Qué significa? | Ejemplo con el dataset |
# |---|---|---|
# | Dimensión | | |
# | Métrica | | |
# | Agregación | | |
# | KPI | | |
# | Insight | | |
#
# > 💬 **Idea clave:** una PivotTable resume muchas filas en una vista compacta para comparar grupos y detectar patrones.
# Escribe con tus palabras: _______________________________________________

# %% [markdown]
# ## 4.1 Building Your First PivotTable (25 min)
#
# **Pregunta guía:** ¿Qué **regiones** y **productos** explican más `Total_Sales`?
#
# ### Paso a paso guiado
# 1. Selecciona el rango completo con encabezados en `Raw Data`.
# 2. Inserta una **tabla dinámica** en una hoja nueva o en `Pivot_Trabajo`.
# 3. Configura la pivot.
# 4. Verifica que el total general coincida con la suma manual del dataset.
#
# ### Completa la configuración
#
# | Elemento de la Pivot | Tu selección |
# |---|---|
# | Filas | |
# | Columnas | |
# | Valores | |
# | Tipo de agregación | |
# | ¿Mostraste totales? | ☐ Sí / ☐ No |
#
# ### QA rápido
#
# | Validación | Resultado |
# |---|---|
# | Total general de la Pivot | |
# | `=SUM(Total_Sales)` en los datos base | |
# | ¿Coinciden ambos valores? | ☐ Sí / ☐ No |
#
# ### Interpretación inicial
#
# | Pregunta | Tu respuesta |
# |---|---|
# | ¿Qué región aparece con mayor venta total? | |
# | ¿Qué producto domina visualmente la tabla? | |
# | ¿Qué combinación Región × Producto te llama la atención? | |
#
# > 💬 **Reflexión:** ¿qué ventaja tiene una tabla dinámica frente a construir manualmente muchas `SUMIF/SUMIFS`?
# _Tu respuesta:_ _______________________________________________

# %% [markdown]
# ## 4.2 Filtering and Sorting Inside PivotTables (15 min)
#
# **Objetivo:** reducir el ruido y enfocarte en un subconjunto relevante.
#
# ### Actividad
# Aplica al menos:
# - un filtro temporal
# - un filtro por vendedor o segmento
# - un orden descendente por ventas
#
# ### Bitácora de filtros
#
# | Configuración | Lo que aplicaste |
# |---|---|
# | Rango de fechas | |
# | Campo usado como filtro adicional | |
# | Criterio de exclusión o selección | |
# | Orden aplicado | |
#
# ### Resultado del análisis filtrado
#
# | Pregunta | Tu respuesta |
# |---|---|
# | ¿Qué cambió respecto a la Pivot inicial? | |
# | ¿Qué región quedó arriba después del filtro? | |
# | ¿Qué producto subió o bajó posiciones? | |
# | ¿Qué hallazgo no veías antes de filtrar? | |
#
# > 💬 **Anota en una frase:** ¿por qué es importante documentar los filtros aplicados cuando compartes resultados?
# _Tu respuesta:_ _______________________________________________

# %% [markdown]
# ## 4.3 Summarizing with Different Calculations (20 min)
#
# **Preguntas guía:**
# - ¿Cuál es el **volumen** vendido por grupo?
# - ¿Cuál es el **ticket promedio**?
# - ¿Qué **% del total** aporta cada segmento?
#
# ### Completa esta ficha de trabajo
#
# | Métrica | ¿Cómo la construirías? | ¿Dónde la pondrías? |
# |---|---|---|
# | `SUM(Total_Sales)` | | |
# | `SUM(Units_Sold)` | | |
# | `TicketProm = Total_Sales / Units_Sold` | | |
# | `% del total` | | |
#
# ### Campo calculado / fórmula auxiliar
# Escribe aquí la lógica que usarás para calcular el ticket promedio:
#
# ```text
# TicketProm = _______________________________________________
# ```
#
# ### Comparación de segmentos
#
# | Segmento (ej. Region o Product) | Ingresos | Unidades | Ticket promedio | % del total |
# |---|---:|---:|---:|---:|
# | | | | | |
# | | | | | |
# | | | | | |
#
# ### Interpretación
#
# | Pregunta | Tu respuesta |
# |---|---|
# | ¿Qué segmento tiene alto volumen pero ticket bajo? | |
# | ¿Qué segmento parece más “premium”? | |
# | ¿Qué interpretación de negocio harías de esa diferencia? | |

# %% [markdown]
# ## 4.4 Refining Layout & Interpreting Results (10 min)
#
# ### Mejora tu Pivot
# Marca lo que aplicaste:
#
# - ☐ Jerarquía en filas (por ejemplo `Region` → `Product`)
# - ☐ Subtotales y totales visibles
# - ☐ Formato moneda
# - ☐ Formato de número sin demasiados decimales
# - ☐ Títulos o nombres de campos más claros
# - ☐ Notas al lado con hallazgos
#
# ### Cuadro de lectura de resultados
#
# | Punto a revisar | Tu respuesta |
# |---|---|
# | Top 3 regiones por ingresos | |
# | Producto con mayor ticket en cada región | |
# | ¿Hay una región fuerte por volumen pero no por ticket? | |
# | Hipótesis del patrón observado | |
#
# > 💬 **Mini insight:** redacta 2 bullets con estructura **hallazgo → posible explicación**
# 1. _______________________________________________
# 2. _______________________________________________

# %% [markdown]
# ## 4.5 AI 🤖 Using LLMs to Propose Cuts/QA (10 min)
#
# El objetivo no es que el LLM haga el análisis por ti, sino usarlo como apoyo para:
# - proponer cortes adicionales
# - sugerir chequeos de calidad
# - ayudarte a redactar preguntas mejores
#
# ### Prompt de ejemplo
# > Tengo un dataset de ventas con columnas Date, Region, Product, Units_Sold, Unit_Price, Salesperson y Total_Sales. Ya hice una Pivot por Region y Product. Sugiere 3 cortes adicionales, 3 posibles problemas de calidad de datos y 2 preguntas de negocio que podría responder con otra tabla dinámica.
#
# ### Completa mientras observas o pruebas
#
# | Elemento | Respuesta del LLM | ¿La aceptarías? ¿Cómo la validarías? |
# |---|---|---|
# | Corte adicional 1 | | |
# | Corte adicional 2 | | |
# | Corte adicional 3 | | |
# | Riesgo o issue de calidad | | |
# | Nueva pregunta de negocio | | |
#
# > 💬 **Reflexión:** ¿qué tipo de respuesta sí le confiarías a un LLM y cuál no aceptarías sin validar en Sheets/Excel?
# _Tu respuesta:_ _______________________________________________

# %% [markdown]
# # 5. Visualizing and Highlighting Key Insights
#
# Trabajarás con los resultados de tus PivotTables para transformar tablas en elementos visuales más fáciles de comunicar.
#
# ### Antes de graficar
# Completa esta tabla:
#
# | Tipo de pregunta | Gráfico que usarías | ¿Por qué? |
# |---|---|---|
# | Comparar categorías | | |
# | Ver tendencia temporal | | |
# | Ver composición del total | | |
# | Resaltar outliers | | |
#
# > 💬 **Regla práctica:** el gráfico correcto depende de la pregunta, no de “lo bonito” que se vea.

# %% [markdown]
# ## 5.1 Right Chart for the Question (15 min)
#
# ### Actividad 1 — gráfico por categoría
# Construye un gráfico para mostrar los productos o regiones con más ventas.
#
# | Elemento | Tu decisión |
# |---|---|
# | Pregunta que responde | |
# | Tabla o Pivot usada como base | |
# | Tipo de gráfico | |
# | Eje X | |
# | Eje Y | |
#
# ### Actividad 2 — gráfico temporal
# Construye un gráfico para ver la evolución de ventas por mes.
#
# | Elemento | Tu decisión |
# |---|---|
# | ¿Creaste una columna `Month`? | ☐ Sí / ☐ No |
# | Fórmula o método usado | |
# | Tipo de gráfico | |
# | ¿Qué tendencia observas? | |
#
# ### Actividad 3 — composición
# Representa el peso de las regiones dentro del total.
#
# | Elemento | Tu decisión |
# |---|---|
# | Tipo de gráfico | |
# | ¿Qué región aporta más? | |
# | ¿Qué región aporta menos? | |
# | ¿Tu gráfico es fácil de leer? ¿Qué mejorarías? | |

# %% [markdown]
# ## 5.2 Conditional Formatting to Surface Outliers (10 min)
#
# ### Aplica al menos 2 reglas de formato condicional
#
# | Regla | ¿Dónde la aplicaste? | ¿Qué buscabas resaltar? |
# |---|---|---|
# | Escala de color | | |
# | Valor mayor a un umbral | | |
# | Top / Bottom | | |
# | Regla personalizada | | |
#
# ### Registro del criterio usado
#
# | Criterio | Tu valor |
# |---|---|
# | Umbral alto de ventas | |
# | Umbral bajo o outlier | |
# | ¿Usaste percentiles o un valor fijo? | |
# | ¿Anotaste la regla aplicada? | ☐ Sí / ☐ No |
#
# > 💬 **Pregunta:** ¿qué riesgo existe si usas formato condicional muy agresivo o arbitrario?
# _Tu respuesta:_ _______________________________________________

# %% [markdown]
# ## 5.3 Simple Summary Dashboard (10 min)
#
# ### Diseña una hoja `Resumen` o `dashboard`
# Incluye como mínimo:
# - 2 KPIs
# - 1 tabla resumen o Pivot
# - 1 o 2 gráficos
# - título y rango de fechas analizado
#
# ### Plan del dashboard
#
# | Componente | Qué mostrarás | Fórmula / fuente |
# |---|---|---|
# | KPI 1 | | |
# | KPI 2 | | |
# | Tabla resumen | | |
# | Gráfico 1 | | |
# | Gráfico 2 (opcional) | | |
#
# ### Fórmulas sugeridas
# Completa o adapta:
#
# - **Ingresos del período:** `=SUMIFS( __________________________ )`
# - **Ticket promedio:** `= __________________________ `
# - **Top región o top producto:** `= __________________________ `
#
# ### Auto-chequeo visual
#
# - ☐ Los títulos son claros
# - ☐ Los formatos de moneda / fecha son consistentes
# - ☐ El dashboard no está saturado
# - ☐ Se entiende qué filtros o período se analizaron

# %% [markdown]
# ## 5.4 Communicating Insights (5 min)
#
# En la hoja `Resumen` o en una diapositiva/espacio de notas, redacta 3 bullets con esta estructura:
#
# **contexto → hallazgo → implicación / acción**
#
# 1. _______________________________________________
# 2. _______________________________________________
# 3. _______________________________________________
#
# ### Mini slide o mini resumen ejecutivo
#
# | Elemento | Tu borrador |
# |---|---|
# | Título ejecutivo | |
# | Qué pasó | |
# | Por qué podría estar pasando | |
# | Qué harías a continuación | |

# %% [markdown]
# ## Evaluación rápida (auto-chequeo)
#
# Marca lo que sí lograste hoy:
#
# - ☐ Construí una PivotTable funcional
# - ☐ Validé el total general contra la base original
# - ☐ Apliqué filtros y documenté mis criterios
# - ☐ Añadí más de una métrica en la tabla dinámica
# - ☐ Interpreté resultados y no solo los mostré
# - ☐ Elegí un gráfico coherente con la pregunta
# - ☐ Usé formato condicional con un criterio claro
# - ☐ Armé una hoja de resumen tipo dashboard
# - ☐ Escribí 2–3 insights de negocio

# %% [markdown]
# ## Rúbrica sugerida (10 pts)
#
# Completa una autoevaluación honesta:
#
# | Criterio | Puntaje máximo | Mi puntaje |
# |---|---:|---:|
# | PivotTables correctas y bien configuradas | 4 | |
# | Uso de filtros, orden y varias métricas | 2 | |
# | Gráficos claros y útiles | 2 | |
# | Dashboard e insights ejecutivos | 2 | |
#
# **Total:** __________ / 10

# %% [markdown]
# ## Tips y buenas prácticas
#
# Marca cuáles aplicaste y anota una observación:
#
# | Buena práctica | ¿La apliqué? | Observación |
# |---|---|---|
# | Verificar que fechas y números estén bien tipados | ☐ | |
# | Validar el total de la Pivot contra la base | ☐ | |
# | Documentar filtros aplicados | ☐ | |
# | Evitar gráficos saturados o con demasiadas categorías | ☐ | |
# | Usar nombres claros en títulos y campos | ☐ | |
# | Validar cualquier sugerencia del LLM con cálculos reales | ☐ | |
#
# > 💬 **Consejo personal para mí en futuras clases:** _______________________________________________

# %% [markdown]
# ## (Opcional) Pistas breves
#
# <details>
# <summary>Ver pistas</summary>
#
# - **4.1**: empieza con una Pivot simple: `Region` en filas y `SUM(Total_Sales)` en valores.
# - **4.2**: filtrar cambia la historia que cuenta tu tabla; anótalo siempre.
# - **4.3**: no confundas “alto volumen” con “alto ticket”.
# - **4.4**: una buena tabla no solo calcula; también se lee fácil.
# - **4.5**: usa al LLM para ideas, no para aceptar números finales.
# - **5.1**: barras para comparar, líneas para tendencia.
# - **5.2**: resalta lo importante, no todo.
# - **5.3**: un dashboard simple suele comunicar mejor que uno recargado.
# - **5.4**: un insight útil conecta dato con acción.
#
# </details>

# %% [markdown]
# ## Cierre
#
# ### Reflexión final
#
# | Pregunta | Tu respuesta |
# |---|---|
# | ¿Cuándo preferirías una tabla dinámica sobre una fórmula manual? | |
# | ¿Qué fue más difícil: configurar la Pivot, interpretar los resultados o comunicar el hallazgo? | |
# | ¿Qué error habría sido más costoso si no lo detectabas? | |
# | ¿Qué concepto te gustaría repasar en la próxima sesión? | |
#
# ### Notas del Kahoot / discusión final
# - _______________________________________________
# - _______________________________________________
# - _______________________________________________

# %% [markdown]
# ## Siguientes Pasos
#
# - **Próxima sesión:** continuar profundizando en análisis aplicado con archivos de negocio.
# - **Práctica recomendada:** crea 2 tablas dinámicas adicionales cambiando la dimensión principal (por ejemplo, `Salesperson` o `Month`).
# - **Mini tarea personal:** formula una pregunta de negocio que responderías con una nueva Pivot.
#
# **Formato sugerido:** `[métrica]` para `[grupo]` en `[tiempo]`
#
# _Tu pregunta:_ _______________________________________________
#
# ### ¿Necesitas ayuda?
# Recuerda los canales de ayuda que tenemos disponibles:
# - `DATA-CO-LEARNING`: Revisa los horarios de atencion en la guia dele studiante. Recuerda que tenemos horarios de apoyo todos los días para tus dudas puntuales!
# - `DA_CONSULTA`: Uuedes publicar tus preguntas sobre el contenido de la plataforma o el proyecto 24/7. Recuerda que en tu pregunta debes de agregar el tag @Dataconsulta.
# - `SPRINT FOCUS`: Para los Sprints 1 al 5 tenemos sesiones extra donde abordamos temáticas de cada sprint a rpofundidad. Revisa la guia del estudiante para conocer los horarios!
# - `SESIONES 1:1`: Recuerda que puedes agendar sesiones 1:1 con un tutor. Agendalas con antelación y resuelve todas tus dudas, desde temás del proyecto, curso, carrera hasta problemas técnicos.
# - `CANAL DE DISCORD DE COMMUNITY`: Recuerda que tu cohorte tiene un canal especial donde puedes compartir cualquier item interesante que quieras mostrar a tus compañeros de curso.
#
# ### Dudas que quiero llevar a clase o a Discord
#
# 1. _______________________________________________
# 2. _______________________________________________
