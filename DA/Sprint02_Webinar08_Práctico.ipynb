# %% [markdown]
# # Sprint 2 - Webinar 6 - Clase 120 min: Warm‑Up Proyecto Walmart — Student Version
#
# **Enfoque:** práctica guiada *similar* al proyecto, **sin solución completa**
# **Fecha:** ____________________
# **Trabajo en:** Excel o Google Sheets (sin Python/pandas)
# **Archivo base:** `sp2_Projecto 2 _ Student.xlsx`
# **Datasets del proyecto (referencia):** `sales.csv`, `stores.csv`, `departments.csv`
#
# > Este cuaderno es tu guía de trabajo en clase. Úsalo para **tomar apuntes**, **registrar decisiones**, **completar ejercicios**, **anotar fórmulas** y **documentar hallazgos** mientras avanzas en el caso Walmart.

# %% [markdown]
# <div style="text-align: center">
#     <img src="https://raw.githubusercontent.com/ljpiere/tpdata_python/main/images/3_11.png" width="400">
# </div>
#
# ### Observación inicial
# Antes de empezar, responde en 2–3 líneas:
#
# - ¿Qué tipo de análisis crees que permite este caso?
# - ¿Qué columnas o variables imaginas que serán más importantes?
# - ¿Qué problemas de calidad de datos podrían aparecer?

# %% [markdown]
# ---
# ## Objetivos de aprendizaje
#
# Completa la última columna al final de la sesión:
#
# | Objetivo | ¿Lo logré? | En mis palabras |
# |---|---|---|
# | Importar y organizar correctamente los archivos fuente | ☐ Sí / ☐ Parcial / ☐ No | |
# | Limpiar ventas por tienda, departamento y semana | ☐ Sí / ☐ Parcial / ☐ No | |
# | Enriquecer la tabla de ventas con dimensiones de tienda y catálogo | ☐ Sí / ☐ Parcial / ☐ No | |
# | Construir KPIs útiles para analizar desempeño comercial | ☐ Sí / ☐ Parcial / ☐ No | |
# | Diseñar un dashboard simple pero claro | ☐ Sí / ☐ Parcial / ☐ No | |
# | Documentar QA, supuestos y decisiones de trabajo | ☐ Sí / ☐ Parcial / ☐ No | |

# %% [markdown]
# ## Material y agenda
#
# **Datasets esperados:** `sp2_w4_walmart_sales.csv`, `sp2_w4_walmart_stores.csv`, `sp2_w4_walmart_departments.csv`
# **Salida esperada:** libro con hojas `raw_*`, `clean_sales`, `kpi_*`, `dashboard`, `README`, `QA_checks`, `change_log`
#
# | Bloque | Tiempo | Qué haremos |
# |---|---:|---|
# | Preparación | 5 min | Importación, orden y control inicial |
# | Parte 1 — Limpieza | 25 min | Estandarizar tipos, fechas y columnas |
# | Parte 2 — Enriquecimiento | 35 min | Integrar dimensiones y validar joins |
# | Parte 3 — KPIs | 70 min | Eficiencia, crecimiento YoY y participación |
# | Parte 4 — Dashboard | 40 min | Llevar KPIs y gráficos a una hoja ejecutiva |
# | Parte 5 — C→F→I | 10 min | Convertir resultados en acciones |
# | Parte 6 — QA & README | 5 min | Validar consistencia y documentar |
# | Cierre | 5 min | Reflexión, entregables y pendientes |
#
# ### Meta personal de hoy
# Escribe qué te gustaría lograr al terminar la clase:
#
# ____________________________________________________
#
# ____________________________________________________

# %% [markdown]
# ---
# ## 0. Preparación
#
# Marca lo que ya verificaste:
#
# - ☐ Creé un archivo nuevo en Google Sheets o abrí el Excel base.
# - ☐ Importé `sales`, `stores` y `departments`.
# - ☐ Renombré hojas como `raw_sales`, `raw_stores`, `raw_departments`.
# - ☐ Congelé fila 1 y activé filtros.
# - ☐ Creé una hoja `change_log`.
#
# ### Registro inicial en `change_log`
# Completa esta mini-bitácora:
#
# | Fecha | Acción | Autor | Observación |
# |---|---|---|---|
# | | Importación de `raw_*` | | |
# | | Activación de filtros / congelado | | |
# | | | | |
#
# ### Exploración rápida
# Sin hacer cambios todavía, responde:
#
# | Pregunta | Tu respuesta |
# |---|---|
# | ¿Qué columnas trae `raw_sales`? | |
# | ¿Qué columna parece ser la llave para unir con `raw_stores`? | |
# | ¿Qué columna parece ser la llave para unir con `raw_departments`? | |
# | ¿Qué campo será clave para análisis temporal? | |

# %% [markdown]
# ---
# # Parte 1 — Limpieza
#
# ## 1.1 Duplica y protege la fuente
# - Duplica `raw_sales` y renómbrala **`clean_sales`**.
# - No edites la hoja raw.
#
# ### Antes de transformar, anota:
# - ¿Por qué conviene trabajar sobre una copia?
#
#   ____________________________________________________
#
# - ¿Qué podría salir mal si modificas la hoja raw?
#
#   ____________________________________________________
#
# ## 1.2 Revisión de encabezados y tipos
# Verifica si los nombres esperados están correctamente escritos:
#
# - `Store`
# - `Dept`
# - `Date`
# - `Weekly_Sales`
# - `IsHoliday`
#
# ### Checklist de limpieza
# Marca y documenta:
#
# | Validación | ¿Hecha? | Evidencia / nota |
# |---|---|---|
# | Encabezados claros y consistentes | ☐ | |
# | `Date` en formato fecha | ☐ | |
# | `Weekly_Sales` en formato numérico | ☐ | |
# | `Store`, `Dept`, `IsHoliday` sin espacios raros | ☐ | |
# | Filtros activos para revisar anomalías | ☐ | |
#
# ## 1.3 Semana estándar
# Agrega y completa estas columnas nuevas:
#
# - `Year`
# - `Week`
#
# ### Fórmulas esperadas
# Escribe aquí la fórmula que usaste o la que te sugirió el docente:
#
# | Columna | Fórmula / procedimiento | Comentario |
# |---|---|---|
# | `Year` | | |
# | `Week` | | |
#
# ### Breakout Room — diagnóstico inicial
# Completa con tu grupo:
#
# 1. ¿Detectaron filas problemáticas o valores sospechosos?
#    ____________________________________________________
#
# 2. ¿Qué regla usarán para decidir si una fecha es válida?
#    ____________________________________________________
#
# 3. ¿Qué dejarán registrado en `change_log`?
#    ____________________________________________________

# %% [markdown]
# ## 1.4 Resultado esperado de la limpieza
#
# Al final de esta parte, `clean_sales` debería tener como mínimo:
#
# - `Store`
# - `Dept`
# - `Date`
# - `Weekly_Sales`
# - `IsHoliday`
# - `Year`
# - `Week`
#
# ### Evidencia de salida
# Completa:
#
# | Pregunta | Tu respuesta |
# |---|---|
# | Número de filas en `clean_sales` | |
# | ¿Todas las fechas quedaron válidas? | |
# | ¿Hubo que corregir texto o números? | |
# | ¿Qué fue lo más difícil de esta etapa? | |
#
# ### Mini reflexión
# ¿Por qué la limpieza no es “solo formato” sino parte del análisis?
#
# ____________________________________________________
#
# ____________________________________________________

# %% [markdown]
# ---
# # Parte 2 — Enriquecimiento
#
# **Objetivo:** añadir atributos de tienda y catálogo para convertir la base en una tabla más analítica.
#
# ## 2.1 Join con `raw_stores`
# Añade al final de `clean_sales`:
#
# - `Type`
# - `Size`
#
# ## 2.2 Join con `raw_departments`
# Añade:
#
# - `dept_name`
#
# ### Guía de trabajo
# Completa esta tabla mientras avanzas:
#
# | Campo nuevo | Hoja origen | Llave usada | Fórmula o método | ¿Funcionó? |
# |---|---|---|---|---|
# | `Type` | | | | ☐ |
# | `Size` | | | | ☐ |
# | `dept_name` | | | | ☐ |
#
# ### Verificación del join
# Filtra resultados como `"No Match"` o equivalentes y completa:
#
# | Revisión | Resultado |
# |---|---|
# | ¿Hubo tiendas sin match? | |
# | ¿Hubo departamentos sin match? | |
# | ¿Qué causa encontraste? | |
# | ¿Cómo lo resolviste o documentaste? | |
#
# ## 2.3 Estadísticos rápidos
# Registra aquí los valores que calculaste:
#
# | Métrica | Resultado |
# |---|---|
# | Total de filas | |
# | Ventas totales | |
# | Número de tiendas únicas | |
# | Número de departamentos únicos | |
#
# ### Nota de clase
# ¿Por qué este paso mejora la capacidad de análisis del caso?
#
# ____________________________________________________
#
# ____________________________________________________

# %% [markdown]
# ## 2.4 Salida mínima de enriquecimiento
#
# Marca lo que ya quedó completo:
#
# - ☐ `clean_sales` tiene `Type`
# - ☐ `clean_sales` tiene `Size`
# - ☐ `clean_sales` tiene `dept_name`
# - ☐ Revisé valores sin match
# - ☐ Registré correcciones en `change_log`
#
# ### Pregunta de comprensión
# ¿Qué diferencia hay entre una tabla de hechos y una dimensión en este caso?
#
# **Tu respuesta:**
#
# ____________________________________________________
#
# ____________________________________________________

# %% [markdown]
# ---
# # Parte 3 — KPIs
#
# En esta sección construirás **una hoja o Pivot por KPI**. No se trata solo de calcular, sino de dejar evidencia de:
#
# 1. cómo configuraste el cálculo,
# 2. qué resultado obtuviste,
# 3. cómo lo interpretas.
#
# Antes de empezar, responde:
#
# - ¿Qué hace valioso a un KPI en un contexto de negocio?
#
#   ____________________________________________________
#
# - ¿Qué riesgo hay en construir un KPI correcto técnicamente pero poco útil para decidir?
#
#   ____________________________________________________

# %% [markdown]
# ## KPI 1 — Eficiencia (Ventas por m²)
#
# **Definición:** `Sales_per_m2 = SUM(Weekly_Sales) / AVG(Size)` por `Store`
#
# ### Configuración esperada
# Completa:
#
# | Elemento Pivot / tabla | Configuración |
# |---|---|
# | Hoja de salida | |
# | Filas | |
# | Valores 1 | |
# | Valores 2 | |
# | Cálculo final | |
#
# ### Resultado
# Registra lo más importante:
#
# | Pregunta | Tu respuesta |
# |---|---|
# | Tienda con mayor eficiencia | |
# | Tienda con menor eficiencia | |
# | ¿El total de ventas cuadra con la base? | |
# | ¿Qué gráfico usaste? | |
#
# ### Interpretación
# Redacta 2 hallazgos:
#
# 1. ____________________________________________________
#
# 2. ____________________________________________________
#
# ### Hipótesis
# ¿Por qué una tienda grande podría no ser eficiente?
#
# ____________________________________________________

# %% [markdown]
# ## KPI 2 — Crecimiento interanual (YoY)
#
# **Definición:** `YoY = (Sales_{Y} - Sales_{Y-1}) / Sales_{Y-1}`
#
# ### Configuración esperada
# Si el dataset no tiene `Region`, define con el docente si usarás `Type` o `Store`.
#
# | Elemento Pivot / tabla | Configuración |
# |---|---|
# | Hoja de salida | |
# | Filas | |
# | Columnas | |
# | Valores | |
# | Fórmula YoY fuera o dentro de la Pivot | |
#
# ### Validaciones
# Marca y anota:
#
# - ☐ Revisé que el año base no fuera cero
# - ☐ Evité divisiones por cero
# - ☐ Formateé el resultado como porcentaje
# - ☐ Elegí un gráfico coherente
#
# ### Resultado
# | Pregunta | Tu respuesta |
# |---|---|
# | Segmento con mejor crecimiento | |
# | Segmento con peor crecimiento | |
# | ¿Hay valores atípicos o poco creíbles? | |
# | ¿Qué explicación posible encuentras? | |
#
# ### Nota de negocio
# ¿Por qué crecimiento no siempre significa buen desempeño?
#
# ____________________________________________________

# %% [markdown]
# ## KPI 3 — Participación por departamento
#
# **Definición:** `Share = Sales_dept / Sales_total`
#
# ### Configuración esperada
# Completa:
#
# | Elemento | Configuración |
# |---|---|
# | Hoja de salida | |
# | Filas | |
# | Valores | |
# | Método para % del total | |
# | Tipo de gráfico | |
#
# ### Resultado
# | Pregunta | Tu respuesta |
# |---|---|
# | Top 3 departamentos | |
# | % acumulado de esos departamentos | |
# | ¿El negocio está concentrado o diversificado? | |
# | ¿Qué insight te parece más relevante? | |
#
# ### Reflexión
# ¿Qué decisiones podría tomar un gerente a partir de este KPI?
#
# ____________________________________________________
#
# ____________________________________________________

# %% [markdown]
# ## Resumen comparativo de KPIs
#
# Completa esta tabla al terminar los tres indicadores:
#
# | KPI | Qué mide | Nivel de análisis | Principal hallazgo | Riesgo de interpretación |
# |---|---|---|---|---|
# | Eficiencia | | | | |
# | Crecimiento YoY | | | | |
# | Participación por depto | | | | |
#
# ### Pausa de síntesis
# ¿Cuál de los tres KPIs te pareció más útil? ¿Por qué?
#
# ____________________________________________________
#
# ____________________________________________________

# %% [markdown]
# ---
# # Parte 4 — Dashboard
#
# ## 4.1 Diseño de la hoja `dashboard`
# Anota cómo organizaste tu hoja:
#
# | Zona | Qué pusiste allí |
# |---|---|
# | Encabezado / título | |
# | KPI 1 | |
# | KPI 2 | |
# | KPI 3 | |
# | Insights escritos | |
# | Segmentadores / filtros | |
#
# ## 4.2 KPIs que llevaste al dashboard
# Registra fórmulas, vínculos o referencias usadas:
#
# | Elemento | Fuente / fórmula / rango |
# |---|---|
# | Ventas totales | |
# | KPI adicional 1 | |
# | KPI adicional 2 | |
#
# ## 4.3 Visualización
# Marca qué componentes sí incluiste:
#
# - ☐ Gráfico Top‑10 eficiencia
# - ☐ Gráfico YoY
# - ☐ Gráfico share por depto
# - ☐ Título claro
# - ☐ Fecha de actualización
# - ☐ Formato consistente
# - ☐ Segmentadores
#
# ### Revisión de diseño
# ¿Qué cambiarías para que el dashboard fuera más ejecutivo?
#
# ____________________________________________________
#
# ____________________________________________________

# %% [markdown]
# ## 4.4 Insights accionables
#
# Redacta 3 insights con esta estructura:
#
# **qué pasó → por qué podría estar pasando → qué harías**
#
# 1. ____________________________________________________
#
# 2. ____________________________________________________
#
# 3. ____________________________________________________
#
# ### Extra
# Si agregaste un segmentador por `IsHoliday`, anota aquí qué observaste:
#
# ____________________________________________________
#
# ____________________________________________________

# %% [markdown]
# ---
# # Parte 5 — C→F→I
#
# **Cifras → Factores → Iniciativas**
#
# Completa esta tabla con base en tu análisis:
#
# | Cifras (qué pasó) | Factores (por qué) | Iniciativas (qué hacer) | Responsable | Fecha objetivo |
# |---|---|---|---|---|
# | | | | | |
# | | | | | |
# | | | | | |
#
# ### Nota de clase
# ¿Por qué esta parte es importante cuando presentas resultados a stakeholders?
#
# ____________________________________________________
#
# ____________________________________________________

# %% [markdown]
# ---
# # Parte 6 — QA & README
#
# ## 6.1 README
# Asegúrate de documentar:
#
# - objetivo del trabajo
# - datasets fuente
# - definición de KPIs
# - supuestos
# - pendientes
# - autor / fecha
#
# ## 6.2 QA_checks
# Completa este control mínimo:
#
# | Validación | ¿Cumple? | Evidencia / comentario |
# |---|---|---|
# | Totales de ventas cuadran con la base | ☐ | |
# | No quedan `"No Match"` sin revisar | ☐ | |
# | Fechas válidas | ☐ | |
# | Semanas calculadas correctamente | ☐ | |
# | No hay divisiones por cero en YoY | ☐ | |
# | Dashboard muestra datos coherentes | ☐ | |
#
# ### Producción vs práctica
# Si esto fuera un flujo productivo real, ¿qué automatizarías primero?
#
# ____________________________________________________
#
# ____________________________________________________

# %% [markdown]
# ---
# ## Entregables mínimos al cierre
#
# Marca lo que sí dejaste listo hoy:
#
# - ☐ `clean_sales` completo y consistente
# - ☐ `kpi_efficiency` funcional
# - ☐ `kpi_growth` funcional
# - ☐ `kpi_share` funcional
# - ☐ `dashboard` con al menos 3 visuales
# - ☐ `README` creado
# - ☐ `QA_checks` creado
# - ☐ `change_log` con entradas básicas
#
# ### Estado general de avance
# Selecciona una opción y explica por qué:
#
# - ☐ Muy adelantado
# - ☐ Bien encaminado
# - ☐ Necesito reforzar varios pasos
#
# **Comentario:**
#
# ____________________________________________________

# %% [markdown]
# ## Rúbrica sugerida y autoevaluación
#
# | Criterio | Puntaje máximo | Mi puntaje | Observación |
# |---|---:|---:|---|
# | Limpieza y llaves | 2 | | |
# | Enriquecimiento correcto | 2 | | |
# | KPIs correctos y replicables | 3 | | |
# | Dashboard claro y útil | 2 | | |
# | README / QA mínimos | 1 | | |
#
# ### Lo que debo repasar después de clase
# - _______________________________________________
# - _______________________________________________
# - _______________________________________________

# %% [markdown]
# ## Tips y pistas breves
#
# <details>
# <summary>Ver pistas</summary>
#
# - En limpieza, primero valida tipos antes de crear nuevas columnas.
# - En enriquecimiento, revisa si las llaves realmente tienen el mismo formato.
# - En KPI 1, recuerda que eficiencia no es lo mismo que ventas totales.
# - En KPI 2, no interpretes crecimiento sin revisar la base de comparación.
# - En KPI 3, un porcentaje alto puede ser bueno o riesgoso según la concentración.
# - En el dashboard, menos elementos pero mejor organizados suele comunicar más.
#
# </details>

# %% [markdown]
# ## Cierre
#
# ### Reflexión final
#
# | Pregunta | Tu respuesta |
# |---|---|
# | ¿Qué fue más desafiante: limpiar, enriquecer o interpretar? | |
# | ¿Qué aprendiste hoy que podrías reutilizar en otro proyecto? | |
# | ¿Qué error evitarías la próxima vez? | |
# | ¿Qué parte todavía te genera dudas? | |
#
# ### Kahoot / preguntas rápidas
# Anota aquí conceptos o dudas que surgieron:
#
# - _______________________________________________
# - _______________________________________________
# - _______________________________________________

# %% [markdown]
# ## Siguientes pasos
#
# - **Próxima sesión:** Sprint 3 - Introducción a SQL y Bases de Datos.
# - **Antes de la próxima clase:** revisa si tus KPIs responden preguntas reales de negocio.
# - **Práctica recomendada:** intenta rehacer uno de los KPIs cambiando el nivel de análisis (por ejemplo, de `Store` a `Type` o `Dept`).
#
# ### ¿Necesitas ayuda?
# Recuerda los canales de ayuda que tenemos disponibles:
# - `DATA-CO-LEARNING`: Revisa los horarios de atencion en la guia dele studiante. Recuerda que tenemos horarios de apoyo todos los días para tus dudas puntuales!
# - `DA_CONSULTA`: Uuedes publicar tus preguntas sobre el contenido de la plataforma o el proyecto 24/7. Recuerda que en tu pregunta debes de agregar el tag @Dataconsulta.
# - `SPRINT FOCUS`: Para los Sprints 1 al 5 tenemos sesiones extra donde abordamos temáticas de cada sprint a rpofundidad. Revisa la guia del estudiante para conocer los horarios!
# - `SESIONES 1:1`: Recuerda que puedes agendar sesiones 1:1 con un tutor. Agendalas con antelación y resuelve todas tus dudas, desde temás del proyecto, curso, carrera hasta problemas técnicos.
# - `CANAL DE DISCORD DE COMMUNITY`: Recuerda que tu cohorte tiene un canal especial donde puedes compartir cualquier item interesante que quieras mostrar a tus compañeros de curso.
