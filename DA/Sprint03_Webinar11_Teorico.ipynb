# %% [markdown]
# # Sprint 3 - Webinar 11: KPIs financieros con SQL en SQL Workbench — Student Version
#
# **Fecha:** ____________________
# **Herramienta:** DuckDB en `https://sql-workbench.com/`
# **Dataset:** *Bookstore* (`customers`, `orders`, `order_items`, `products`, `payments`)
# **Modalidad:** teoría guiada + práctica acompañada
#
# ### Propósito de la sesión
# Hoy aprenderás a construir **KPIs financieros** con SQL y a convertir una consulta en una recomendación de negocio.
#
# **Mi expectativa para la clase:**
# ____________________________________________________________
# ____________________________________________________________

# %% [markdown]
# ## Objetivos de aprendizaje
#
# Completa la última columna al final de la sesión.
#
# | Objetivo | ¿Lo logré? | En mis palabras |
# |---|---|---|
# | Calcular `revenue` y `cost` con joins y agregaciones | ☐ Sí / ☐ Parcial / ☐ No | |
# | Explicar qué es `gross_profit` y `margin_pct` | ☐ Sí / ☐ Parcial / ☐ No | |
# | Construir un ejemplo básico de `ROI` con una tabla temporal | ☐ Sí / ☐ Parcial / ☐ No | |
# | Validar un KPI antes de reportarlo | ☐ Sí / ☐ Parcial / ☐ No | |
# | Organizar un reporte SQL claro para stakeholders | ☐ Sí / ☐ Parcial / ☐ No | |
# | Analizar una tendencia mensual y sacar conclusiones | ☐ Sí / ☐ Parcial / ☐ No | |

# %% [markdown]
# ## Agenda (100 min)
#
# | Bloque | Tiempo | Qué haré |
# |---|---:|---|
# | 0) Setup y carga del dataset | 10 min | |
# | 1) Modelo mental: de transacciones a KPIs | 5 min | |
# | 2) KPIs financieros principales | 35 min | |
# | 3) Reportes financieros y comunicación | 30 min | |
# | 4) Tendencias y preguntas de negocio | 20 min | |
# | 5) Cierre | 5 min | |
#
# **Pregunta guía de la sesión:**
# ¿Cómo paso de “tablas transaccionales” a “métricas financieras listas para tomar decisiones”?

# %% [markdown]
# ## 0) Setup en SQL Workbench
#
# Marca lo que ya verificaste:
#
# - ☐ Abrí `https://sql-workbench.com/`
# - ☐ Confirmé que estoy usando **DuckDB**
# - ☐ Tengo claro que hoy trabajaré con **SQL**, no con Python
# - ☐ Recuerdo las tablas del dataset Bookstore
# - ☐ Entiendo que hoy **no** usaremos CTEs (`WITH ... AS`)
#
# ### Registro de errores
# Cada vez que una consulta falle, completa esta tabla antes de corregirla:
#
# | Consulta / bloque | Error que apareció | Posible causa | ¿Cómo lo corregí? |
# |---|---|---|---|
# | | | | |
# | | | | |
# | | | | |

# %% [markdown]
# ## 1) Cargar el dataset desde GitHub
#
# En esta sesión el docente compartirá un bloque para crear vistas desde archivos publicados en GitHub.
#
# ### Verificación esperada
# Después de ejecutar el bloque de carga, registra qué ocurrió.
#
# | Vista | ¿Se creó sin error? | Nº filas aproximado | Observación |
# |---|---|---:|---|
# | `customers` | ☐ | | |
# | `orders` | ☐ | | |
# | `order_items` | ☐ | | |
# | `products` | ☐ | | |
# | `payments` | ☐ | | |
#
# ### Mini chequeo
# - Tabla con más filas: ______________________________
# - Tabla con menos filas: _____________________________
# - Campo de fecha principal en `orders`: __________________
# - Campo de precio principal en `products` o `order_items`: __________________
#
# ### Si algo falla
# Marca la causa más probable:
#
# - ☐ nombre de tabla incorrecto
# - ☐ nombre de columna incorrecto
# - ☐ problema con la URL
# - ☐ error de sintaxis
# - ☐ otro: ______________________

# %%
-- Pega aquí el bloque de carga que comparta el docente.
-- Luego ejecuta consultas cortas para validar que todas las vistas existen.

-- Ejemplo:
-- SELECT COUNT(*) FROM customers;
-- SELECT COUNT(*) FROM orders;
-- SELECT COUNT(*) FROM order_items;
-- SELECT COUNT(*) FROM products;
-- SELECT COUNT(*) FROM payments;

# %% [markdown]
# ## 2) Modelo mental: de transacciones a KPIs
#
# Completa el mapa conceptual de la sesión.
#
# | Tabla | ¿Qué representa? | Columnas clave | ¿Para qué me sirve al calcular KPIs? |
# |---|---|---|---|
# | `orders` | | | |
# | `order_items` | | | |
# | `products` | | | |
# | `payments` | | | |
#
# ### Idea central
# Casi todos los KPIs financieros de hoy salen de esta lógica:
#
# 1. Identifico la **tabla de detalle**: ______________________________
# 2. Busco la dimensión de análisis: ________________________________
# 3. Multiplico o agrego las columnas correctas para obtener:
#    - `revenue` = __________________________________________
#    - `cost` = _____________________________________________
# 4. Luego derivo:
#    - `gross_profit` = _____________________________________
#    - `margin_pct` = _______________________________________
#    - `ROI` = ______________________________________________
#
# ### Nota para mí
# ¿Cuál es la diferencia entre “ventas registradas” y “dinero efectivamente pagado”?
# ____________________________________________________________
# ____________________________________________________________

# %% [markdown]
# # 3) Calculating Key Financial Metrics
#
# ## 3.1 Revenue y Cost
#
# ### Antes de escribir SQL
# Completa la lógica:
#
# | KPI | Fórmula conceptual | Tablas involucradas | Columna(s) clave |
# |---|---|---|---|
# | Revenue | | | |
# | Cost | | | |
#
# ### Recuerda
# - `revenue` suele venir de `quantity * price`
# - `cost` suele venir de `quantity * cost`
# - Si una columna puede venir nula, conviene pensar en `COALESCE(...)`
#
# ### Resultado esperado
# Después de ejecutar la consulta por categoría, anota:
#
# | Categoría con mayor revenue | Valor | Categoría con mayor cost | Valor |
# |---|---:|---|---:|
# | | | | |
#
# ### Interpretación
# ¿Qué podría explicar que una categoría tenga alto revenue pero también alto cost?
# ____________________________________________________________
# ____________________________________________________________

# %%
-- Ejercicio 3.1
-- Escribe una consulta que muestre revenue y cost por categoría.
-- Sugerencia:
-- 1) parte desde order_items
-- 2) une products
-- 3) agrega por p.category
-- 4) usa ROUND(..., 2)

SELECT
    -- completa aquí
;

# %% [markdown]
# ## 3.2 Gross Profit y Margin
#
# ### Fórmulas
# Completa con tus palabras:
#
# - **Gross Profit** mide: __________________________________________
# - Fórmula: `______________________________________________`
#
# - **Margin %** mide: _____________________________________________
# - Fórmula: `______________________________________________`
#
# ### Antes de correr el query
# Responde:
#
# 1. ¿Por qué `margin_pct` no es lo mismo que `gross_profit`?
#    ________________________________________________________
#
# 2. ¿Qué problema evita `NULLIF(revenue, 0)`?
#    ________________________________________________________
#
# ### Registro del resultado
# | Categoría | Revenue | Cost | Gross Profit | Margin % | ¿Qué concluyo? |
# |---|---:|---:|---:|---:|---|
# | | | | | | |
# | | | | | | |

# %%
-- Ejercicio 3.2
-- Calcula el top 5 de categorías por gross_profit.
-- Luego agrega margin_pct.

SELECT
    -- completa aquí
;

# %% [markdown]
# ## 3.3 ROI por campaña
#
# En este dataset no siempre existe una tabla real de campañas, así que hoy usamos una **tabla temporal** para practicar el concepto.
#
# ### Completa la idea
# - Una tabla temporal sirve para: ___________________________________
# - En este ejemplo, `spend_usd` representa: __________________________
# - El ROI responde a la pregunta: ___________________________________
#
# ### Fórmula del ROI
# `ROI = ________________________________________________`
#
# ### Ojo metodológico
# Si el gasto se repite por fila debido a un join mal hecho, el ROI puede quedar:
# - ☐ inflado
# - ☐ subestimado
# - ☐ correcto
#
# Explica por qué:
# ____________________________________________________________

# %%
-- Crea aquí la tabla temporal de campaign_spend si el docente no la deja fija
-- y luego construye el query de ROI por campaign.

-- Tu código:

# %% [markdown]
# ## 3.4 Validación de resultados (sanity checks)
#
# Antes de publicar un KPI, debo revisar:
#
# - ☐ ¿El join duplicó filas?
# - ☐ ¿Hay nulos en columnas críticas?
# - ☐ ¿Existe riesgo de división por cero?
# - ☐ ¿El número parece razonable comparado con un conteo simple?
#
# ### Registro de validaciones
# | Validación | ¿Qué consulta usaría? | ¿Qué espero ver? | ¿Qué vi realmente? | Interpretación |
# |---|---|---|---|---|
# | Órdenes sin items | | | | |
# | Items sin producto | | | | |
# | Revenue demasiado alto por duplicidad | | | | |
# | División por cero en margin o ROI | | | | |
#
# ### Mi regla personal
# Antes de confiar en un KPI, siempre voy a:
# ____________________________________________________________
# ____________________________________________________________

# %%
-- Escribe aquí uno o dos sanity checks.
-- Ejemplo: órdenes sin items, items sin producto, duplicados, etc.

-- Tu código:

# %% [markdown]
# # 4) Structuring, Delivering and Communicating Financial Reports
#
# ## 4.1 Cómo debería verse un reporte útil
#
# Un reporte financiero no solo muestra una métrica; debe organizarla para que otra persona entienda qué pasó.
#
# ### Diseña tu reporte ideal
# Completa qué columnas tendría un reporte por categoría:
#
# | Columna | ¿Para qué sirve? |
# |---|---|
# | `category` | |
# | `revenue` | |
# | `cost` | |
# | `gross_profit` | |
# | `margin_pct` | |
# | `n_orders` | |
#
# ### Preguntas de negocio
# - ¿Qué indicador mostrarías primero a un CFO? ______________________
# - ¿Qué indicador mostrarías primero a Marketing? ___________________
# - ¿Cuál usarías para priorizar acciones? ___________________________

# %%
-- Ejercicio 4.1
-- Construye un reporte por categoría que incluya:
-- revenue, cost, gross_profit, margin_pct y n_orders

SELECT
    -- completa aquí
;

# %% [markdown]
# ## 4.2 Documentar SQL con comentarios
#
# ### ¿Por qué comentar una consulta?
# Escribe 2 razones:
#
# 1. ____________________________________________________________
# 2. ____________________________________________________________
#
# ### Plantilla de documentación
# Completa este mini-header antes de tus consultas más importantes:
#
# ```sql
# -- Nombre del reporte:
# -- Objetivo:
# -- Supuesto principal:
# -- Tablas usadas:
# -- Regla de filtrado:
# ```
#
# ### Autoevaluación de legibilidad
# Marca lo que aplicaste hoy:
#
# - ☐ Usé alias claros
# - ☐ Puse cada métrica en una línea distinta
# - ☐ Nombré bien las columnas con `AS`
# - ☐ Dejé comentarios explicando la lógica
# - ☐ Mi consulta final se puede leer sin que yo la explique

# %% [markdown]
# ## 4.3–4.5 Recomendaciones para stakeholders
#
# Convierte tus números en una mini-narrativa.
#
# ### Plantilla
# - **Hallazgo:** _______________________________________________
# - **Evidencia:** ______________________________________________
# - **Implicación:** ____________________________________________
# - **Acción recomendada:** _____________________________________
#
# ### Redacción para dos audiencias
# | Stakeholder | ¿Qué le diría en 2–3 líneas? |
# |---|---|
# | CFO | |
# | Marketing | |
#
# ### Reflexión
# ¿Por qué una misma tabla puede generar recomendaciones distintas según el stakeholder?
# ____________________________________________________________
# ____________________________________________________________

# %% [markdown]
# ## 4.6 AI 🤖 Uso opcional de LLMs para resumir hallazgos
#
# ### ¿Cuándo sí ayuda?
# Marca las opciones que te parecen válidas:
#
# - ☐ cuando ya tengo una tabla limpia y validada
# - ☐ cuando no entiendo mis propios números
# - ☐ cuando quiero transformar KPIs en bullets ejecutivos
# - ☐ cuando necesito un primer borrador de recomendaciones
#
# ### Prompt base
# Completa el prompt con tus resultados reales:
#
# > Resume estos KPIs financieros para un CFO y para Marketing.
# > Revenue total: __________
# > Categoría top por revenue: __________
# > Categoría top por gross_profit: __________
# > Categoría con menor margin_pct: __________
# > Recomendación inicial: __________

# %% [markdown]
# # 5) Analyzing Trends
#
# ## 5.1 Tracking KPIs Over Time
#
# ### Antes del query
# Responde:
#
# - La columna de fecha que usaré es: __________________________
# - El nivel temporal que quiero analizar es: ☐ día ☐ semana ☐ mes
# - El KPI que quiero seguir en el tiempo es: ___________________
#
# ### Interpretación esperada
# Si el revenue sube pero el margin_pct baja, eso podría significar:
# ____________________________________________________________
# ____________________________________________________________
#
# ### Registro de resultados
# | Mes | Revenue | Cost | Margin % | ¿Qué pasó en ese periodo? |
# |---|---:|---:|---:|---|
# | | | | | |
# | | | | | |
# | | | | | |

# %%
-- Ejercicio 5.1
-- Calcula margin_pct por mes.
-- Luego identifica el mes con peor margen y explora por categoría.

SELECT
    -- completa aquí
;

# %% [markdown]
# ## 5.2 Traducir preguntas de negocio a queries
#
# Completa la tabla antes de escribir SQL.
#
# | Pregunta | Tablas necesarias | Métrica | Nivel de agregación | Filtro clave |
# |---|---|---|---|---|
# | ¿Qué productos tienen revenue alto pero margen bajo? | | | | |
# | ¿Qué categorías crecieron más en revenue? | | | | |
# | ¿Qué campaña tiene ROI alto pero poco volumen? | | | | |
#
# ### Ejercicio guiado
# Escribe la lógica para encontrar productos con:
# - `revenue` alto
# - `margin_pct` bajo
#
# **Paso 1.** Tabla base: __________________________
# **Paso 2.** Join necesario: _______________________
# **Paso 3.** Métricas a calcular: ___________________
# **Paso 4.** Filtro final: _________________________

# %%
-- Ejercicio 5.2
-- Encuentra el top 10 de productos con revenue alto y margin_pct bajo.

SELECT
    -- completa aquí
;

# %% [markdown]
# ## Evaluación rápida y cierre
#
# ### Auto-chequeo
# Marca lo que sí lograste hoy:
#
# - ☐ Entendí cómo construir `revenue` y `cost`
# - ☐ Pude derivar `gross_profit` y `margin_pct`
# - ☐ Entendí la lógica del `ROI`
# - ☐ Ejecuté al menos un sanity check
# - ☐ Organicé una tabla lista para reporte
# - ☐ Pude interpretar una tendencia temporal
# - ☐ Transformé un resultado en una recomendación
#
# ### Rúbrica sugerida
#
# | Criterio | Puntaje máximo | Mi puntaje | Observación |
# |---|---:|---:|---|
# | Comprensión de KPIs financieros | 2 | | |
# | Construcción correcta de queries | 2 | | |
# | Validación de resultados | 2 | | |
# | Claridad del reporte | 2 | | |
# | Interpretación y recomendación | 2 | | |
#
# **Total:** ______ / 10

# %% [markdown]
# ## Reflexión final
#
# | Pregunta | Tu respuesta |
# |---|---|
# | ¿Qué KPI me resultó más fácil construir? | |
# | ¿Cuál me costó más interpretar? | |
# | ¿Qué error cometí hoy y qué aprendí al corregirlo? | |
# | ¿Qué consulta quiero volver a practicar? | |
#
# ### Resumen en 3 líneas
# 1. Hoy aprendí que un KPI financiero en SQL depende de ______________________
# 2. La validación es importante porque ______________________________________
# 3. Mi siguiente paso será _________________________________________________
#
# ## Siguientes pasos
#
# - Repasar las fórmulas de `revenue`, `cost`, `gross_profit`, `margin_pct` y `ROI`.
# - Repetir al menos 2 queries sin mirar las notas.
# - Intentar crear un reporte final por categoría y una recomendación por stakeholder.
#
# **Mi plan personal para repasar:**
# ____________________________________________________________
# ____________________________________________________________
#
#
# ### ¿Necesitas ayuda?
# Recuerda los canales de ayuda que tenemos disponibles:
# - `DATA-CO-LEARNING`: Revisa los horarios de atencion en la guia dele studiante. Recuerda que tenemos horarios de apoyo todos los días para tus dudas puntuales!
# - `DA_CONSULTA`: Uuedes publicar tus preguntas sobre el contenido de la plataforma o el proyecto 24/7. Recuerda que en tu pregunta debes de agregar el tag @Dataconsulta.
# - `SPRINT FOCUS`: Para los Sprints 1 al 5 tenemos sesiones extra donde abordamos temáticas de cada sprint a rpofundidad. Revisa la guia del estudiante para conocer los horarios!
# - `SESIONES 1:1`: Recuerda que puedes agendar sesiones 1:1 con un tutor. Agendalas con antelación y resuelve todas tus dudas, desde temás del proyecto, curso, carrera hasta problemas técnicos.
# - `CANAL DE DISCORD DE COMMUNITY`: Recuerda que tu cohorte tiene un canal especial donde puedes compartir cualquier item interesante que quieras mostrar a tus compañeros de curso.
