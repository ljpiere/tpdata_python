# %% [markdown]
# # Sprint 1 - Webinar 4: Limpieza básica en Google Sheets
#
# **Duración:** 100 minutos
# **Modo:** hands-on (trabajo guiado + mini retos)
#
# **Dataset:** `sp1_w1_taylor_swift_da_intro.xlsx`
#
# ---
#
# ### Restricciones de la sesión: ¿por qué cada regla?
#
# Completa la columna "motivo" mientras el/la docente explica:
#
# | Regla | ¿Permitida? | Motivo |
# |---|---|---|
# | Buscar y Reemplazar | ✅ | |
# | `SUBSTITUTE` / `SUSTITUIR` | ❌ | |
# | Fórmulas concatenadas (`TRIM(LOWER(...))`) | ❌ | |
# | `LOWER`, `UPPER`, `TRIM`, `NOMBREPROPIO` | ✅ | |
# | `SUM`, `AVERAGE`, `COUNT`, `UNIQUE`, `SUMIF` | ✅ | |
#
# > 💬 **Pregunta de entrada:** ¿Qué columnas del dataset crees que van a necesitar más trabajo hoy?
#
# _Tu respuesta:_ _______________________________________________

# %% [markdown]
# ## Introducción
#
# Hoy vas a **modificar el dataset** (no solo identificar). La idea es ir **columna por columna** y dejar evidencia:
#
# Completa las tres columnas de evidencia que debés dejar en cada cambio:
#
# 1. _______________ (antes vs. después en celdas ejemplo)
# 2. _______________ rápida con conteos y listas únicas
# 3. _______________ en `change_log`
#
# > 🎯 **Mentalidad DA:** "si mañana me preguntan qué cambiaste, debo poder responder en 30 segundos con un _______________".

# %% [markdown]
# ## Objetivos de aprendizaje
#
# Marca cada objetivo al completarlo durante la sesión:
#
# | # | Objetivo | ¿Listo? |
# |---|---|---|
# | 1 | Preparar el archivo para limpieza (copias, filtros, vistas) | ☐ |
# | 2 | Renombrar columnas de forma consistente | ☐ |
# | 3 | Corregir problemas típicos con Buscar y Reemplazar | ☐ |
# | 4 | Normalizar texto sin fórmulas complejas | ☐ |
# | 5 | Verificar que los cambios funcionaron con funciones básicas | ☐ |
# | 6 | Documentar cambios de manera reproducible | ☐ |

# %% [markdown]
# ## Agenda (100 min)
#
# - **0) Setup y reglas de trabajo (10 min)**
# - **1) Renombrar columnas (10 min)**
# - **2) Buscar y Reemplazar para números y valores categóricos (25 min)**
# - **3) Normalización de texto con funciones simples (20 min)**
# - **4) Verificación con métricas rápidas (20 min)**
# - **5) Documentación en change_log + cierre (15 min)**

# %% [markdown]
# ## Material de la sesión
#
# **Hojas que vamos a crear:**
#
# | Hoja original | Copia de trabajo | ¿Creada? |
# |---|---|---|
# | `raw_songs` | `songs_clean_v1` | ☐ |
# | `raw_albums` | `albums_clean_v1` | ☐ |
#
# **Entrega mínima al final de la sesión:**
#
# | Entregable | ¿Completado? |
# |---|---|
# | `songs_clean_v1` con columnas renombradas + 5 columnas corregidas | ☐ |
# | `albums_clean_v1` revisada (nombres + verificación simple) | ☐ |
# | `change_log` con **10 entradas** | ☐ |

# %% [markdown]
# ## 0) Setup y reglas de trabajo (10 min)
#
# Sigue los pasos y anota lo que observas en cada uno:
#
# 1. ☐ Abre el `.xlsx` en Google Sheets.
# 2. ☐ Duplica `raw_songs` → renómbrala `songs_clean_v1`
# 3. ☐ Duplica `raw_albums` → renómbrala `albums_clean_v1`
# 4. ☐ Congela fila 1 y activa filtro en ambas hojas.
# 5. ☐ En `summary_template`, en A1 escribe **"Control rápido"** y deja espacio en A3:B3 para métricas.
#
# **Observaciones del setup:**
# - Total de filas en `songs_clean_v1` (sin encabezado): _______
# - Total de columnas en `songs_clean_v1`: _______
# - ¿Hay algo que llame la atención al duplicar? → _______________________________________________
#
# ✅ **Checkpoint:** puedes filtrar, ordenar y `summary_template` está listo.

# %% [markdown]
# ## 1) Renombrar columnas (10 min)
#
# ### 1.1 Convención: snake_case en inglés
#
# Completa la columna "Tu propuesta" con el nombre que le darías **antes** de ver la solución, luego confirma con la tabla oficial:
#
# | Original | Tu propuesta | Nombre oficial |
# |---|---|---|
# | Song | | `song` |
# | Album | | `album` |
# | Release Date | | `release_date` |
# | Duration | | `duration` |
# | Spotify Streams (M) | | `spotify_streams_m` |
# | YouTube Views (M) | | `youtube_views_m` |
# | Explicit | | `explicit` |
# | Writers | | `writers` |
# | ISRC | | `isrc` |
# | Tour Era | | `tour_era` |
# | Date Added | | `date_added` |
#
# **Tarea:** aplica los cambios en `songs_clean_v1` y `albums_clean_v1`.
#
# - ☐ Encabezados renombrados en `songs_clean_v1`
# - ☐ Encabezados renombrados en `albums_clean_v1`
#
# > 💬 ¿Por qué la convención es snake_case en inglés y no otra cosa?
#
# _Tu respuesta:_ _______________________________________________
#
# ✅ **Validación:** el filtro muestra nombres cortos y consistentes. ☐

# %% [markdown]
# ## 2) Buscar y Reemplazar (25 min)
#
# > Herramienta: **Editar → Buscar y reemplazar**
#
# ---
#
# ### 2.1 Números con separador de miles (8 min)
#
# **Antes de empezar — inspección visual:**
# - Abre `spotify_streams_m`. ¿Cómo están alineados los valores? → ☐ Izquierda (texto) / ☐ Derecha (número)
# - Ejemplo de un valor con problema que encontraste: _______________
#
# **Pasos:**
# 1. ☐ Selecciona la columna `spotify_streams_m` completa.
# 2. ☐ Buscar: `,` → Reemplazar por: *(vacío)* → Reemplazar todo.
# 3. ☐ Repite para `youtube_views_m`.
#
# **Resultado del reemplazo:**
# - Cantidad de reemplazos en `spotify_streams_m`: _______
# - Cantidad de reemplazos en `youtube_views_m`: _______
#
# **Validación en `summary_template`:**
#
# | Fórmula | Resultado antes | Resultado después | ¿Funciona? |
# |---|---|---|---|
# | `=COUNT(songs_clean_v1!E2:E)` | | | ☐ |
# | `=AVERAGE(songs_clean_v1!E2:E)` | error / valor: ___ | | ☐ |
#
# ---
#
# ### 2.2 Estandarizar booleanos en `explicit` (8 min)
#
# **Antes de empezar — inspección:**
#
# Usa el filtro en `explicit` y anota todos los valores únicos que encontrás:
# - Valores encontrados: _______________________________________________
#
# **Objetivo:** dejar solo `TRUE` o `FALSE`.
#
# **Pasos** (completa la tabla mientras lo hacés):
#
# | Buscar | Reemplazar por | ¿Aplicado? |
# |---|---|---|
# | `N` | `FALSE` | ☐ |
# | `0` | `FALSE` | ☐ |
# | `1` | `TRUE` | ☐ |
# | `Y` | `TRUE` | ☐ |
# | ___ | ___ | ☐ |
#
# **Validación en `summary_template`:**
# - Fórmula: `=UNIQUE(songs_clean_v1!G2:G)`
# - Valores únicos que quedan: _______________________________________________
# - ¿Solo TRUE y FALSE? → ☐ Sí / ☐ No (¿qué sobró? _______________)
#
# ---
#
# ### 2.3 Limpiar caracteres basura en fechas (9 min)
#
# **Inspección de `date_added` y `release_date`:**
#
# Anotá los problemas que encontrás en cada columna:
#
# | Columna | Problema observado | Ejemplo concreto |
# |---|---|---|
# | `date_added` | | |
# | `release_date` | | |
#
# **Pasos de limpieza:**
#
# | Paso | Buscar | Reemplazar por | ¿Aplicado? | Reemplazos realizados |
# |---|---|---|---|---|
# | Quitar comas finales | `,` | *(vacío)* | ☐ | |
# | Quitar dobles espacios | `  ` (2 espacios) | ` ` (1 espacio) | ☐ | |
# | Unificar separador (si aplica) | `-` | `/` | ☐ | |
#
# **Validación:**
# - Ordena por `release_date` → ¿quedan valores con coma o espacios raros? → ☐ Sí / ☐ No
# - ¿Las fechas se reconocen como tal (alineadas a la derecha)? → ☐ Sí / ☐ No / ☐ Parcialmente
#
# > ⚠️ Recuerda: hoy solo dejamos lista la columna para formato. La conversión perfecta viene después.

# %% [markdown]
# ## 3) Normalización de texto con funciones simples (20 min)
#
# > Regla: **una función por columna auxiliar**. Si necesitás otra transformación, creás otra columna auxiliar.
#
# ---
#
# ### 3.1 TRIM para `writers` (6 min)
#
# **Inspección previa:**
# - ¿Qué tipo de espacios encontrás en `writers`? → _______________________________________________
# - Ejemplo de una celda con problema: _______________________________________________
#
# **Pasos:**
# 1. ☐ Inserta una columna a la derecha de `writers` → nómbrala `writers_trim`.
# 2. ☐ En fila 2 de `writers_trim`: `=TRIM(H2)` *(ajusta la letra de columna según tu archivo)*
# 3. ☐ Arrastra la fórmula hacia abajo.
#
# **Comparación antes/después (anota 2 ejemplos reales):**
#
# | Celda | Valor en `writers` (original) | Valor en `writers_trim` (limpio) |
# |---|---|---|
# | Fila ___ | | |
# | Fila ___ | | |
#
# ✅ ☐ Validación completada
#
# ---
#
# ### 3.2 Normalizar `tour_era` con LOWER (7 min)
#
# **Inspección previa:**
# - Usa `=UNIQUE(songs_clean_v1!J2:J)` *(ajusta columna)*
# - ¿Cuántas variantes distintas hay? → _______ (incluyendo las que son el mismo valor con distinto case)
# - Ejemplo de variantes del mismo valor: _______________ / _______________ / _______________
#
# **Pasos:**
# 1. ☐ Inserta columna a la derecha → nómbrala `tour_era_lower`.
# 2. ☐ Fórmula: `=LOWER(J2)` *(ajusta la columna)*
# 3. ☐ Arrastra hacia abajo.
#
# **Validación en `summary_template`:**
# - `=UNIQUE(` *rango de `tour_era_lower`* `)`
# - Categorías únicas antes: _______ / Categorías únicas después: _______
# - ¿Bajó el número? → ☐ Sí / ☐ No
#
# ---
#
# ### 3.3 Normalizar `album` con NOMBREPROPIO (7 min)
#
# **Inspección previa:**
# - Ejemplo del mismo álbum en distintos formatos: _______________ / _______________
#
# **Pasos:**
# 1. ☐ Inserta columna a la derecha de `album` → nómbrala `album_proper`.
# 2. ☐ Fórmula: `=NOMBREPROPIO(B2)` *(o `=PROPER(B2)` según idioma de tu Sheets)*
# 3. ☐ Arrastra hacia abajo.
#
# **Validación:**
# - UNIQUE de `album` → _______ variantes / UNIQUE de `album_proper` → _______ variantes
# - ¿Hubo reducción? → ☐ Sí / ☐ No
# - ¿NOMBREPROPIO funcionó bien con nombres como `Taylor's Version`? → _______________________________________________
#
# > 💬 ¿Cuándo podría fallar `NOMBREPROPIO`? ¿Podés pensar en un caso del dataset?
#
# _Tu respuesta:_ _______________________________________________

# %% [markdown]
# ## 4) Verificación con métricas rápidas (20 min)
#
# > La limpieza debe poder demostrarse con 3–4 números. Completá cada resultado.
#
# ---
#
# ### 4.1 COUNT — ¿Cuántas filas numéricas tengo? (5 min)
#
# | Columna | Fórmula | Resultado | Total de filas del dataset | ¿Coincide? |
# |---|---|---|---|---|
# | `spotify_streams_m` | `=COUNT(songs_clean_v1!E2:E)` | | | ☐ Sí / ☐ No |
# | `youtube_views_m` | `=COUNT(songs_clean_v1!F2:F)` | | | ☐ Sí / ☐ No |
#
# **Interpretación:** si COUNT es menor que el total de filas → _______________________________________________
#
# ---
#
# ### 4.2 AVERAGE — ¿El promedio tiene sentido? (5 min)
#
# | Fórmula | Resultado | ¿Da error? | ¿El valor es razonable? |
# |---|---|---|---|
# | `=AVERAGE(songs_clean_v1!E2:E)` | | ☐ Sí / ☐ No | ☐ Sí / ☐ No — ¿por qué? _____ |
#
# ---
#
# ### 4.3 UNIQUE — ¿Cuántas categorías reales quedan? (5 min)
#
# | Columna | Fórmula | Valores únicos que aparecen |
# |---|---|---|
# | `explicit` | `=UNIQUE(songs_clean_v1!G2:G)` | |
# | `tour_era_lower` *(ajusta rango)* | `=UNIQUE(...)` | |
#
# **¿Quedaron variantes no deseadas?** → _______________________________________________
#
# ---
#
# ### 4.4 SUMIF — Una pregunta de negocio real (5 min)
#
# **Pregunta:** ¿Cuántos streams totales (M) tiene cada álbum?
#
# Completa la fórmula para el álbum que elijas y anota el resultado:
#
# | Álbum consultado | Fórmula usada | Resultado (M) |
# |---|---|---|
# | | `=SUMIF(songs_clean_v1!B:B, "___", songs_clean_v1!E:E)` | |
# | | `=SUMIF(songs_clean_v1!B:B, "___", songs_clean_v1!E:E)` | |
# | | `=SUMIF(songs_clean_v1!B:B, "___", songs_clean_v1!E:E)` | |
#
# **¿SUMIF funcionó?** → ☐ Sí / ☐ No
#
# Si funcionó, significa que...
# 1. La columna `album` es _______________ (o estás usando `album_proper`)
# 2. `spotify_streams_m` ya es _______________
#
# > 💬 **Mini reto:** ¿Cuál es el álbum con más streams según tu SUMIF? → _______________________________________________

# %% [markdown]
# ## 5) Documentación en change_log + cierre (15 min)
#
# ### 5.1 Completa tus 10 entradas en el change_log (10 min)
#
# Usa la tabla de abajo para borradorear antes de pasarlo al archivo:
#
# | # | sheet | column | issue | action | before_example | after_example |
# |---|---|---|---|---|---|---|
# | 1 | songs_clean_v1 | `spotify_streams_m` | | | | |
# | 2 | songs_clean_v1 | `youtube_views_m` | | | | |
# | 3 | songs_clean_v1 | `explicit` | | | | |
# | 4 | songs_clean_v1 | `date_added` | | | | |
# | 5 | songs_clean_v1 | `writers` | | | | |
# | 6 | songs_clean_v1 | `tour_era` | | | | |
# | 7 | songs_clean_v1 | `album` | | | | |
# | 8 | songs_clean_v1 | *(encabezados)* | | | | |
# | 9 | | | | | | |
# | 10 | | | | | | |
#
# - ☐ Las 10 entradas están pasadas al `change_log` del archivo
#
# ---
#
# ### 5.2 Métricas finales en `summary_template` (5 min)
#
# Deja estas 3 métricas visibles en `summary_template`:
#
# | Métrica | Fórmula | Valor final |
# |---|---|---|
# | Count streams | `=COUNT(songs_clean_v1!E2:E)` | |
# | Average streams | `=AVERAGE(songs_clean_v1!E2:E)` | |
# | Eras únicas | `=UNIQUE(` *rango tour_era_lower* `)` | |
#
# - ☐ Las 3 métricas están en `summary_template`

# %% [markdown]
# ## Takeaways y checklist de cierre
#
# ### Completa los takeaways con tus palabras:
#
# 1. **Buscar y Reemplazar** = corrección _______________ sin _______________.
# 2. `TRIM`, `LOWER/UPPER`, `NOMBREPROPIO` = estándar mínimo de _______________.
# 3. `COUNT`, `AVERAGE`, `UNIQUE`, `SUMIF` = _______________ rápida (evidencia de calidad).
# 4. Documentar cambios te permite _______________ el proceso y _______________ tu trabajo.
#
# ---
#
# ### ✅ Checklist de salida
#
# | Ítem | ¿Listo? |
# |---|---|
# | Columnas renombradas en snake_case | ☐ |
# | `spotify_streams_m` y `youtube_views_m` en formato numérico | ☐ |
# | `explicit` solo con TRUE/FALSE | ☐ |
# | `tour_era` normalizado (`tour_era_lower`) | ☐ |
# | `writers` con TRIM (`writers_trim`) | ☐ |
# | `change_log` con 10 entradas | ☐ |
# | 3 métricas finales en `summary_template` | ☐ |
#
# ### ¿Necesitas ayuda?
# Recuerda los canales de ayuda que tenemos disponibles:
# - `DATA-CO-LEARNING`: Revisa los horarios de atencion en la guia dele studiante. Recuerda que tenemos horarios de apoyo todos los días para tus dudas puntuales!
# - `DA_CONSULTA`: Uuedes publicar tus preguntas sobre el contenido de la plataforma o el proyecto 24/7. Recuerda que en tu pregunta debes de agregar el tag @Dataconsulta.
# - `SPRINT FOCUS`: Para los Sprints 1 al 5 tenemos sesiones extra donde abordamos temáticas de cada sprint a rpofundidad. Revisa la guia del estudiante para conocer los horarios!
# - `SESIONES 1:1`: Recuerda que puedes agendar sesiones 1:1 con un tutor. Agendalas con antelación y resuelve todas tus dudas, desde temás del proyecto, curso, carrera hasta problemas técnicos.
# - `CANAL DE DISCORD DE COMMUNITY`: Recuerda que tu cohorte tiene un canal especial donde puedes compartir cualquier item interesante que quieras mostrar a tus compañeros de curso.
#
# ---
#
# > 💬 **Pregunta de salida:** Si tuvieras que pasarle este archivo a un/a compañero/a para que continúe el análisis, ¿qué le dirías que aún falta limpiar?
#
# _Tu respuesta:_ _______________________________________________
