# %% [markdown]
# # Sprint 5 · Webinar 18 · Introducción a Python y Pandas (Sesión práctica) — Student Version
#
# **Programa:** Introducción a la Analítica de Datos
# **Duración:** 100 minutos
# **Formato:** Sesión práctica guiada + trabajo individual / en grupos
#
# En esta versión vas a usar el notebook como **cuaderno de trabajo**.
# La idea no es copiar una solución completa, sino:
#
# - tomar apuntes,
# - completar código paso a paso,
# - registrar resultados,
# - escribir interpretaciones cortas,
# - dejar evidencia de tus decisiones.
#
# **Tema central de hoy:** crear un dataset pequeño, cargarlo con `pandas`, explorarlo y aplicar filtros, selección de columnas y slicing.

# %% [markdown]
# ## Fecha
#
# Completa la información de la sesión:
#
# - **Fecha:** `____ / ____ / 2025`
# - **Instructor/a:** `________________________`
# - **Estudiante:** `________________________`
# - **Grupo / Cohorte:** `________________________`

# %% [markdown]
# ## Objetivos de la sesión práctica
#
# Marca la primera columna al final de la clase y completa la última con evidencia.
#
# | Objetivo | ¿Lo logré? | Evidencia / ejemplo mío |
# |---|---|---|
# | Crear un notebook ordenado con secciones y celdas documentadas | ☐ | |
# | Crear o completar un dataset pequeño en Python | ☐ | |
# | Guardar un dataset como `.csv` y volverlo a cargar con `pandas` | ☐ | |
# | Explorar un `DataFrame` con `.head()`, `.shape`, `.info()` y `.describe()` | ☐ | |
# | Renombrar columnas con una lógica clara y consistente | ☐ | |
# | Aplicar filtros, selección de columnas y slicing | ☐ | |
# | Interpretar resultados básicos de negocio a partir de una tabla | ☐ | |

# %% [markdown]
# ## Agenda sugerida (100 minutos)
#
# | Tiempo | Bloque | Producto esperado |
# |---|---|---|
# | 0–10 min | Bienvenida y contexto | Entender el objetivo del práctico |
# | 10–25 min | Ejercicio 0 | Notebook organizado + mini repaso de Python |
# | 25–45 min | Ejercicio 1 | Dataset creado / guardado / cargado |
# | 45–65 min | Ejercicio 2 | Esquema revisado y columnas mejoradas |
# | 65–90 min | Ejercicio 3 | Filtros, selección y slicing resueltos |
# | 90–100 min | Cierre | Take aways, dudas y siguientes pasos |
#
# > Si terminas antes, usa los retos opcionales para profundizar.

# %% [markdown]
# ## Ejercicio 0 · Calentamiento en breakout rooms (10–15 min)
#
# **Objetivo:** retomar la lógica de Jupyter Notebook y Python básico antes de entrar a `pandas`.
#
# ### Consigna
#
# En parejas o grupos pequeños:
#
# 1. Crea o revisa la estructura del notebook.
# 2. Asegúrate de tener al menos estas secciones en Markdown:
#    - `# Cargar datos`
#    - `# Explorar datos`
#    - `# Filtrar datos`
# 3. En una celda de código:
#    - imprime un mensaje,
#    - define dos variables numéricas,
#    - calcula una operación simple,
#    - deja un comentario explicando qué hiciste.
#
# ### Checklist del ejercicio
#
# - ☐ Identifiqué una celda Markdown.
# - ☐ Identifiqué una celda de código.
# - ☐ Ejecuté una celda sin errores.
# - ☐ Modifiqué una variable y observé el cambio en la salida.
#
# ### Registro rápido
#
# | Acción | ¿Qué observé? |
# |---|---|
# | Ejecuté una celda de código | |
# | Cambié una variable | |
# | Agregué un comentario | |
# | Vi un error o warning | |

# %%
# Ejercicio 0 — espacio de práctica

# 1) Escribe un mensaje de bienvenida
mensaje = "Escribe aquí tu mensaje"
print(mensaje)

# 2) Crea dos variables numéricas relacionadas con analítica
# Ejemplo: total_streams, total_usuarios, ventas_enero, etc.
valor_1 = 0
valor_2 = 0

# 3) Calcula una operación simple
resultado = valor_1 + valor_2
print("Resultado:", resultado)

# 4) Deja un comentario en esta celda explicando qué representa cada variable

# 5) Opcional:
# cambia la operación para calcular promedio, diferencia o porcentaje

# %% [markdown]
# ## Ejercicio 1 · Crear y cargar un nuevo dataset con pandas
#
# En esta práctica trabajarás con un dataset pequeño sobre canciones y reproducciones en plataformas de streaming.
#
# ### Variables esperadas
#
# Cada fila debe representar una combinación de canción + país + plataforma.
#
# Columnas sugeridas:
#
# - `song_title`
# - `album`
# - `country`
# - `platform`
# - `streams_millions`
# - `release_year`
#
# ### Tu tarea
#
# 1. Completa el diccionario o la estructura base del dataset.
# 2. Crea un `DataFrame`.
# 3. Guarda el archivo como `streams_practice_dataset.csv`.
# 4. Vuelve a cargarlo desde disco con `pd.read_csv(...)`.
#
# > No necesitas inventar un dataset perfecto. Lo importante es practicar la lógica completa: **crear → guardar → cargar**.

# %%
import pandas as pd

# Configuración opcional para visualizar mejor los resultados
pd.set_option("display.max_columns", 20)
pd.set_option("display.precision", 2)

# Paso 1: completa el dataset
# Puedes conservar esta temática o adaptarla a otra similar.
data = {
    "song_title": [
        "Midnight City Lights",
        "Summer Haze",
        # TODO: agrega más títulos
    ],
    "album": [
        "Neon Dreams",
        "Neon Dreams",
        # TODO: agrega más valores
    ],
    "country": [
        "USA",
        "USA",
        # TODO: agrega más países
    ],
    "platform": [
        "Spotify",
        "Apple Music",
        # TODO: agrega más plataformas
    ],
    "streams_millions": [
        120.5,
        98.2,
        # TODO: agrega más métricas numéricas
    ],
    "release_year": [
        2022,
        2022,
        # TODO: agrega más años
    ]
}

# Paso 2: crea el DataFrame cuando tu diccionario esté completo
# df_source = pd.DataFrame(data)

# Paso 3: guarda el CSV
# df_source.to_csv("streams_practice_dataset.csv", index=False)

# Paso 4: revisa las primeras filas
# df_source.head()

# %% [markdown]
# ### 1.1. Cargar el archivo `.csv` con pandas
#
# Antes de ejecutar, responde brevemente:
#
# | Pregunta | Mi predicción |
# |---|---|
# | ¿Cuántas filas creo que tendrá el dataset? | |
# | ¿Qué columnas serán de texto? | |
# | ¿Qué columnas serán numéricas? | |
# | ¿Qué campo podría usar para filtrar con más facilidad? | |
#
# Ahora carga el archivo en una variable llamada `df` y muestra las primeras filas.

# %%
# Cargar el dataset desde el archivo CSV
# Reemplaza la ruta si guardaste el archivo en otra carpeta.

ruta_archivo = "streams_practice_dataset.csv"

# TODO: carga el archivo en la variable df
# df = pd.read_csv(ruta_archivo)

# TODO: muestra las primeras filas
# df.head()

# %% [markdown]
# ### Preguntas guiadas para el Ejercicio 1
#
# Responde debajo de tus resultados, en una celda Markdown nueva o en tus notas personales.
#
# 1. ¿Cuántas filas y columnas tiene el dataset?
# 2. ¿Qué tipo de dato tiene cada columna?
# 3. ¿Qué te dicen las estadísticas descriptivas de las columnas numéricas?
# 4. ¿Detectas alguna posible inconsistencia o algo que revisarías antes de seguir?
#
# ### Sugerencia de respuesta
#
# | Método | ¿Para qué lo usé? | Hallazgo principal |
# |---|---|---|
# | `df.shape` | | |
# | `df.info()` | | |
# | `df.describe()` | | |

# %%
# Explora el DataFrame con estas ayudas

# 1) Dimensiones
# df.shape

# 2) Información general
# df.info()

# 3) Estadísticas descriptivas
# df.describe()

# 4) Opcional: últimas filas
# df.tail()

# %% [markdown]
# ## Ejercicio 2 · Explorar el esquema y mejorar los nombres de columnas
#
# **Objetivo:** practicar la lectura del esquema del dataset y aplicar buenas prácticas de nombres.
#
# ### Parte A · Leer el esquema
#
# Completa esta tabla mientras revisas el dataset:
#
# | Columna original | ¿Qué representa? | Tipo de dato esperado | ¿La dejaría igual? |
# |---|---|---|---|
# | `song_title` | | | |
# | `album` | | | |
# | `country` | | | |
# | `platform` | | | |
# | `streams_millions` | | | |
# | `release_year` | | | |
#
# ### Parte B · Crear una versión limpia
#
# Crea una copia del DataFrame original y renombra columnas si hace falta.
#
# Criterios sugeridos:
#
# - minúsculas,
# - sin espacios,
# - nombres claros,
# - unidades explícitas cuando corresponda.

# %%
# Parte A: inspeccionar columnas
# TODO: imprime la lista de columnas
# df.columns

# Parte B: crear copia de trabajo
# df_clean = df.copy()

# TODO: renombra columnas si lo consideras necesario
# Ejemplo:
# df_clean = df_clean.rename(columns={
#     "streams_millions": "streams_millions_total"
# })

# TODO: revisa el resultado
# df_clean.columns

# %% [markdown]
# > **Discusión rápida**
# >
# > 1. ¿Qué nombre de columna cambiarías sí o sí?
# > 2. ¿Qué nombre te parece suficientemente claro y no necesita ajuste?
# > 3. Si esto fuera un reporte ejecutivo, ¿qué columnas pondrías primero?
# >
# > **Checklist de calidad**
# >
# > - ☐ Todas las columnas están en minúsculas.
# > - ☐ No hay nombres ambiguos.
# > - ☐ Las métricas numéricas tienen nombres comprensibles.
# > - ☐ La tabla es fácil de leer para otra persona.

# %% [markdown]
# ## Ejercicio 3 · Filtrar, seleccionar y hacer slicing
#
# **Objetivo:** practicar filtros con condiciones, selección de columnas y slicing en `pandas`.
#
# Trabaja sobre `df_clean` o sobre `df` si decidiste no crear una copia separada.
#
# Antes de escribir el código, completa esta mini planificación:
#
# | Pregunta | Mi idea |
# |---|---|
# | ¿Qué columna usaré para filtrar por plataforma? | |
# | ¿Qué columna usaré para filtrar por país? | |
# | ¿Qué columnas dejaría en una tabla resumen? | |
# | ¿Qué diferencia hay entre filtrar y hacer slicing? | |

# %% [markdown]
# ### Parte A · Filtrar por condiciones
#
# Resuelve los siguientes puntos:
#
# 1. Crea un DataFrame con solo las filas donde la plataforma sea `"Spotify"`.
# 2. Crea un DataFrame con solo las filas del país `"Mexico"` o el país que exista en tu dataset.
# 3. Crea un DataFrame que combine **dos condiciones** al mismo tiempo.
# 4. Explica con una frase qué patrón de filtro te pareció más útil.
#
# > Recuerda usar paréntesis cuando combines condiciones con `&` o `|`.

# %%
# Parte A: filtros por condición

# Ejemplo de variable base:
# df_base = df_clean

# 1) Solo Spotify
# df_spotify = df_base[df_base["platform"] == "Spotify"]
# df_spotify

# 2) Solo Mexico
# df_mexico = df_base[df_base["country"] == "Mexico"]
# df_mexico

# 3) Spotify + Mexico
# df_spotify_mexico = df_base[
#     (df_base["platform"] == "Spotify") &
#     (df_base["country"] == "Mexico")
# ]
# df_spotify_mexico

# 4) Reto opcional:
# crea un filtro para canciones lanzadas desde 2021 en adelante

# %% [markdown]
# ### Parte B · Seleccionar columnas clave
#
# Construye una tabla resumen con las columnas que serían más útiles para una persona de negocio.
#
# Sugerencia mínima:
#
# - `song_title`
# - `country`
# - `platform`
# - una métrica numérica
# - una columna temporal (si tiene sentido)
#
# Luego responde:
#
# 1. ¿Por qué escogiste esas columnas?
# 2. ¿Qué información sobra para un resumen ejecutivo?

# %%
# Parte B: selección de columnas clave

# Ejemplo:
# columnas = ["song_title", "country", "platform", "streams_millions_total"]
# df_resumen = df_base[columnas]
# df_resumen.head()

# TODO:
# 1) define tu lista de columnas
# 2) crea df_resumen
# 3) muestra las primeras filas

# %% [markdown]
# ### Parte C · Slicing por posición
#
# Ahora trabaja por posición de filas y columnas.
#
# Tu tarea:
#
# 1. Muestra las primeras 4 filas de `df_resumen`.
# 2. Usa `.iloc` para mostrar un subconjunto de filas y columnas por posición.
# 3. Compara el resultado de un filtro lógico vs un slicing por posición.
#
# ### Registro de aprendizaje
#
# | Acción | Sintaxis que usé | ¿Qué obtuve? |
# |---|---|---|
# | Primeras filas | | |
# | `.iloc` con rango de filas | | |
# | `.iloc` con filas y columnas específicas | | |

# %%
# Parte C: slicing

# 1) Primeras 4 filas
# df_resumen[0:4]

# 2) Filas 2 a 5, columnas 0 y 3 (ajusta si tu resumen tiene otra estructura)
# df_resumen.iloc[2:6, [0, 3]]

# 3) Prueba otro slicing distinto y anota qué cambió

# %% [markdown]
# ### Reflexión sobre el Ejercicio 3 + reto opcional
#
# Responde con tus palabras:
#
# - ¿Qué ventajas tiene filtrar con `pandas` frente a filtrar manualmente en una hoja de cálculo?
# - ¿Qué error podrías cometer al combinar condiciones con `&` o `|`?
# - ¿Qué diferencia práctica observaste entre seleccionar columnas por nombre y por posición?
#
# ### Reto opcional
#
# Si terminas antes, intenta una de estas opciones:
#
# 1. Crear una columna derivada, por ejemplo:
#    - `is_recent_release`
#    - `streams_bucket`
# 2. Ordenar el DataFrame por la métrica numérica de mayor a menor.
# 3. Mostrar solo las 3 filas con mayor volumen de streams.

# %% [markdown]
# ## 6. Take aways de la sesión práctica
#
# Completa al final de la clase:
#
# 1. Hoy reforcé que un notebook sirve para: `_____________________________________`
# 2. El método de `pandas` que más utilicé fue: `_______________________________`
# 3. La diferencia entre filtrar y hacer slicing es: `__________________________`
# 4. Un error que quiero evitar la próxima vez es: `___________________________`
# 5. Una pregunta que sí pude responder con datos fue: `_______________________`
#
# ### Semáforo personal
#
# - 🟢 Lo entendí bien: `________________________________________`
# - 🟡 Necesito practicar más: `__________________________________`
# - 🔴 Todavía me confunde: `_____________________________________`

# %% [markdown]
# ## 7. Cierre y próximos pasos
#
# Antes de cerrar el notebook, deja evidencia de tu trabajo:
#
# - ☐ Ejecuté al menos una vez cada bloque principal.
# - ☐ Escribí notas o respuestas en Markdown.
# - ☐ Guardé mi notebook con cambios.
# - ☐ Puedo explicar qué hace al menos un filtro que escribí.
#
# ### Mini resumen final
#
# Escribe en 3–5 líneas:
#
# - ¿Qué aprendiste hoy?
# - ¿Qué parte te pareció más sencilla?
# - ¿Qué parte te costó más?

# %% [markdown]
# ## 8. Información complementaria y recursos
#
# - Documentación oficial de `pandas` sobre indexado y selección: <https://pandas.pydata.org/docs/user_guide/indexing.html>
# - Guía rápida de `pandas`: busca una *pandas cheat sheet* y guárdala para próximas clases.
# - Recurso interactivo para practicar `pandas`: <https://www.kaggle.com/learn/pandas>
#
# ### Recomendación práctica
#
# Después de clase, intenta repetir este flujo con otro tema:
#
# `crear dataset → guardar CSV → cargar con pandas → explorar → filtrar → resumir`

# %% [markdown]
# ## Cierre
#
# **Kahoot o repaso rápido (5 min)**
#
# Anota aquí las respuestas o ideas que te parecieron más importantes del cierre:
#
# 1. Comando o método más útil de hoy:
# 2. Error más común que debo evitar:
# 3. Diferencia clave entre `.head()`, `.info()` y `.describe()`:
# 4. Situación real donde usaría filtros en `pandas`:
#
# ### ¿Necesitas ayuda?
# - `DATA-CO-LEARNING`: revisa los horarios de apoyo en la guía del estudiante.
# - `DA_CONSULTA`: publica dudas de contenido o del proyecto usando el tag correspondiente.
# - `SPRINT FOCUS`: sesiones extra para profundizar temas clave del sprint.
# - `SESIONES 1:1`: agenda con anticipación si necesitas apoyo individual.

# %% [markdown]
# ## Siguientes Pasos
#
# - **Próxima sesión / conexión con el sprint:** continuar profundizando en transformación y análisis de datos.
# - **Práctica recomendada:** rehacer los ejercicios sin mirar las pistas.
# - **Reto personal:** inventa un dataset pequeño de otro tema (series, libros, entrenamientos, ventas, etc.) y repite el flujo completo.
# - **Nota para mí:** `______________________________________________________________`
