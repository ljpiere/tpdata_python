# %% [markdown]
# # Sprint 09 · Webinar 02 Extra · Student Version
#
# **Mini-proyecto guiado:** extracción de datos desde una **REST API** + **EDA básico** + **correlación Pearson** + publicación en **GitHub**
#
# **Fuente sugerida:** `JSONPlaceholder`
# **Modalidad:** notebook de trabajo para completar durante la sesión.
#
# ---
#
# > **Pregunta de entrada:** ¿Qué diferencias ves entre trabajar con un CSV local y consumir datos desde una API?
# > Escribe 2 ideas iniciales:
# >
# > 1. ________________________________
# > 2. ________________________________

# %% [markdown]
# ---
# ## Objetivos de aprendizaje
#
# Completa la última columna al final de la clase.
#
# | Objetivo | ¿Lo logré? | En mis palabras (cierre) |
# |---|---|---|
# | Explicar qué es una API REST y cómo se consume con HTTP | ☐ Sí / ☐ Parcial / ☐ No | |
# | Extraer datos JSON y convertirlos en DataFrames con `pandas` | ☐ Sí / ☐ Parcial / ☐ No | |
# | Construir un dataset analítico a partir de varias fuentes relacionadas | ☐ Sí / ☐ Parcial / ☐ No | |
# | Realizar una exploración inicial del dataset | ☐ Sí / ☐ Parcial / ☐ No | |
# | Identificar y tratar vacíos y nulos con reglas simples | ☐ Sí / ☐ Parcial / ☐ No | |
# | Interpretar una matriz de correlación Pearson | ☐ Sí / ☐ Parcial / ☐ No | |
# | Exportar resultados y dejar el proyecto listo para GitHub | ☐ Sí / ☐ Parcial / ☐ No | |

# %% [markdown]
# ---
# ## Agenda sugerida (100 min)
#
# | Bloque | Tiempo | Actividad |
# |---|---:|---|
# | Contexto | 10 min | ¿Qué es una API REST? |
# | Ejercicio 1 | 25 min | Consumir una API y crear DataFrames |
# | Ejercicio 2 | 20 min | EDA básico con `pandas` |
# | Ejercicio 3 | 20 min | Vacíos y nulos |
# | Ejercicio 4 | 15 min | Correlación Pearson |
# | Ejercicio 5 | 10 min | Exportación y publicación en GitHub |
#
# **Meta de la sesión:** construir un mini-proyecto analítico de extremo a extremo.

# %% [markdown]
# ---
# ## 0. Conceptos base: API REST
#
# Completa durante la explicación del docente.
#
# | Concepto | Definición en tus palabras |
# |---|---|
# | API | |
# | REST | |
# | Endpoint | |
# | HTTP `GET` | |
# | JSON | |
# | Status code | |
#
# **Preguntas guía**
# 1. ¿Por qué una API suele devolver JSON y no una tabla lista?
#    **Respuesta:** ____________________________________________
#
# 2. ¿Qué ventaja tiene separar los datos por endpoints (`/users`, `/posts`, `/comments`)?
#    **Respuesta:** ____________________________________________

# %% [markdown]
# ---
# ## 0.1 Setup del entorno
#
# Antes de empezar, verifica:
#
# - ☐ Tengo conexión a internet.
# - ☐ Tengo instaladas las librerías necesarias.
# - ☐ Entiendo qué endpoint voy a consultar primero.
# - ☐ Sé dónde guardaré los archivos descargados.
#
# **Checklist de proyecto**
# - Carpeta para datos crudos: `data/raw`
# - Carpeta para datos procesados: `data/processed`
# - Notebook principal del análisis
# - CSV final limpio para exportar

# %%
# Setup básico
# Completa o ajusta lo necesario para dejar el entorno listo.

import json
from pathlib import Path

import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt

# TODO: crear o confirmar la carpeta para datos crudos
# CACHE_DIR = ...
# CACHE_DIR.mkdir(...)

# TODO: opcional -> configura opciones de pandas si las necesitas
# pd.set_option(...)

# %% [markdown]
# ---
# # 1. Ejercicio 1 · Extraer datos desde una REST API
#
# **Meta:** consumir una API pública, revisar la estructura del JSON y convertirlo en tablas útiles.
#
# Trabajaremos con estos endpoints:
#
# - `/users`
# - `/posts`
# - `/comments`
#
# Antes de programar, completa:
#
# | Endpoint | ¿Qué crees que devuelve? | Clave(s) que esperas encontrar |
# |---|---|---|
# | `/users` | | |
# | `/posts` | | |
# | `/comments` | | |

# %% [markdown]
# ### 1.1 Diseñar una función simple para hacer `GET`
#
# La función debería:
#
# - Recibir un `endpoint`
# - Hacer una petición HTTP
# - Validar errores
# - Convertir la respuesta a JSON
# - Guardar una copia local del resultado
# - Retornar los datos
#
# **Piensa antes de escribir**
# 1. ¿Qué pasa si la API responde con error? ______________________
# 2. ¿Por qué conviene guardar una copia local del JSON? ______________________

# %%
BASE_URL = "https://jsonplaceholder.typicode.com"
CACHE_DIR = Path("data/raw")
CACHE_DIR.mkdir(parents=True, exist_ok=True)

def fetch_json(endpoint: str, cache_name: str):
    """Descarga datos JSON desde un endpoint y guarda una copia local."""

    # TODO 1: construir la URL completa
    # url = ...

    # TODO 2: hacer la petición con requests.get(...)
    # response = ...

    # TODO 3: validar que la respuesta sea exitosa
    # response.raise_for_status()

    # TODO 4: convertir la respuesta a JSON
    # data = ...

    # TODO 5: guardar una copia del JSON en CACHE_DIR / cache_name
    # with open(..., "w", encoding="utf-8") as f:
    #     json.dump(..., f, ensure_ascii=False, indent=2)

    # TODO 6: retornar los datos
    # return data

    pass

# %% [markdown]
# ### 1.2 Descargar usuarios y convertir a DataFrame
#
# **Objetivo:** crear una tabla base de usuarios.
#
# Completa antes de ejecutar:
#
# - ¿Qué nivel de análisis tendrá tu dataset final? `________________`
# - ¿Qué columnas del usuario crees que te servirán para análisis? `________________`

# %%
# TODO: descargar /users
# users_json = fetch_json(...)

# TODO: convertir a DataFrame
# users = ...

# TODO: inspeccionar rápidamente la estructura
# users.head()

# %% [markdown]
# **Registro rápido**
#
# | Pregunta | Tu respuesta |
# |---|---|
# | ¿Cuántos usuarios llegaron? | |
# | ¿Qué columnas parecen útiles para negocio? | |
# | ¿Qué columnas parecen más técnicas o menos útiles? | |

# %% [markdown]
# ### 1.3 Descargar posts y agregar por usuario
#
# **Objetivo:** calcular cuántos posts hizo cada usuario.
#
# **Diseño del paso**
# 1. Descargar `posts`
# 2. Convertir a DataFrame
# 3. Agrupar por `userId`
# 4. Calcular una métrica de conteo
#
# **Antes de escribir el código**
# - ¿Qué función de `pandas` usarás para agrupar? `________________`
# - ¿Qué nombre le darás a la nueva métrica? `________________`

# %%
# TODO: descargar /posts
# posts_json = ...

# TODO: convertir a DataFrame
# posts = ...

# TODO: crear tabla agregada por usuario
# posts_per_user = (
#     ...
# )

# posts_per_user.head()

# %% [markdown]
# ### 1.4 Descargar comentarios y relacionarlos con posts
#
# Ahora los comentarios no vienen directamente a nivel usuario.
# Tendrás que pensar cómo llegar desde `comments` hasta `userId`.
#
# **Esquema lógico**
# `comments` → `postId` → `posts.id` → `posts.userId`
#
# Completa:
#
# | Pregunta | Tu respuesta |
# |---|---|
# | ¿Con qué tabla debes unir `comments` primero? | |
# | ¿Cuál será la llave del merge? | |
# | ¿Qué métrica(s) quieres calcular por usuario? | |

# %%
# TODO: descargar /comments
# comments_json = ...

# TODO: convertir a DataFrame
# comments = ...

# TODO: unir comments con posts para obtener userId
# comments_with_user = comments.merge(
#     ...,
#     left_on=...,
#     right_on=...,
#     how="..."
# )

# TODO: crear al menos dos métricas por usuario
# Ejemplo: cantidad de comentarios, longitud promedio del comentario, etc.
# comments_with_user["comment_len"] = ...
# comments_per_user = (
#     ...
# )

# comments_per_user.head()

# %% [markdown]
# ### 1.5 Construir el dataset analítico final
#
# **Meta:** crear una sola tabla a nivel usuario.
#
# Columnas sugeridas:
# - datos identificadores del usuario
# - `posts_count`
# - `comments_count`
# - `avg_comment_len`
# - una métrica simple de engagement
#
# **Diseño previo**
# 1. Seleccionar columnas útiles de `users`
# 2. Renombrar columnas si hace falta
# 3. Unir métricas de `posts` y `comments`
# 4. Tratar faltantes básicos
# 5. Crear una métrica derivada

# %%
# TODO: seleccionar columnas útiles del usuario
# users_small = ...

# TODO: renombrar columnas si hace falta
# users_small = users_small.rename(columns={...})

# TODO: unir users_small con posts_per_user y comments_per_user
# df = ...

# TODO: tratar faltantes en conteos
# df["posts_count"] = ...
# df["comments_count"] = ...

# TODO: crear una métrica derivada simple
# df["engagement_score"] = ...

# df.head()

# %% [markdown]
# **Control de calidad del dataset final**
#
# | Validación | Resultado |
# |---|---|
# | Cada fila representa un usuario | |
# | No hay duplicados de `userId` | |
# | Las métricas numéricas tienen sentido | |
# | Las columnas de texto clave están presentes | |
#
# **Hallazgo principal del Ejercicio 1:**
# ____________________________________________________________

# %% [markdown]
# ---
# # 2. Ejercicio 2 · EDA básico con pandas
#
# **Meta:** entender rápidamente el dataset.
#
# Completa la exploración usando funciones estándar como:
#
# - `shape`
# - `info()`
# - `describe()`
# - revisión visual de filas

# %%
# TODO: revisar tamaño del dataset
# df.shape

# TODO: revisar tipos de dato y nulos
# df.info()

# TODO: obtener estadísticas descriptivas
# df.describe(include="all").T

# %% [markdown]
# ### Registro de exploración
#
# | Pregunta | Tu respuesta |
# |---|---|
# | ¿Cuántas filas y columnas tiene el dataset? | |
# | ¿Qué columnas son numéricas? | |
# | ¿Qué columnas son categóricas/texto? | |
# | ¿Observas valores faltantes o sospechosos? | |
# | ¿Qué métrica parece más importante para negocio? | |

# %% [markdown]
# ---
# # 3. Ejercicio 3 · Vacíos y nulos
#
# **Meta:** practicar el tratamiento de datos faltantes.
#
# En este ejercicio simularemos problemas para luego resolverlos.
#
# **Recuerda**
# - `NaN` = valor nulo real
# - `""` = string vacío
# - No siempre se tratan igual

# %% [markdown]
# ### 3.1 Simular vacíos y nulos
#
# Antes de programar, decide:
#
# | Columna | Problema que vas a simular | ¿Por qué esa columna? |
# |---|---|---|
# | `email` | | |
# | `avg_comment_len` | | |
# | otra columna opcional | | |

# %%
# TODO: crear una copia de trabajo
# df_dirty = ...

# TODO: fijar semilla para reproducibilidad
# np.random.seed(...)

# TODO: simular strings vacíos en una columna de texto
# mask_email = ...
# df_dirty.loc[mask_email, "email"] = ""

# TODO: simular nulos en una columna numérica
# mask_len = ...
# df_dirty.loc[mask_len, "avg_comment_len"] = np.nan

# df_dirty.head()

# %% [markdown]
# ### 3.2 Detectar nulos y vacíos
#
# **Objetivo:** distinguir claramente qué problema tiene cada columna.
#
# Completa:
#
# 1. Conteo de nulos por columna
# 2. Conteo de vacíos en columnas de texto
# 3. Comentario breve sobre qué tipo de faltante apareció

# %%
# TODO: contar nulos por columna
# nulls_per_col = ...

# TODO: contar vacíos en columnas de texto relevantes
# empty_email = ...

# TODO: mostrar resultados
# nulls_per_col
# empty_email

# %% [markdown]
# ### 3.3 Estandarizar vacíos → nulos
#
# ¿Por qué conviene hacerlo?
#
# ____________________________________________________________________

# %%
# TODO: crear copia limpia
# df_clean = ...

# TODO: convertir strings vacíos a NaN
# df_clean["email"] = ...

# TODO: revisar el resultado
# df_clean[["email"]].head()

# %% [markdown]
# ### 3.4 Tratar faltantes con reglas simples
#
# Reglas sugeridas:
# - Variables de texto → `"desconocido"`
# - Variables numéricas → mediana
#
# **Justifica tu elección**
# - ¿Por qué mediana y no media? ______________________________________
# - ¿Cuándo no sería buena idea imputar? ______________________________

# %%
# TODO: imputar columnas de texto
# df_clean["email"] = ...
# df_clean["city"] = ...

# TODO: calcular la mediana de la columna numérica elegida
# median_avg_len = ...

# TODO: imputar faltantes numéricos
# df_clean["avg_comment_len"] = ...

# TODO: validar que el tratamiento funcionó
# df_clean.isna().sum()

# %% [markdown]
# **Resumen del tratamiento de faltantes**
#
# | Columna | Problema detectado | Solución aplicada | ¿Te parece razonable? |
# |---|---|---|---|
# | email | | | |
# | avg_comment_len | | | |
# | city | | | |

# %% [markdown]
# ---
# # 4. Ejercicio 4 · Correlación Pearson
#
# La correlación Pearson mide la relación lineal entre variables numéricas.
#
# **Recuerda**
# - Cerca de `1`: relación positiva fuerte
# - Cerca de `-1`: relación negativa fuerte
# - Cerca de `0`: poca relación lineal
#
# Antes de calcularla, completa:
#
# | Variable | ¿Qué representa? | ¿Esperas correlación con engagement? |
# |---|---|---|
# | `posts_count` | | |
# | `comments_count` | | |
# | `avg_comment_len` | | |
# | `engagement_score` | | |

# %%
# TODO: seleccionar columnas numéricas de interés
# num_cols = [...]

# TODO: calcular matriz de correlación Pearson
# corr = ...

# corr

# %%
# TODO: crear un heatmap simple con matplotlib
# plt.figure(figsize=(6, 4))
# plt.imshow(...)
# plt.xticks(...)
# plt.yticks(...)
# plt.colorbar()
# plt.title("Matriz de correlación")
# plt.tight_layout()
# plt.show()

# %%
# TODO: crear un scatter plot para una relación que quieras inspeccionar
# plt.figure(figsize=(6, 4))
# plt.scatter(...)
# plt.xlabel(...)
# plt.ylabel(...)
# plt.title(...)
# plt.show()

# %% [markdown]
# ### Interpretación
#
# | Relación observada | Valor aproximado | Interpretación |
# |---|---|---|
# | `posts_count` vs `engagement_score` | | |
# | `comments_count` vs `engagement_score` | | |
# | otra relación interesante | | |
#
# **Conclusión breve:**
# ____________________________________________________________

# %% [markdown]
# ---
# # 5. Ejercicio 5 · Exportar resultados y publicar en GitHub
#
# **Meta:** guardar el dataset limpio y dejar el proyecto listo para compartir.
#
# Antes de exportar, verifica:
# - ☐ El dataset final ya fue limpiado
# - ☐ Las columnas tienen nombres entendibles
# - ☐ El archivo final tendrá una ruta clara

# %%
# TODO: crear carpeta de salida
# processed_dir = ...
# processed_dir.mkdir(...)

# TODO: definir ruta de exportación
# output_path = ...

# TODO: exportar el dataset limpio a CSV
# df_clean.to_csv(output_path, index=False)

# TODO: confirmar la ruta final
# output_path

# %% [markdown]
# ## Checklist para publicar el proyecto en GitHub
#
# Marca cuando lo tengas listo:
#
# - ☐ Notebook limpio y ordenado
# - ☐ CSV exportado en `data/processed`
# - ☐ README explicado en lenguaje simple
# - ☐ Commits con mensajes claros
# - ☐ Repositorio público o compartible
#
# **Estructura mínima sugerida**
# ```text
# mi-proyecto-api/
# ├── data/
# │   ├── raw/
# │   └── processed/
# ├── notebooks/
# ├── README.md
# └── requirements.txt
# ```

# %% [markdown]
# ## Comandos base de Git
#
# Completa o practica con el docente:
#
# ```bash
# git init
# git add .
# git commit -m "primer commit"
# git branch -M main
# git remote add origin <URL_DEL_REPO>
# git push -u origin main
# ```
#
# **Anota aquí lo que hace cada comando:**
#
# | Comando | ¿Qué hace? |
# |---|---|
# | `git init` | |
# | `git add .` | |
# | `git commit -m "..."` | |
# | `git branch -M main` | |
# | `git remote add origin ...` | |
# | `git push -u origin main` | |

# %% [markdown]
# ---
# # Cierre · Takeaways
#
# Completa al final de la clase.
#
# 1. Lo más importante que aprendí sobre APIs fue:
#    **__________________________________________________________**
#
# 2. El paso técnico que me resultó más difícil fue:
#    **__________________________________________________________**
#
# 3. La parte del análisis que me dio más contexto de negocio fue:
#    **__________________________________________________________**
#
# 4. Si tuviera que repetir este mini-proyecto con otra API, tendría cuidado con:
#    **__________________________________________________________**
#
# ### ¿Necesitas ayuda?
# - `DATA-CO-LEARNING`: revisa los horarios de apoyo en la guía del estudiante.
# - `DA_CONSULTA`: publica dudas de contenido o del proyecto usando el tag correspondiente.
# - `SPRINT FOCUS`: sesiones extra para profundizar temas clave del sprint.
# - `SESIONES 1:1`: agenda con anticipación si necesitas apoyo individual.

# %% [markdown]
# ## Autoevaluación final
#
# | Criterio | Me siento cómodo | Necesito repasar |
# |---|---|---|
# | Consumir una API con `requests` | ☐ | ☐ |
# | Convertir JSON a DataFrame | ☐ | ☐ |
# | Unir tablas relacionadas | ☐ | ☐ |
# | Detectar nulos y vacíos | ☐ | ☐ |
# | Imputar faltantes con reglas simples | ☐ | ☐ |
# | Interpretar correlaciones | ☐ | ☐ |
# | Exportar y organizar un mini-proyecto | ☐ | ☐ |
#
# **Duda pendiente para la próxima sesión:**
# ____________________________________________________________
