# %% [markdown]
# # Sprint 10 · Webinar 33 · BI práctico · Student Version
# **Proyecto:** Dashboard de desempeño comercial 2024–2025
# **Herramienta:** Power BI Desktop (gratis) + entrega/publicación
#
# > En esta sesión práctica vas a **construir un dashboard en Power BI** y, al mismo tiempo, completar este notebook como **bitácora de trabajo**.
#
# **Usa este notebook para:**
# - tomar apuntes,
# - documentar decisiones,
# - completar plantillas,
# - registrar resultados,
# - redactar una conclusión ejecutiva.
#
# > Cuando veas `TODO`, significa que debes completar esa parte durante la clase.

# %% [markdown]
# ## Fecha
# > Completa aquí la fecha de la sesión.
#
# **Fecha:** __________________________
# **Nombre del estudiante:** __________________________
# **Cohorte / grupo:** __________________________

# %% [markdown]
# ## Objetivo de la sesión práctica (100 min)
#
# Al finalizar esta clase, podrás:
#
# 1. Preparar y validar el dataset del proyecto antes de llevarlo a Power BI.
# 2. Importar un archivo **Excel** y revisar su estructura en **Power Query**.
# 3. Corregir tipos de datos críticos:
#    - fecha con **locale**
#    - columnas numéricas
#    - perfil de columna
# 4. Diseñar un dashboard con **2 páginas**:
#    - **Overview:** qué pasó
#    - **Detalle:** por qué pasó
# 5. Crear medidas DAX básicas para tus KPIs.
# 6. Redactar una **narrativa ejecutiva** basada en evidencia.
#
# ### Entregable esperado
# Al terminar la clase deberías tener:
# - tu archivo `.pbix` con dos páginas,
# - medidas DAX mínimas,
# - segmentadores funcionando,
# - y este notebook con tus decisiones e interpretación.

# %% [markdown]
# ## Agenda sugerida (100 minutos)
#
# 1. Contexto del proyecto + checklist de entregables
# 2. **Actividad 0:** preguntas de negocio + KPIs + boceto
# 3. Ejercicio 1: dataset del proyecto + grano + columnas clave
# 4. Ejercicio 2: conexión y exploración en Power BI
# 5. Ejercicio 3: Power Query (tipos, locale, columna condicional, perfil)
# 6. Ejercicio 4: planificación de las 2 vistas
# 7. Ejercicio 5: construcción de la página **Overview**
# 8. Ejercicio 6: construcción de la página **Detalle** + segmentadores
# 9. Ejercicio 7: narrativa SCQA + entrega final
#
# ### Recomendación de trabajo
# En cada bloque intenta registrar:
# - **qué hiciste,**
# - **qué observaste,**
# - **qué decidiste,**
# - **qué significa para negocio.**

# %% [markdown]
# ## Materiales de la sesión
#
# ### Archivos de apoyo
# - Notebook de trabajo del proyecto
# - Power BI Desktop
# - Dataset del proyecto en Excel
#
# ### Qué practicarás hoy
# - conexión a archivo Excel,
# - revisión de estructura y grano,
# - transformación en Power Query,
# - medidas DAX,
# - diseño de dashboard,
# - narrativa ejecutiva.
#
# ### Checklist técnico
# Marca lo que tengas listo:
# - [ ] Tengo acceso a Power BI Desktop
# - [ ] Tengo el archivo Excel del proyecto
# - [ ] Puedo abrir Power Query
# - [ ] Entiendo qué significa **1 fila** en el dataset
# - [ ] Tengo claro que el entregable final incluye dashboard + interpretación

# %% [markdown]
# ## Dataset de la sesión — Andes Retail Group
#
# ### ¿Qué representa una fila?
# En este proyecto:
#
# > **1 fila = 1 transacción** (un producto vendido dentro de un pedido)
#
# ### Columnas importantes del caso
# - `Fecha_pedido`
# - `Ingresos`
# - `Costo`
# - `Ganancia`
# - `Pais`
# - `Region`
# - `Ciudad`
# - `Segmento_Cliente`
# - `Categoria_Producto`
# - `Producto`
# - `Canal`
# - `Campaña`
# - `Estación`
#
# ### Antes de empezar
# Completa:
# 1. **¿Cuál es la métrica principal del dashboard?** __________________________
# 2. **¿Qué columnas usarías para segmentar?** __________________________
# 3. **¿Qué errores de calidad podrían romper una visualización o una medida?** __________________________
#
# ### Mini diccionario de datos
# Completa con tus palabras:
# - `Fecha_pedido`: ________________________________________
# - `Ingresos`: ________________________________________
# - `Ganancia`: ________________________________________
# - `Pais`: ________________________________________
# - `Categoria_Producto`: ________________________________________
# - `Segmento_Cliente`: ________________________________________

# %% [markdown]
# ---
#
# # Actividad 0 · Boceto rápido del dashboard (10 min)
#
# ### Caso
# **“Andes Retail Group quiere entender cómo evolucionaron los ingresos 2024–2025 y por qué cambian por meses, países, categorías y estaciones.”**
#
# ### Tu tarea
# Antes de abrir Power BI, piensa el dashboard como una historia.
#
# Completa:
#
# - **Audiencia principal:** ________________________________________
# - **Pregunta principal del Overview:** ________________________________________
# - **3 o 4 KPIs del Overview:** ________________________________________
# - **Pregunta principal del Detalle:** ________________________________________
# - **2 posibles causas a investigar:** ________________________________________
# - **2 segmentadores mínimos:** ________________________________________
#
# ### Boceto rápido
# Escribe cómo distribuirías la página:
#
# **Overview**
# - fila superior: ________________________________________
# - parte central: ________________________________________
# - lado derecho / inferior: ________________________________________
#
# **Detalle**
# - visual 1: ________________________________________
# - visual 2: ________________________________________
# - tabla / apoyo: ________________________________________
#
# ### Reflexión breve
# ¿Por qué un dashboard no debe ser solo “muchos gráficos juntos”?
# ________________________________________________________________
# ________________________________________________________________

# %% [markdown]
# # Ejercicio 1 · Generar/obtener el Excel del proyecto + entender estructura (10 min)
#
# **Meta:** tener el archivo listo y entender la estructura antes de llevarlo a Power BI.
#
# ### Tu tarea
# 1. Generar el Excel o confirmar que ya lo tienes.
# 2. Ver una muestra de los datos.
# 3. Confirmar:
#    - grano,
#    - columnas clave,
#    - posibles problemas de tipo.
#
# ### Evidencia mínima
# - nombre del archivo,
# - cantidad de filas y columnas,
# - 5 columnas importantes para el dashboard,
# - una observación sobre calidad de datos.

# %%
# ============================================================
# Generación del dataset de práctica (ejecuta si necesitas crear el Excel)
# ============================================================
import pandas as pd
import numpy as np
import random
import datetime as dt

random.seed(42)
np.random.seed(42)

def season_es(date):
    m = date.month
    if m in [12, 1, 2]:
        return "Verano"
    if m in [3, 4, 5]:
        return "Otoño"
    if m in [6, 7, 8]:
        return "Invierno"
    return "Primavera"

countries = {
    "Peru": {"cities": [("Lima", "Costa"), ("Arequipa", "Sierra"), ("Trujillo", "Costa"), ("Cusco", "Sierra")], "weight": 0.42},
    "Colombia": {"cities": [("Bogotá", "Andina"), ("Medellín", "Andina"), ("Cali", "Pacífico"), ("Barranquilla", "Caribe")], "weight": 0.28},
    "Chile": {"cities": [("Santiago", "Centro"), ("Valparaíso", "Centro"), ("Concepción", "Sur"), ("Antofagasta", "Norte")], "weight": 0.18},
    "Mexico": {"cities": [("CDMX", "Centro"), ("Guadalajara", "Occidente"), ("Monterrey", "Norte"), ("Puebla", "Centro")], "weight": 0.12},
}
country_list = list(countries.keys())
country_weights = np.array([countries[c]["weight"] for c in country_list])
country_weights = country_weights / country_weights.sum()

segments = ["Premium", "Estandar", "Basico"]
segment_w = [0.25, 0.5, 0.25]

categories = {
    "Electronica": {"products": [("Audifonos", 120), ("Smartwatch", 180), ("Tablet", 350), ("Parlante", 140)]},
    "Hogar": {"products": [("Licuadora", 90), ("Aspiradora", 220), ("Cafetera", 130), ("Lampara", 60)]},
    "Moda": {"products": [("Zapatillas", 110), ("Chaqueta", 150), ("Jeans", 80), ("Bolso", 95)]},
    "Deportes": {"products": [("Bicicleta", 520), ("Guantes", 35), ("Cuerda", 18), ("Mancuernas", 65)]},
}
channels = ["Online", "Tienda"]
channel_w = [0.62, 0.38]
campaigns = ["Siempre activo", "Back to School", "Black Friday", "Navidad", "Temporada baja"]
campaign_w = [0.55, 0.10, 0.12, 0.13, 0.10]

def make_orders(n_rows=9000):
    start = dt.date(2024, 1, 1)
    end = dt.date(2025, 12, 31)
    days = (end - start).days + 1
    dates = [start + dt.timedelta(days=int(np.random.randint(0, days))) for _ in range(n_rows)]
    out = []

    for i, d in enumerate(dates):
        country = np.random.choice(country_list, p=country_weights)
        city, region = random.choice(countries[country]["cities"])
        seg = np.random.choice(segments, p=segment_w)

        cat = random.choice(list(categories.keys()))
        prod, base_price = random.choice(categories[cat]["products"])
        channel = np.random.choice(channels, p=channel_w)
        campaign = np.random.choice(campaigns, p=campaign_w)
        season = season_es(d)

        units = int(np.random.choice([1, 2, 3, 4, 5], p=[0.35, 0.28, 0.18, 0.12, 0.07]))
        season_factor = 1.0
        if season == "Verano":
            season_factor = 1.10
        elif season == "Invierno":
            season_factor = 0.92

        campaign_factor = {
            "Siempre activo": 1.00,
            "Back to School": 1.05,
            "Black Friday": 0.93,
            "Navidad": 1.12,
            "Temporada baja": 0.90
        }[campaign]

        seg_factor = {"Premium": 1.20, "Estandar": 1.00, "Basico": 0.88}[seg]
        channel_factor = {"Online": 0.98, "Tienda": 1.03}[channel]

        price = base_price * season_factor * campaign_factor * seg_factor * channel_factor * np.random.normal(1, 0.08)
        ingresos = max(10, round(price * units, 2))

        margin_pct = np.random.uniform(0.18, 0.42)
        costo = round(ingresos * (1 - margin_pct), 2)
        ganancia = ingresos - costo

        discount = np.random.uniform(0.00, 0.25)
        if np.random.rand() < 0.015:
            discount = np.nan

        unidades_val = str(units) if np.random.rand() < 0.35 else units
        ingresos_val = f"{ingresos:.2f}" if np.random.rand() < 0.25 else ingresos

        out.append({
            "ID_Pedido": f"ORD-{d.year}{d.month:02d}-{i:05d}",
            "Fecha_pedido": d.strftime("%d/%m/%Y"),
            "ID_Cliente": f"CLI-{np.random.randint(1000, 9999)}",
            "Segmento_Cliente": seg,
            "Pais": country,
            "Region": region,
            "Ciudad": city,
            "Categoria_Producto": cat,
            "Producto": prod,
            "Canal": channel,
            "Campaña": campaign,
            "Estación": season,
            "Unidades": unidades_val,
            "Descuento_pct": discount,
            "Ingresos": ingresos_val,
            "Costo": costo,
            "Ganancia": ganancia
        })
    return pd.DataFrame(out)

df = make_orders(9000)

excel_path = "S10_AndesRetail_Desempeno_Comercial_2024_2025.xlsx"
csv_path = "S10_AndesRetail_Desempeno_Comercial_2024_2025.csv"

df.to_csv(csv_path, index=False, encoding="utf-8")
with pd.ExcelWriter(excel_path, engine="openpyxl") as writer:
    df.to_excel(writer, sheet_name="Ventas", index=False)

print("Archivo Excel:", excel_path)
print("Archivo CSV:", csv_path)
print("Dimensiones:", df.shape)

# TODO opcional:
# 1. imprime df.head()
# 2. revisa df.dtypes
# 3. anota qué columnas podrían dar problemas en Power BI

# %%
# Exploración rápida del dataset
# Completa o ajusta estas líneas según lo que necesites registrar.

# TODO: muestra las primeras filas
df.head()

# TODO: revisa dimensiones
print("Dimensiones:", df.shape)

# TODO: revisa tipos
df.dtypes

# %% [markdown]
# ### Registro del Ejercicio 1
#
# Completa:
#
# - **Nombre del archivo a importar en Power BI:** __________________________
# - **Número de filas:** __________________________
# - **Número de columnas:** __________________________
# - **Grano del dataset:** __________________________
#
# **5 columnas clave para el dashboard**
# 1. __________________________
# 2. __________________________
# 3. __________________________
# 4. __________________________
# 5. __________________________
#
# **Observaciones de calidad**
# - Columna que puede venir como texto pero debería ser fecha: __________________________
# - Columna que puede venir como texto pero debería ser numérica: __________________________
# - Otra observación: __________________________

# %% [markdown]
# # Ejercicio 2 · Paso 1 del proyecto: Conexión y exploración en Power BI (10 min)
#
# **Meta:** abrir correctamente la fuente y entender qué revisar antes de construir visualizaciones.
#
# ### Qué debes hacer en Power BI
# 1. **Obtener datos → Excel**
# 2. Seleccionar el archivo del proyecto
# 3. Elegir la hoja **Ventas**
# 4. Ir a **Transformar datos**
# 5. Revisar columnas, tipos y posibles errores
#
# ### Checklist de revisión
# Marca lo que observes:
# - [ ] `Fecha_pedido` quedó como fecha
# - [ ] `Fecha_pedido` quedó como texto
# - [ ] `Ingresos` quedó como decimal
# - [ ] `Ingresos` quedó como texto
# - [ ] `Unidades` necesita corrección
# - [ ] Veo íconos de tipo incorrectos
# - [ ] La hoja cargó sin errores visibles
#
# ### Registro de observaciones
# - ¿Qué columna revisarías primero? __________________________
# - ¿Qué error sería más riesgoso para el dashboard? __________________________
# - ¿Qué campos son métricas? __________________________
# - ¿Qué campos son segmentadores? __________________________

# %% [markdown]
# # Ejercicio 3 · Paso 2 del proyecto: Transformación con Power Query (18 min)
#
# **Meta:** dejar la tabla lista para análisis.
#
# ## Parte A · Fecha con locale
# Convierte `Fecha_pedido` correctamente usando configuración regional.
#
# ### Registra aquí
# - **Tipo original de `Fecha_pedido`:** __________________________
# - **Locale usado:** __________________________
# - **¿Se resolvió el problema?** __________________________
#
# ## Parte B · Tipos numéricos
# Revisa y corrige:
# - `Ingresos`
# - `Costo`
# - `Ganancia`
# - `Descuento_pct`
# - `Unidades`
#
# ### Tabla de control
# | Columna | Tipo antes | Tipo después | ¿Hubo errores? | Nota |
# |---|---|---|---|---|
# | Ingresos |  |  |  |  |
# | Costo |  |  |  |  |
# | Ganancia |  |  |  |  |
# | Descuento_pct |  |  |  |  |
# | Unidades |  |  |  |  |
#
# ## Parte C · Columna condicional `Nivel_Venta`
# Crea una regla como esta:
# - si `Ingresos` >= `1000` → `Venta Alta`
# - si no → `Venta Baja`
#
# ### Completa
# - **Nombre de la columna creada:** __________________________
# - **Lógica aplicada:** __________________________
# - **¿Por qué puede servir esta columna en el dashboard?** __________________________
#
# ## Parte D · Perfil de columna
# Activa:
# - Calidad de columna
# - Distribución de columna
# - Perfil de columna
#
# ### Hallazgos
# - ¿Qué columna tiene nulos? __________________________
# - ¿Qué columna tiene valores sospechosos o mixtos? __________________________
# - ¿Qué corregiste o documentaste? __________________________

# %% [markdown]
# # Ejercicio 4 · Paso 3 del proyecto: Diseño y planificación del dashboard (12 min)
#
# **Meta:** pensar el dashboard antes de construirlo.
#
# ## Vista 1 · Overview
# **Pregunta principal:** ________________________________________
#
# ### KPIs elegidos
# 1. __________________________
# 2. __________________________
# 3. __________________________
# 4. __________________________
#
# ### Visuales planeados
# - Visual 1: __________________________
# - Visual 2: __________________________
# - Visual 3: __________________________
#
# ### Justificación
# ¿Por qué esos visuales ayudan a responder la pregunta?
# ________________________________________________________________
# ________________________________________________________________
#
# ## Vista 2 · Detalle
# **Pregunta principal:** ________________________________________
#
# ### Visuales planeados
# - Visual 1: __________________________
# - Visual 2: __________________________
# - Visual 3 / tabla: __________________________
#
# ### Posibles causas del cambio en ingresos
# - Causa 1: __________________________
# - Causa 2: __________________________
# - Causa 3: __________________________
#
# ## Segmentadores mínimos
# - Segmentador 1: __________________________
# - Segmentador 2: __________________________
# - Segmentador opcional: __________________________

# %% [markdown]
# # Ejercicio 5 · Paso 4 del proyecto: Construir Vista 1 (Overview Ejecutivo) (18 min)
#
# **Meta:** construir la página que responda **qué pasó**.
#
# ## Parte A · Medidas DAX sugeridas
# Completa o adapta estas medidas en Power BI:
#
# ```DAX
# Ingresos Total = SUM(Ventas[________________])
# ```
#
# ```DAX
# Ganancia Total = SUM(Ventas[________________])
# ```
#
# ```DAX
# Margen = DIVIDE([________________], [________________])
# ```
#
# ```DAX
# Pedidos = DISTINCTCOUNT(Ventas[________________])
# ```
#
# ```DAX
# Clientes = DISTINCTCOUNT(Ventas[________________])
# ```
#
# ```DAX
# Ticket Promedio = DIVIDE([________________], [________________])
# ```
#
# ## Parte B · Checklist de construcción
# Marca lo que ya dejaste listo:
# - [ ] Tarjeta KPI de Ingresos
# - [ ] Tarjeta KPI de Ganancia
# - [ ] Tarjeta KPI de Margen
# - [ ] Tarjeta KPI de Pedidos o Clientes
# - [ ] Línea temporal de ingresos
# - [ ] Comparación por país o región
# - [ ] Comparación por categoría o segmento
#
# ## Registro de implementación
# - **Eje temporal usado:** __________________________
# - **Variable geográfica usada:** __________________________
# - **Variable comercial usada:** __________________________
# - **Visual que mejor explica el overview:** __________________________
#
# ## Mini interpretación
# ¿Qué observaste en el Overview?
# ________________________________________________________________
# ________________________________________________________________

# %% [markdown]
# # Ejercicio 6 · Paso 4 del proyecto: Construir Vista 2 (Análisis Detallado) + segmentadores (12 min)
#
# **Meta:** construir la página que responda **por qué pasó**.
#
# ## Visuales recomendados
# Usa al menos 3 de estos enfoques:
# - ingresos por `Estación`
# - ingresos por `Categoria_Producto`
# - ingresos por `Segmento_Cliente`
# - ingresos por `Canal`
# - tabla de diagnóstico con KPIs
#
# ## Diseño de la vista
# Completa:
# - **Visual principal del detalle:** __________________________
# - **Dimensión que parece explicar mejor el cambio:** __________________________
# - **Tabla o apoyo adicional:** __________________________
#
# ## Segmentadores
# Marca o anota cuáles agregaste:
# - [ ] Fecha / rango
# - [ ] País
# - [ ] Categoría
# - [ ] Segmento cliente
# - [ ] Canal
#
# ## Registro de hallazgos
# 1. ¿Qué estación parece más débil? __________________________
# 2. ¿Qué categoría o segmento requiere atención? __________________________
# 3. ¿Qué filtro fue más útil para explicar el comportamiento? __________________________
#
# ## Mini conclusión del detalle
# ________________________________________________________________
# ________________________________________________________________

# %% [markdown]
# # Ejercicio 7 · Paso 5 + Entrega final: narrativa SCQA + mensaje ejecutivo + exportación (5 min)
#
# ## Parte A · Narrativa SCQA
# Completa con tus hallazgos:
#
# **S · Situación**
# ______________________________________________________________
#
# **C · Complicación**
# ______________________________________________________________
#
# **Q · Pregunta**
# ______________________________________________________________
#
# **A · Respuesta / recomendación**
# ______________________________________________________________
# ______________________________________________________________
#
# ## Parte B · Mensaje estilo Slack o correo interno
# Escribe un mensaje corto para stakeholders:
#
# > **Actualización de desempeño comercial**
# > ____________________________________________
# > ____________________________________________
# > ____________________________________________
#
# ## Parte C · Checklist final
# - [ ] Dataset cargado correctamente
# - [ ] Tipos de datos corregidos
# - [ ] `Nivel_Venta` creada
# - [ ] Página Overview lista
# - [ ] Página Detalle lista
# - [ ] Segmentadores funcionando
# - [ ] Narrativa ejecutiva redactada
# - [ ] Archivo listo para entregar o publicar

# %% [markdown]
# # Cierre y autoevaluación
#
# ## Takeaways
# Escribe 3 aprendizajes de la sesión:
# 1. ____________________________________________
# 2. ____________________________________________
# 3. ____________________________________________
#
# ### ¿Necesitas ayuda?
# Recuerda los canales de ayuda que tenemos disponibles:
# - `DATA-CO-LEARNING`: Revisa los horarios de atencion en la guia dele studiante. Recuerda que tenemos horarios de apoyo todos los días para tus dudas puntuales!
# - `DA_CONSULTA`: Uuedes publicar tus preguntas sobre el contenido de la plataforma o el proyecto 24/7. Recuerda que en tu pregunta debes de agregar el tag @Dataconsulta.
# - `SPRINT FOCUS`: Para los Sprints 1 al 5 tenemos sesiones extra donde abordamos temáticas de cada sprint a rpofundidad. Revisa la guia del estudiante para conocer los horarios!
# - `SESIONES 1:1`: Recuerda que puedes agendar sesiones 1:1 con un tutor. Agendalas con antelación y resuelve todas tus dudas, desde temás del proyecto, curso, carrera hasta problemas técnicos.
# - `CANAL DE DISCORD DE COMMUNITY`: Recuerda que tu cohorte tiene un canal especial donde puedes compartir cualquier item interesante que quieras mostrar a tus compañeros de curso.
#
# ## Autoevaluación
# Marca cómo te sentiste hoy:
# - [ ] Puedo importar y revisar una fuente en Power BI
# - [ ] Puedo corregir tipos en Power Query
# - [ ] Puedo planear un dashboard antes de construirlo
# - [ ] Puedo crear medidas DAX básicas
# - [ ] Puedo traducir hallazgos en una recomendación de negocio
