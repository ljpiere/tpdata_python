# %% [markdown]
# # Sprint 3 — Sesión práctica — Versión estudiante
# ## SQL aplicado a KPIs de negocio en Google Colab con DuckDB y Parquet
#
# > **Duración:** 70 minutos
# > **Herramienta principal:** Google Colab
# > **Motor SQL:** DuckDB en memoria
# > **Dataset:** tablas Parquet cargadas desde GitHub
# > **Prefijo de archivos:** `webinar03_`
# > **Caso:** librería online / bookstore finance
#
# Esta sesión consolida las sesiones prácticas del Sprint 3. El objetivo no es configurar herramientas locales, sino practicar SQL sobre tablas reales del caso usando Colab.
#
# URL base esperada:
#
# ```text
# https://github.com/ljpiere/tpdata_course/raw/refs/heads/main/DA/DA_students/datasets/webinar03_*.parquet
# ```

# %% [markdown]
# ## Cómo usar esta versión estudiante
#
# Este notebook está preparado para que tomes apuntes, completes ejercicios y documentes tus decisiones durante la clase.
#
# **Modo de trabajo recomendado:**
#
# 1. Lee primero la consigna de cada bloque o ejercicio.
# 2. Completa los espacios de respuesta antes de comparar con la explicación del instructor/a.
# 3. Ejecuta las celdas de setup cuando existan.
# 4. Escribe interpretación, dudas y decisiones en los espacios de apuntes.
# 5. Al final, revisa si tus respuestas conectan datos, método e implicación de negocio.
#
# > Las salidas de ejecución fueron limpiadas para que puedas correr el notebook desde cero.

# %% [markdown]
# ## Notas de clase principales
#
# - La práctica transforma preguntas de negocio en consultas SQL verificables.
# - Cada ejercicio debe empezar identificando tabla base, llave de unión, métrica y dimensión.
# - Usa `COUNT(DISTINCT ...)` cuando los joins puedan multiplicar registros.
# - Filtra estados no válidos si distorsionan métricas operativas o financieras.
# - La consulta final debe ir acompañada de una interpretación breve del resultado.
#
# ### Mis notas iniciales
#
# -
# -
# -

# %% [markdown]
# ## Agenda de práctica
#
# | Momento | Duración | Propósito |
# |---|---:|---|
# | 1. Setup en Colab | 8 min | Crear tablas DuckDB desde Parquet en GitHub |
# | 2. Sanity checks | 7 min | Validar tablas, conteos y estructura |
# | 3. Ejercicio 0 | 8 min | Analizar estado de orden y método de pago |
# | 4. Ejercicio 1 | 8 min | Calcular órdenes y ticket por segmento |
# | 5. Ejercicio 2 | 10 min | Calcular revenue por categoría |
# | 6. Ejercicio 3 | 9 min | Encontrar top productos por revenue |
# | 7. Ejercicio 4 | 10 min | Calcular margen bruto por categoría |
# | 8. Ejercicio 5 | 5 min | Comparar promo vs no promo |
# | 9. Cierre | 5 min | Validación, takeaways y canales de ayuda |

# %% [markdown]
# ## Objetivos de aprendizaje
#
# Al finalizar la práctica, el estudiante podrá:
#
# - Cargar y validar tablas Parquet desde GitHub en Colab.
# - Formular una pregunta de negocio como consulta SQL.
# - Seleccionar tablas y llaves de unión correctamente.
# - Usar `JOIN`, `GROUP BY`, `CASE`, `ORDER BY` y `LIMIT`.
# - Calcular KPIs de revenue, ticket promedio, margen y ROI.
# - Interpretar resultados sin caer en conclusiones causales débiles.
# - Depurar errores comunes de SQL.

# %% [markdown]
# ## 0) Setup de trabajo
#
# Ejecuta la celda de setup. Si aparece error de lectura de URL, revisa que los archivos `.parquet` ya estén cargados en el repositorio en:
#
# ```text
# new_DA/DA_tutor/datasets/
# ```
#
# con estos nombres:
#
# - `webinar03_customers.parquet`
# - `webinar03_products.parquet`
# - `webinar03_orders.parquet`
# - `webinar03_order_items.parquet`
# - `webinar03_payments.parquet`
# - `webinar03_campaigns.parquet`

# %% [markdown]
# ### Mis apuntes
#
# -
# -
# -

# %%
# Instalaremos un motor de base de datos llamado duckdb
# %pip install duckdb pandas pyarrow

# %%
# Setup de Google Colab para practicar SQL con DuckDB y Parquet desde GitHub


import duckdb
import pandas as pd

BASE_URL = "https://raw.githubusercontent.com/ljpiere/tpdata_python/refs/heads/main/DA/DA_students/datasets/"

TABLE_FILES = {
    "customers": "sprint03_customers.parquet",
    "products": "sprint03_products.parquet",
    "orders": "sprint03_orders.parquet",
    "order_items": "sprint03_order_items.parquet",
    "payments": "sprint03_payments.parquet",
    "campaigns": "sprint03_campaigns.parquet"
}

con = duckdb.connect(database=":memory:")

for table_name, file_name in TABLE_FILES.items():
    url = f"{BASE_URL}/{file_name}"
    df = pd.read_parquet(url)
    con.register(f"{table_name}_df", df)
    con.execute(f"CREATE OR REPLACE TABLE {table_name} AS SELECT * FROM {table_name}_df")

def sql(query):
    """Ejecuta una consulta SQL en DuckDB y devuelve un DataFrame de pandas."""
    return con.execute(query).df()

print("Tablas cargadas en DuckDB:")
print(list(TABLE_FILES.keys()))

# %% [markdown]
# ## 1) Sanity checks
#
# Antes de resolver ejercicios, valida que las tablas existan y tengan el tamaño esperado.
#
# También revisa algunas filas de cada tabla para familiarizarte con columnas, tipos de dato y valores.

# %% [markdown]
# ### Espacio de trabajo del estudiante
#
# **Mi interpretación de la consigna:**
#
# **Mi procedimiento / fórmula / consulta:**
#
# **Resultado obtenido:**
#
# **Conclusión breve:**

# %%
# TODO estudiante: completa la consulta SQL de acuerdo con la consigna anterior.
# Sugerencia:
# 1. Identifica la tabla base.
# 2. Define la métrica y la dimensión.
# 3. Valida si necesitas JOIN, WHERE, GROUP BY u ORDER BY.

query = """
-- Escribe tu SQL aquí
SELECT
    -- columnas o métricas
FROM
    -- tabla_base
-- WHERE ...
-- GROUP BY ...
-- ORDER BY ...
;
"""

sql(query)

# %%
# TODO estudiante: completa la consulta SQL de acuerdo con la consigna anterior.
# Sugerencia:
# 1. Identifica la tabla base.
# 2. Define la métrica y la dimensión.
# 3. Valida si necesitas JOIN, WHERE, GROUP BY u ORDER BY.

query = """
-- Escribe tu SQL aquí
SELECT
    -- columnas o métricas
FROM
    -- tabla_base
-- WHERE ...
-- GROUP BY ...
-- ORDER BY ...
;
"""

sql(query)

# %% [markdown]
# ## Método de trabajo para cada ejercicio
#
# Antes de escribir SQL, completa mentalmente:
#
# | Pregunta | Decisión |
# |---|---|
# | ¿Cuál es la pregunta de negocio? | |
# | ¿Cuál es la tabla base? | |
# | ¿Qué otras tablas necesito? | |
# | ¿Cuál es la llave de unión? | |
# | ¿Qué métrica voy a calcular? | |
# | ¿Debo filtrar algún estado? | |
# | ¿Cómo voy a interpretar el resultado? | |
#
# Regla de negocio sugerida para KPIs operativos:
#
# ```sql
# WHERE o.status NOT IN ('cancelled', 'refunded')
# ```

# %% [markdown]
# ### Espacio de trabajo del estudiante
#
# **Mi interpretación de la consigna:**
#
# **Mi procedimiento / fórmula / consulta:**
#
# **Resultado obtenido:**
#
# **Conclusión breve:**

# %% [markdown]
# ## Ejercicio 0 — Estado de orden y método de pago
#
# ### Objetivo
#
# Calcular, por `status` y `payment_method`:
#
# - número de órdenes;
# - total pagado.
#
# ### Antes de escribir
#
# | Elemento | Respuesta |
# |---|---|
# | Tabla de órdenes | |
# | Tabla de pagos | |
# | Llave de unión | |
# | Métrica principal | |
#
# ### Interpretación
#
# Después de ejecutar, escribe:
#
# **Qué combinación concentra más valor pagado:** ____________________________
#
# **Qué podría significar para el negocio:** _________________________________

# %% [markdown]
# ### Espacio de trabajo del estudiante
#
# **Mi interpretación de la consigna:**
#
# **Mi procedimiento / fórmula / consulta:**
#
# **Resultado obtenido:**
#
# **Conclusión breve:**

# %%
# TODO estudiante: completa la consulta SQL de acuerdo con la consigna anterior.
# Sugerencia:
# 1. Identifica la tabla base.
# 2. Define la métrica y la dimensión.
# 3. Valida si necesitas JOIN, WHERE, GROUP BY u ORDER BY.

query = """
-- Escribe tu SQL aquí
SELECT
    -- columnas o métricas
FROM
    -- tabla_base
-- WHERE ...
-- GROUP BY ...
-- ORDER BY ...
;
"""

sql(query)

# %% [markdown]
# ## Ejercicio 1 — Órdenes por segmento de cliente
#
# ### Objetivo
#
# Obtener por `segment`:
#
# - número de órdenes;
# - total pagado;
# - ticket promedio.
#
# ### Pistas
#
# - `customers` se une con `orders` por `customer_id`.
# - `orders` se une con `payments` por `order_id`.
# - El ticket promedio puede ser `SUM(amount_paid) / COUNT(DISTINCT order_id)`.
#
# ### Resultado
#
# | Segmento con mayor total pagado | Interpretación |
# |---|---|
# | | |

# %% [markdown]
# ### Espacio de trabajo del estudiante
#
# **Mi interpretación de la consigna:**
#
# **Mi procedimiento / fórmula / consulta:**
#
# **Resultado obtenido:**
#
# **Conclusión breve:**

# %%
# TODO estudiante: completa la consulta SQL de acuerdo con la consigna anterior.
# Sugerencia:
# 1. Identifica la tabla base.
# 2. Define la métrica y la dimensión.
# 3. Valida si necesitas JOIN, WHERE, GROUP BY u ORDER BY.

query = """
-- Escribe tu SQL aquí
SELECT
    -- columnas o métricas
FROM
    -- tabla_base
-- WHERE ...
-- GROUP BY ...
-- ORDER BY ...
;
"""

sql(query)

# %% [markdown]
# ## Ejercicio 2 — Revenue por categoría
#
# ### Objetivo
#
# Calcular revenue por `category`.
#
# Fórmula:
#
# ```text
# revenue = quantity * unit_price * (1 - discount_rate)
# ```
#
# ### Antes de empezar
#
# | Elemento | Respuesta |
# |---|---|
# | Tabla con cantidad | |
# | Tabla con categoría | |
# | Llave de unión | |
# | Columna de agrupación | |
#
# ### Pregunta conceptual
#
# ¿Por qué el descuento afecta el revenue?
#
# _____________________________________________________________________

# %% [markdown]
# ### Espacio de trabajo del estudiante
#
# **Mi interpretación de la consigna:**
#
# **Mi procedimiento / fórmula / consulta:**
#
# **Resultado obtenido:**
#
# **Conclusión breve:**

# %%
# TODO estudiante: completa la consulta SQL de acuerdo con la consigna anterior.
# Sugerencia:
# 1. Identifica la tabla base.
# 2. Define la métrica y la dimensión.
# 3. Valida si necesitas JOIN, WHERE, GROUP BY u ORDER BY.

query = """
-- Escribe tu SQL aquí
SELECT
    -- columnas o métricas
FROM
    -- tabla_base
-- WHERE ...
-- GROUP BY ...
-- ORDER BY ...
;
"""

sql(query)

# %% [markdown]
# ## Ejercicio 3 — Top 5 productos por revenue
#
# ### Objetivo
#
# Mostrar:
#
# - `product_id`;
# - `title`;
# - `category`;
# - revenue total.
#
# ### Control mental
#
# - Las columnas no agregadas del `SELECT` deben aparecer en el `GROUP BY`.
# - El top 5 requiere `ORDER BY revenue DESC LIMIT 5`.
#
# ### Resultado
#
# Producto líder: _____________________________________________________
#
# ¿El resultado es esperable? ¿Por qué?
#
# _____________________________________________________________________

# %% [markdown]
# ### Espacio de trabajo del estudiante
#
# **Mi interpretación de la consigna:**
#
# **Mi procedimiento / fórmula / consulta:**
#
# **Resultado obtenido:**
#
# **Conclusión breve:**

# %%
# TODO estudiante: completa la consulta SQL de acuerdo con la consigna anterior.
# Sugerencia:
# 1. Identifica la tabla base.
# 2. Define la métrica y la dimensión.
# 3. Valida si necesitas JOIN, WHERE, GROUP BY u ORDER BY.

query = """
-- Escribe tu SQL aquí
SELECT
    -- columnas o métricas
FROM
    -- tabla_base
-- WHERE ...
-- GROUP BY ...
-- ORDER BY ...
;
"""

sql(query)

# %% [markdown]
# ## Ejercicio 4 — Margen bruto por categoría
#
# ### Objetivo
#
# Calcular por categoría:
#
# - `revenue`;
# - `cost`;
# - `gross_profit`;
# - `margin_pct`.
#
# Fórmulas:
#
# ```text
# gross_profit = revenue - cost
# margin_pct = 100 * gross_profit / revenue
# ```
#
# ### Pregunta de control
#
# ¿Por qué conviene proteger el cálculo de margen con `NULLIF`?
#
# _____________________________________________________________________

# %% [markdown]
# ### Espacio de trabajo del estudiante
#
# **Mi interpretación de la consigna:**
#
# **Mi procedimiento / fórmula / consulta:**
#
# **Resultado obtenido:**
#
# **Conclusión breve:**

# %%
# TODO estudiante: completa la consulta SQL de acuerdo con la consigna anterior.
# Sugerencia:
# 1. Identifica la tabla base.
# 2. Define la métrica y la dimensión.
# 3. Valida si necesitas JOIN, WHERE, GROUP BY u ORDER BY.

query = """
-- Escribe tu SQL aquí
SELECT
    -- columnas o métricas
FROM
    -- tabla_base
-- WHERE ...
-- GROUP BY ...
-- ORDER BY ...
;
"""

sql(query)

# %% [markdown]
# ## Ejercicio 5 — Promo vs no promo
#
# ### Objetivo
#
# Comparar órdenes con promo y sin promo.
#
# Debes obtener:
#
# - `grupo_promo`;
# - `n_orders`;
# - `total_discount`;
# - `total_paid`;
# - `avg_ticket`.
#
# ### Pista
#
# Usa `CASE`:
#
# ```sql
# CASE
#     WHEN o.promo_code IS NULL THEN 'sin_promo'
#     ELSE 'con_promo'
# END AS grupo_promo
# ```
#
# ### Reflexión
#
# Si las órdenes con promo venden más, eso no prueba automáticamente que la promo funciona.
#
# Escribe una razón:
#
# _____________________________________________________________________

# %% [markdown]
# ### Espacio de trabajo del estudiante
#
# **Mi interpretación de la consigna:**
#
# **Mi procedimiento / fórmula / consulta:**
#
# **Resultado obtenido:**
#
# **Conclusión breve:**

# %%
# TODO estudiante: completa la consulta SQL de acuerdo con la consigna anterior.
# Sugerencia:
# 1. Identifica la tabla base.
# 2. Define la métrica y la dimensión.
# 3. Valida si necesitas JOIN, WHERE, GROUP BY u ORDER BY.

query = """
-- Escribe tu SQL aquí
SELECT
    -- columnas o métricas
FROM
    -- tabla_base
-- WHERE ...
-- GROUP BY ...
-- ORDER BY ...
;
"""

sql(query)

# %% [markdown]
# ## Ejercicio 6 — ROI por campaña
#
# ### Objetivo
#
# Usar la tabla `campaigns` para calcular ROI por campaña.
#
# Debes obtener:
#
# - `promo_code`;
# - `campaign_name`;
# - `spend_usd`;
# - `n_orders`;
# - `net_revenue`;
# - `roi_pct`.
#
# Fórmula:
#
# ```text
# ROI % = 100 * (net_revenue - spend_usd) / spend_usd
# ```
#
# ### Interpretación
#
# Campaña con mejor ROI: _____________________________________________
#
# Campaña con más volumen: ___________________________________________
#
# ¿Son la misma? ¿Qué significa?
#
# _____________________________________________________________________

# %% [markdown]
# ### Espacio de trabajo del estudiante
#
# **Mi interpretación de la consigna:**
#
# **Mi procedimiento / fórmula / consulta:**
#
# **Resultado obtenido:**
#
# **Conclusión breve:**

# %%
# TODO estudiante: completa la consulta SQL de acuerdo con la consigna anterior.
# Sugerencia:
# 1. Identifica la tabla base.
# 2. Define la métrica y la dimensión.
# 3. Valida si necesitas JOIN, WHERE, GROUP BY u ORDER BY.

query = """
-- Escribe tu SQL aquí
SELECT
    -- columnas o métricas
FROM
    -- tabla_base
-- WHERE ...
-- GROUP BY ...
-- ORDER BY ...
;
"""

sql(query)

# %% [markdown]
# # Retos opcionales
#
# ## Reto A — Estados con mayor volumen
#
# Construye una consulta para ver estados de orden con más actividad y total pagado.
#
# ## Reto B — Top 10 clientes por gasto total
#
# Identifica clientes de mayor valor.
#
# ## Reto C — Categorías con margen alto pero bajo volumen
#
# Busca oportunidades de crecimiento.
#
# ## Reto D — Campañas con ROI alto pero bajo volumen
#
# Evalúa eficiencia versus escala.
#
# ### Planeación
#
# | Reto | Tablas | Métrica principal | Interpretación esperada |
# |---|---|---|---|
# | | | | |

# %% [markdown]
# ### Espacio de trabajo del estudiante
#
# **Mi interpretación de la consigna:**
#
# **Mi procedimiento / fórmula / consulta:**
#
# **Resultado obtenido:**
#
# **Conclusión breve:**

# %% [markdown]
# ## Errores frecuentes y cómo leerlos
#
# | Error frecuente | Qué significa | Cómo corregir |
# |---|---|---|
# | `HTTP Error 404` | El archivo no existe en la URL raw de GitHub. | Revisa nombre exacto, prefijo `webinar03_` y ubicación `/datasets`. |
# | `Catalog Error: Table ... does not exist` | La tabla no fue creada en DuckDB. | Ejecuta de nuevo la celda de setup. |
# | `Binder Error: column must appear in the GROUP BY` | Seleccionaste una columna no agregada que no está en el `GROUP BY`. | Agrégala al `GROUP BY` o usa una función agregada. |
# | `Referenced table alias not found` | Usaste un alias que no existe. | Revisa el alias declarado en `FROM` o `JOIN`. |
# | `Parser Error` | Problema de sintaxis. | Revisa comas, paréntesis, comillas y punto y coma. |
# | Resultado duplicado o inflado | El `JOIN` multiplicó filas. | Revisa llaves de unión y usa `COUNT(DISTINCT ...)` cuando corresponda. |
#
# La depuración también es parte del aprendizaje de SQL. No memorices errores; aprende a leerlos.

# %% [markdown]
# ## Preguntas de validación de conocimiento
#
# | Pregunta | Mi respuesta / apuntes |
# |---|---|
# | ¿Qué tabla contiene una fila por orden? |   |
# | ¿Qué tabla contiene una fila por producto comprado dentro de una orden? |   |
# | ¿Qué tabla usarías para conocer el monto pagado? |   |
# | ¿Qué tabla permite clasificar productos por categoría? |   |
# | ¿Qué llave une `order_items` con `products`? |   |
# | ¿Qué hace `COUNT(DISTINCT o.order_id)`? |   |
# | ¿Para qué sirve `CASE`? |   |
# | ¿Por qué filtrar `cancelled` y `refunded` en KPIs operativos? |   |
# | ¿Qué representa `gross_profit`? |   |
# | ¿Por qué promo vs no promo no demuestra causalidad? |   |

# %% [markdown]
# ### Mis respuestas de validación
#
# 1.
# 2.
# 3.
#
# **Tema que necesito repasar:**

# %% [markdown]
# ## Cierre
#
# En esta práctica usamos SQL para pasar de tablas Parquet en GitHub a indicadores de negocio.
#
# Patrón que debes dominar:
#
# ```text
# Pregunta de negocio → tablas necesarias → llaves de unión → cálculo → agrupación → interpretación
# ```
#
# ### Checklist final
#
# - ☐ Ejecuté el setup en Google Colab.
# - ☐ Validé que todas las tablas cargaran.
# - ☐ Resolví consultas con `JOIN`.
# - ☐ Usé `GROUP BY` para calcular KPIs.
# - ☐ Usé `CASE` para crear segmentos analíticos.
# - ☐ Calculé revenue, ticket, margen y ROI.
# - ☐ Interpreté al menos un resultado en lenguaje de negocio.
# - ☐ Identifiqué al menos un error común de SQL.
#
# ### Takeaways
#
# - La práctica de SQL empieza validando datos, no escribiendo el KPI más complejo.
# - Las llaves de unión determinan si el resultado es confiable.
# - `COUNT(DISTINCT ...)` ayuda a evitar conteos inflados.
# - `GROUP BY` convierte datos transaccionales en métricas.
# - `CASE` permite crear categorías analíticas desde reglas de negocio.
# - Las promociones deben interpretarse con cuidado: comparación no es causalidad.
# - Un resultado útil combina cálculo correcto e interpretación clara.
#
# ### Canales de apoyo
#
# - `DATA-CO-LEARNING`: horarios de atención para dudas puntuales.
# - `DA_CONSULTA`: preguntas sobre contenido o proyecto usando el tag correspondiente.
# - `SPRINT FOCUS`: sesiones extra para profundizar en temas del sprint.
# - `SESIONES 1:1`: tutorías individuales agendadas con antelación.
# - Canal de Discord de la cohorte: espacio para compartir recursos, dudas y aprendizajes.
