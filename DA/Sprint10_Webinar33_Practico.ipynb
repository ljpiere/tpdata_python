# %% [markdown]
# # Sprint 10 · Webinar 31 · Proyecto Power BI · Desempeño Comercial 2024–2025 (Clase práctica, 100 min)
# **Proyecto:** Dashboard de desempeño comercial (Andes Retail Group)
# **Herramienta:** Power BI Desktop (gratis) + publicación/entrega (opciones gratuitas)
#
# > En esta sesión vas a **resolver el proyecto** (llenando la guía del estudiante) y luego construirás el **dashboard en Power BI** con 2 vistas: **Overview** y **Detalle**.

# %% [markdown]
# ## Fecha
# > Completa aquí la fecha de la sesión.

# %% [markdown]
# ## Objetivo de la sesión (100 min)
#
# Al finalizar esta clase, podrás:
#
# 1. Completar la guía del proyecto (versión estudiante) con una **planeación** clara y una **narrativa SCQA**.
# 2. Importar un archivo **Excel** en Power BI Desktop y **explorar** la estructura del dataset.
# 3. Transformar datos con **Power Query** (tipos, fechas con *locale*, columna condicional, perfil de columnas).
# 4. Crear **medidas DAX básicas** para KPIs (Ingresos, Ganancia, Margen, Pedidos, Clientes, Ticket promedio).
# 5. Construir un dashboard con 2 páginas:
#    - **Overview:** evolución + comparaciones clave
#    - **Detalle:** explicación/diagnóstico de cambios en ingresos
# 6. Agregar **interactividad** (segmentadores) y dejar el archivo listo para entrega/exportación.

# %% [markdown]
# ## Agenda sugerida (100 minutos)
#
# 1. Contexto del proyecto + reglas de evaluación (5 min)
# 2. **Actividad 0 (breakout rooms):** preguntas de negocio + KPIs + boceto (10 min)
# 3. Ejercicio 1: dataset del proyecto (Excel) + diccionario + grano (10 min)
# 4. Ejercicio 2: **Paso 1** (proyecto) · Conexión y exploración en Power BI (10 min)
# 5. Ejercicio 3: **Paso 2** (proyecto) · Power Query (locale, tipos, Nivel_Venta, perfil) (18 min)
# 6. Ejercicio 4: **Paso 3** (proyecto) · Planificación de las 2 vistas (12 min)
# 7. Ejercicio 5: **Paso 4** (proyecto) · Construir Vista Overview (18 min)
# 8. Ejercicio 6: **Paso 4** (proyecto) · Construir Vista Detalle + segmentadores (12 min)
# 9. Ejercicio 7: **Paso 5 + Entrega** · Narrativa SCQA + mensaje Slack + exportar/publicar (5 min)
# 10. Cierre + checklist de entrega (0–5 min)
#
# > Si te falta tiempo: prioriza **Power Query + Overview + 2 segmentadores + narrativa**.

# %% [markdown]
# ## Materiales (lo que vas a usar hoy)
#
# ### Archivos del proyecto (los que te entregaron)
# - `S10_Proyecto_VersionEstudiante_PowerBI_Desempeno_Comercial.ipynb` (plantilla del estudiante)
# - `S10_Proyecto_Solucion_PowerBI_Desempeno_Comercial.ipynb` (ejemplo de solución textual)
#
# 📌 *En clase vamos a completar la plantilla del estudiante usando el ejemplo como referencia, y luego lo llevamos a Power BI.*
#
# ### Dataset (Excel)
# Usaremos un archivo Excel con ventas **2024–2025** (sintético, realista) con columnas como:
# - `Fecha_pedido`, `Ingresos`, `Costo`, `Ganancia`
# - `Pais`, `Region`, `Ciudad`
# - `Segmento_Cliente`, `Categoria_Producto`, `Producto`, `Canal`, `Campaña`, `Estación`
#
# ✅ Este archivo está pensado para que practiques:
# - cambiar **tipos de datos**
# - convertir fecha con **locale**
# - crear una columna condicional `Nivel_Venta`

# %% [markdown]
# ## Dataset de la sesión (sintético) — Andes Retail Group
#
# ### ¿Qué representa una fila (grano)?
# **1 fila = 1 transacción** (un producto vendido dentro de un pedido).
# En este dataset simplificado, `ID_Pedido` ya identifica esa transacción.
#
# ### Diccionario rápido de columnas (para principiantes)
# - `ID_Pedido`: identificador de la transacción (texto)
# - `Fecha_pedido`: fecha del pedido (viene como **texto** `dd/mm/yyyy` para practicar *locale*)
# - `ID_Cliente`: cliente (texto)
# - `Ingresos`: monto vendido (puede venir como número o texto → lo arreglamos)
# - `Costo`, `Ganancia`: costos y ganancia (número)
# - `Unidades`: unidades (puede venir mezclado texto/número → lo arreglamos)
# - `Pais`, `Region`, `Ciudad`: ubicación
# - `Segmento_Cliente`: Premium / Estandar / Basico
# - `Categoria_Producto`, `Producto`: producto
# - `Canal`: Online / Tienda
# - `Campaña`: campaña comercial
# - `Estación`: Verano / Otoño / Invierno / Primavera
#
# > Importante: si Power BI detecta mal un tipo de dato, **no lo ignores**. Primero se corrige en Power Query.

# %% [markdown]
# ---
#
# # Actividad 0 · Boceto rápido del dashboard (10 min)
#
# ### Objetivo
# Pensar el dashboard como una **historia**: *qué pasó → por qué → qué haría el negocio*.
#
# ### Instrucciones (breakout rooms, 3–4 personas)
#
# 1) Lean el caso:
# **“Andes Retail Group quiere entender cómo evolucionaron los ingresos 2024–2025 y por qué cambian por meses/estaciones.”**
#
# 2) Definan (en 6–8 minutos):
# - **Audiencia:** ¿quién lo verá? (ej. Director Comercial)
# - **Pregunta Overview:** 1 sola
# - **3–4 KPIs Overview:** (ej. Ingresos, Ganancia, Margen, Pedidos)
# - **2 preguntas Detalle:** (ej. “¿qué países o categorías explican la caída?”)
# - **Segmentadores mínimos:** 2 (ej. Año, País)
#
# 3) Entregable (escríbanlo en 6 líneas):
# - Audiencia: ___________
# - Pregunta Overview: ___________
# - KPIs: ___________
# - Preguntas Detalle: ___________
# - Segmentadores: ___________
#
# ### Pista
# Si no sabes qué poner, copia esta estructura:
# - Overview = *evolución + comparación*
# - Detalle = *diagnóstico (estacionalidad, país, categoría, canal)*
#
# ### Solución (ejemplo)
# - Audiencia: Director/a Comercial
# - Pregunta Overview: “¿Cómo evolucionó el ingreso total entre 2024 y 2025 y qué mercados lo impulsan?”
# - KPIs: Ingresos, Ganancia, Margen, #Pedidos
# - Preguntas Detalle: “¿La caída se explica por estacionalidad?” + “¿Qué categoría/segmento aporta menos en meses críticos?”
# - Segmentadores: Año, País (y opcional: Categoría)

# %% [markdown]
# # Ejercicio 1 · Crear/obtener el Excel del proyecto + entender estructura (10 min)
#
# ### Fundamentación teórica (muy corta)
# Un dashboard es tan confiable como su dataset. Antes de graficar:
# 1) confirmas **grano** (qué es 1 fila)
# 2) revisas **tipos**
# 3) verificas **calidad** (nulos, valores raros)
#
# ### Qué haremos
# 1) Generar el archivo Excel (si ya lo tienes, puedes saltar la generación).
# 2) Abrir una vista previa para confirmar columnas.
# 3) Identificar 5 columnas clave para el dashboard.
#
# ### Pista
# En este proyecto, las columnas “estrella” son:
# - tiempo: `Fecha_pedido`
# - métrica: `Ingresos` (y `Ganancia`)
# - segmentación: `Pais`, `Categoria_Producto`, `Segmento_Cliente`

# %%
# Si ya tienes el Excel del proyecto, puedes saltarte esta celda.
import pandas as pd, numpy as np, random, datetime as dt

random.seed(42)
np.random.seed(42)

def season_es(date):
    m = date.month
    if m in [12,1,2]:
        return "Verano"
    if m in [3,4,5]:
        return "Otoño"
    if m in [6,7,8]:
        return "Invierno"
    return "Primavera"

countries = {
    "Peru": {"cities": [("Lima","Costa"),("Arequipa","Sierra"),("Trujillo","Costa"),("Cusco","Sierra")], "weight": 0.42},
    "Colombia": {"cities": [("Bogotá","Andina"),("Medellín","Andina"),("Cali","Pacífico"),("Barranquilla","Caribe")], "weight": 0.28},
    "Chile": {"cities": [("Santiago","Centro"),("Valparaíso","Centro"),("Concepción","Sur"),("Antofagasta","Norte")], "weight": 0.18},
    "Mexico": {"cities": [("CDMX","Centro"),("Guadalajara","Occidente"),("Monterrey","Norte"),("Puebla","Centro")], "weight": 0.12},
}
country_list = list(countries.keys())
country_weights = np.array([countries[c]["weight"] for c in country_list])
country_weights = country_weights / country_weights.sum()

segments = ["Premium","Estandar","Basico"]
segment_w = [0.25,0.5,0.25]

categories = {
    "Electronica": {"products": [("Audifonos",120),("Smartwatch",180),("Tablet",350),("Parlante",140)]},
    "Hogar": {"products": [("Licuadora",90),("Aspiradora",220),("Cafetera",130),("Lampara",60)]},
    "Moda": {"products": [("Zapatillas",110),("Chaqueta",150),("Jeans",80),("Bolso",95)]},
    "Deportes": {"products": [("Bicicleta",520),("Guantes",35),("Cuerda",18),("Mancuernas",65)]},
}
channels = ["Online","Tienda"]
channel_w = [0.62,0.38]
campaigns = ["Siempre activo","Back to School","Black Friday","Navidad","Temporada baja"]
campaign_w = [0.55,0.1,0.12,0.13,0.1]

def make_orders(n_rows=9000):
    start = dt.date(2024,1,1)
    end = dt.date(2025,12,31)
    days = (end-start).days + 1
    dates = [start + dt.timedelta(days=int(np.random.randint(0, days))) for _ in range(n_rows)]
    out = []
    for i, d in enumerate(dates):
        country = np.random.choice(country_list, p=country_weights)
        city, region = random.choice(countries[country]["cities"])
        seg = np.random.choice(segments, p=segment_w)
        cat = random.choice(list(categories.keys()))
        prod, base_price = random.choice(categories[cat]["products"])
        channel = np.random.choice(channels, p=channel_w)
        campaign = np.random.choice(campaigns, p=campaign_w)
        units = int(np.random.choice([1,1,1,2,2,3,4,5], p=[0.32,0.14,0.10,0.18,0.10,0.08,0.05,0.03]))

        seg_mult = {"Premium":1.15,"Estandar":1.0,"Basico":0.9}[seg]
        country_mult = {"Peru":1.08,"Colombia":1.0,"Chile":1.05,"Mexico":0.98}[country]
        chan_mult = {"Online":1.0,"Tienda":1.03}[channel]

        season = season_es(d)
        season_mult = {"Verano":1.05,"Otoño":1.0,"Invierno":0.78,"Primavera":1.02}[season]

        disc_base = {"Siempre activo":0.05,"Back to School":0.08,"Black Friday":0.20,"Navidad":0.12,"Temporada baja":0.10}[campaign]
        disc_jitter = float(np.clip(np.random.normal(0, 0.03), -0.05, 0.08))
        discount = float(np.clip(disc_base + disc_jitter, 0, 0.35))

        price = base_price * seg_mult * country_mult * chan_mult * season_mult
        ingresos = units * price * (1 - discount)
        ingresos *= float(np.clip(np.random.normal(1, 0.06), 0.85, 1.18))

        cost_ratio = {"Electronica":0.70,"Hogar":0.66,"Moda":0.62,"Deportes":0.68}[cat] + float(np.clip(np.random.normal(0, 0.03), -0.05, 0.05))
        costo = ingresos * cost_ratio
        ganancia = ingresos - costo

        # nulos y tipos mixtos
        if np.random.rand() < 0.015:
            discount = np.nan
        unidades_val = str(units) if np.random.rand() < 0.35 else units
        ingresos_val = f"{ingresos:.2f}" if np.random.rand() < 0.25 else ingresos

        out.append({
            "ID_Pedido": f"ORD-{d.year}{d.month:02d}-{i:05d}",
            "Fecha_pedido": d.strftime("%d/%m/%Y"),   # texto dd/mm/yyyy (para practicar locale)
            "ID_Cliente": f"CLI-{np.random.randint(1000,9999)}",
            "Segmento_Cliente": seg,
            "Pais": country,
            "Region": region,
            "Ciudad": city,
            "Categoria_Producto": cat,
            "Producto": prod,
            "Canal": channel,
            "Campaña": campaign,
            "Estación": season,
            "Unidades": unidades_val,
            "Descuento_pct": discount,
            "Ingresos": ingresos_val,                 # a veces texto
            "Costo": costo,
            "Ganancia": ganancia
        })
    return pd.DataFrame(out)

df = make_orders(9000)

excel_path = "S10_AndesRetail_Desempeno_Comercial_2024_2025.xlsx"
csv_path = "S10_AndesRetail_Desempeno_Comercial_2024_2025.csv"

df.to_csv(csv_path, index=False, encoding="utf-8")
with pd.ExcelWriter(excel_path, engine="openpyxl") as writer:
    df.to_excel(writer, sheet_name="Ventas", index=False)

print("Listo")
print("Archivo Excel:", excel_path)
print("Archivo CSV:", csv_path)
print("Filas/columnas:", df.shape)

# %%
df.head(10)

# %% [markdown]
# ### Solución (esperada)
# - Ya tienes un Excel llamado `S10_AndesRetail_Desempeno_Comercial_2024_2025.xlsx`.
# - Confirmas que existen columnas: `Fecha_pedido`, `Ingresos`, `Pais`, `Categoria_Producto`, `Segmento_Cliente`.
# - Grano: **1 fila = 1 transacción** (un producto vendido dentro de un pedido).

# %% [markdown]
# # Ejercicio 2 · Paso 1 del proyecto: Conexión y exploración en Power BI (10 min)
#
# ### Fundamentación teórica
# Antes de transformar o graficar, necesitas verificar:
# - **fuente** (Excel correcto)
# - **estructura** (columnas, nombre, grano)
# - **tipos** (fechas y números)
# - **campos clave** (qué segmenta y qué mide)
#
# ### Qué haremos (Power BI Desktop)
# 1) Abrir Power BI Desktop
# 2) **Obtener datos → Excel** → seleccionar el archivo del proyecto
# 3) Elegir la hoja **Ventas**
# 4) Click en **Transformar datos** (NO “Cargar” todavía) para revisar tipos en Power Query
# 5) Identificar:
#    - ¿`Fecha_pedido` quedó como *Texto*?
#    - ¿`Ingresos` quedó como *Texto*?
#    - ¿hay columnas con íconos “ABC” (texto) que deberían ser numéricas?
#
# ### Pista (dónde mirar)
# En Power Query, mira el ícono a la izquierda del nombre de cada columna:
# - 📅 Fecha
# - 123 Número entero
# - 1.2 Número decimal
# - ABC Texto
#
# ### Solución (esperada)
# En el dataset de esta sesión normalmente verás:
# - `Fecha_pedido` como **Texto** (a propósito)
# - `Ingresos` a veces como **Texto**
# - `Unidades` mezclado (texto/número)
#
# No te preocupes: eso se arregla en el Paso 2.

# %% [markdown]
# # Ejercicio 3 · Paso 2 del proyecto: Transformación con Power Query (18 min)
#
# ### Fundamentación teórica
# Power Query es la etapa de **preparación de datos**: aquí aseguras calidad y consistencia.
# Regla de oro: **si el tipo está mal, tus gráficos y medidas se dañan**.
#
# ### Objetivo (lo mínimo requerido por el proyecto)
# 1) Cambiar `Fecha_pedido` a **Fecha** usando *locale* español (LatAm)
# 2) Corregir tipos numéricos (`Ingresos`, `Unidades`, `Costo`, `Ganancia`, `Descuento_pct`)
# 3) Crear columna condicional `Nivel_Venta` basada en `Ingresos`:
#    - `Ingresos` >= 1000 → **Venta Alta**
#    - caso contrario → **Venta Baja**
# 4) Activar **Perfil de columna** (calidad / distribución) y validar
#
# ---
#
# ## Parte A · Fecha con idioma (locale)
#
# ### Pasos (click a click)
# 1) En Power Query selecciona `Fecha_pedido`
# 2) **Tipo de datos** → **Fecha**
# 3) Si sale un error o fechas raras:
#    - **Cambiar tipo** → **Usar configuración regional...**
#    - Tipo: **Fecha**
#    - Configuración regional: **Español (Colombia)** o **Español (Perú)**
#    - Aceptar
#
# ### Pista
# El dataset está en formato **dd/mm/yyyy**. Si lo interpretas como mm/dd/yyyy, te va a cambiar meses/días.
#
# ---
#
# ## Parte B · Tipos numéricos
#
# ### Pasos sugeridos
# - `Ingresos`: **Número decimal**
# - `Costo`: **Número decimal**
# - `Ganancia`: **Número decimal**
# - `Descuento_pct`: **Número decimal**
# - `Unidades`: **Número entero**
#
# Si alguna columna está como texto:
# 1) Selecciónala
# 2) **Transformar → Tipo de datos**
# 3) Revisa si hay **Errores** (si hay errores, filtra para ver qué pasó)
#
# ---
#
# ## Parte C · Columna condicional Nivel_Venta
#
# ### Pasos
# 1) **Agregar columna → Columna condicional**
# 2) Nombre: `Nivel_Venta`
# 3) Regla:
#    - Si `Ingresos` **es mayor o igual que** `1000` → `Venta Alta`
#    - Si no → `Venta Baja`
#
# ---
#
# ## Parte D · Perfil de columna (calidad)
#
# ### Pasos
# 1) Pestaña **Vista**
# 2) Activar:
#    - **Calidad de columna**
#    - **Distribución de columna**
#    - **Perfil de columna**
# 3) Valida:
#    - nulos en `Descuento_pct` (ok, algunos pueden faltar)
#    - valores raros (negativos en ingresos/costo → NO debería)
#
# ### Solución (esperada)
# - `Fecha_pedido` debe quedar como **Fecha**
# - `Ingresos` debe ser **Decimal**
# - `Unidades` debe ser **Entero**
# - Nueva columna `Nivel_Venta` creada
# - Perfil de columnas activo y revisado
# - Finalmente: **Cerrar y aplicar**

# %% [markdown]
# # Ejercicio 4 · Paso 3 del proyecto: Diseño y planificación del dashboard (12 min)
#
# ### Fundamentación teórica
# Un dashboard claro responde:
# - **una pregunta principal** por página
# - con **pocos KPIs** y visuales que no compiten
#
# ### Qué haremos
# Completar la sección **“Diseño y planificación”** en el notebook del proyecto (versión estudiante):
# - Vista **Overview**: evolución 2024–2025 + comparaciones
# - Vista **Detalle**: diagnóstico (estacionalidad + segmentos)
#
# ### Pista
# Piensa así:
# - Overview = “**qué pasó**”
# - Detalle = “**por qué pasó**”
#
# ---
#
# ## Solución (ejemplo para copiar y adaptar)
#
# ### Vista Overview — ¿Cómo ha evolucionado el ingreso total entre 2024 y 2025?
#
# **KPIs (3–4)**
# - **Ingresos:** para ver tamaño del negocio
# - **Ganancia:** para ver rentabilidad en dinero
# - **Margen:** para comparar rentabilidad sin sesgo de tamaño
# - **#Pedidos** (o Unidades): para separar precio vs volumen
#
# **Gráficos**
# - **Línea (tiempo):** `Ingresos` por `Fecha_pedido` (mes)
# - **Barras (geografía):** `Ingresos` por `Pais` (o `Region`)
# - **Barras (mix comercial):** `Ingresos` por `Segmento_Cliente` y/o `Categoria_Producto`
#
# **Jerarquía visual**
# 1) Título + contexto (2024–2025)
# 2) KPIs arriba (fila superior)
# 3) Comparaciones (País / Segmento / Categoría)
# 4) Tendencia mensual (línea) como “columna vertebral” del Overview
#
# **Segmentadores**
# - `Año`
# - `Mes` (o rango por `Fecha_pedido`)
#
# ---
#
# ### Vista Detalle — ¿Por qué suben/bajan los ingresos?
#
# **Gráficos**
# - Barras: `Ingresos` por `Estación` (estacionalidad)
# - Barras/columnas: `Ingresos` por `Categoria_Producto` (filtrable por estación)
# - Barras: `Ingresos` por `Segmento_Cliente` o `Canal`
# - Tabla (4–6 columnas) con:
#   - `#Pedidos` (DISTINCTCOUNT)
#   - `#Clientes` (DISTINCTCOUNT)
#   - `Ingresos`
#   - `Ganancia`
#   - `Margen`
#
# **Segmentadores (mínimo 2)**
# - Rango `Fecha_pedido`
# - `Pais` (o `Categoria_Producto`)

# %% [markdown]
# # Ejercicio 5 · Paso 4 del proyecto: Construir Vista 1 (Overview Ejecutivo) (18 min)
#
# ### Fundamentación teórica
# Una vista Overview normalmente combina:
# - **KPIs** (qué tan grande / rentable)
# - **tendencia** (cómo cambia en el tiempo)
# - **comparación** (qué segmentos explican el total)
#
# ---
#
# ## Parte A · Crear medidas DAX (KPIs)
#
# ### Medidas (recomendadas para principiantes)
# En Power BI: **Modelado → Nueva medida**
#
# 1) **Ingresos Total**
# ```DAX
# Ingresos Total = SUM(Ventas[Ingresos])
# ```
#
# 2) **Ganancia Total**
# ```DAX
# Ganancia Total = SUM(Ventas[Ganancia])
# ```
#
# 3) **Margen**
# ```DAX
# Margen = DIVIDE([Ganancia Total], [Ingresos Total])
# ```
#
# 4) **Pedidos**
# ```DAX
# Pedidos = DISTINCTCOUNT(Ventas[ID_Pedido])
# ```
#
# 5) *(Opcional)* **Clientes**
# ```DAX
# Clientes = DISTINCTCOUNT(Ventas[ID_Cliente])
# ```
#
# 6) *(Opcional)* **Ticket Promedio**
# ```DAX
# Ticket Promedio = DIVIDE([Ingresos Total], [Pedidos])
# ```
#
# ### Pista
# Si `Ingresos` te da error en SUM, es porque aún no quedó numérico.
# Vuelve a Power Query y revisa el tipo.
#
# ---
#
# ## Parte B · Visuales del Overview (layout sugerido)
#
# ### 1) Tarjetas KPI (fila superior)
# - Ingresos Total
# - Ganancia Total
# - Margen
# - Pedidos (o Clientes)
#
# ### 2) Línea de tendencia (columna vertebral)
# - Visual: **Gráfico de líneas**
# - Eje X: `Fecha_pedido` (nivel Mes)
# - Valores: `Ingresos Total`
#
# ### 3) Comparación geográfica
# - Visual: **Barras**
# - Eje: `Pais` (o `Region`)
# - Valores: `Ingresos Total`
# - Orden: descendente
#
# ### 4) Mix comercial
# - Visual: **Barras**
# - Eje: `Categoria_Producto` o `Segmento_Cliente`
# - Valores: `Ingresos Total`
#
# ### Segmentadores (mínimo)
# - `Año` (puede ser “Jerarquía de fecha” o columna auxiliar)
# - `Mes` (opcional)
#
# ---
#
# ## Solución (esperada)
# - Página **Overview** con 3–4 KPI cards
# - Línea mensual de ingresos
# - 2 comparaciones (País y Categoría/Segmento)
# - Segmentadores visibles y bien ubicados (sin tapar gráficos)

# %% [markdown]
# # Ejercicio 6 · Paso 4 del proyecto: Construir Vista 2 (Análisis Detallado) + segmentadores (12 min)
#
# ### Fundamentación teórica
# La vista Detalle responde “**por qué**”.
# Debe permitir filtrar y aislar causas: estacionalidad, país, categoría, canal.
#
# ---
#
# ## Parte A · Visuales recomendados
#
# ### 1) Estacionalidad
# - Visual: **Barras**
# - Eje: `Estación`
# - Valores: `Ingresos Total`
# - (Opcional) Leyenda: `Pais` o `Categoria_Producto` si no se vuelve ilegible
#
# ### 2) ¿Qué categoría/segmento cae más?
# - Visual: **Columnas** o **barras**
# - Eje: `Categoria_Producto`
# - Valores: `Ingresos Total`
# - Agrega un segmentador para `Estación` o `Fecha_pedido`
#
# ### 3) Tabla de diagnóstico (4–6 campos)
# - `Pais`
# - `Categoria_Producto`
# - `Pedidos`
# - `Clientes`
# - `Ingresos Total`
# - `Margen`
#
# 📌 Consejo: usa formato de número (moneda) y porcentaje.
#
# ---
#
# ## Parte B · Segmentadores (mínimo 2)
#
# ### Recomendados
# - `Fecha_pedido` (tipo “Entre” / rango)
# - `Pais`
# - (Opcional) `Categoria_Producto`, `Segmento_Cliente`, `Canal`
#
# ### Pista (principiante)
# Si los segmentadores “ensucian” la vista:
# - ponlos en una columna izquierda (fija)
# - y deja los gráficos en un grid a la derecha
#
# ---
#
# ## Solución (esperada)
# - Página **Detalle** con:
#   - barras por `Estación`
#   - comparación por categoría/segmento/canal
#   - tabla de diagnóstico
# - 2 segmentadores funcionando (fecha + país o categoría)

# %% [markdown]
# # Ejercicio 7 · Paso 5 + Entrega final: narrativa SCQA + mensaje Slack + exportar/publicar (5 min)
#
# ### Fundamentación teórica
# El dashboard sin narrativa es solo “gráficos bonitos”.
# La narrativa ejecutiva traduce datos en **decisión**.
#
# ---
#
# ## Parte A · SCQA (Situación–Complicación–Pregunta–Respuesta)
#
# ### Plantilla (para copiar)
# **S (Situación):** qué se observa en general (overview)
# **C (Complicación):** qué problema/cambio llama la atención
# **Q (Pregunta):** qué quieres explicar
# **A (Respuesta):** explicación basada en evidencia + acción recomendada
#
# ### Ejemplo (basado en este dataset sintético)
# **S:** 2024–2025 muestra ingresos sólidos, con **Perú** liderando en facturación.
# **C:** Se observa una caída a mitad de año.
# **Q:** ¿Por qué disminuyen los ingresos en esos meses?
# **A:** Hay un patrón estacional: **Invierno** presenta el menor ingreso. Recomendación: campañas específicas en temporada baja y foco en categorías con mayor caída.
#
# ---
#
# ## Parte B · Mensaje asincrónico estilo Slack
#
# **Ejemplo**
# > **📊 Actualización desempeño comercial**
# > Equipo, el análisis 2024–2025 muestra estacionalidad: los ingresos se concentran en **Verano** y caen en **Invierno**, impactando categorías clave.
# > **Acción:** reforzar campañas en temporada baja y ajustar planificación comercial por estación/mes.
#
# ---
#
# ## Parte C · Entrega (elige 1 opción)
# - Exportar/compartir `.pbix` (OneDrive/Drive)
# - Publicar (si lo permite tu entorno) y compartir link
# - Confirmar carga en plataforma según el screencast
#
# ### Checklist final (rápido)
# - [ ] Tipos de datos correctos (Fecha y números)
# - [ ] Columna `Nivel_Venta` creada
# - [ ] Overview: KPI + tendencia + comparaciones
# - [ ] Detalle: estacionalidad + tabla + filtros
# - [ ] Narrativa SCQA + mensaje Slack listos
#
# ---
# # Cierre y Takeaways (0–5 min)
#
# ## Cierre
# **Kahoot de repaso (5 min)**
# - Aplicamos todo lo aprendido: Análisis de negocio + Diseño de un dashboard.
# - Interpretamos resultados para dar recomendaciones de negocio.
#
# **Reflexión:**
# - ¿Qué elementos del dashboard resaltas cómo más relevantes para la toma de decisiones?
# - ¿Cómo complementarias la generación de un dashboard con lo visto en los sprint anteriores?
#
# ## Q&A y próximos pasos
#
# 1) Primero **calidad** (Power Query), luego **visualización**.
# 2) Overview responde **qué pasó**; Detalle responde **por qué**.
# 3) Menos visuales, más claridad: 3–5 gráficos bien elegidos.
# 4) Siempre termina con **recomendación accionable**.
