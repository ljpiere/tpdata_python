# %% [markdown]
# # Sprint 12 · Webinar 37 · Proyecto Final RappiPlus · Student Version
# **Tema:** Recorrido del Proyecto Final — de datos a decisiones de negocio
#
# **Programa:** Data Analytics
# **Sprint:** 12
# **Duración sugerida:** 40 minutos
# **Modalidad:** Teórica guiada con participación activa
#
# ### ¿Cómo usar este cuaderno?
# Este notebook está diseñado para que tomes apuntes, respondas preguntas clave y construyas tu hoja de ruta antes de resolver el proyecto.
#
# - Usa los bloques para registrar ideas, dudas y decisiones.
# - Completa los espacios en blanco con tus propias palabras.
# - Marca los checkpoints cuando sientas que entiendes cada paso.
# - Este cuaderno **no resuelve el proyecto**: te ayuda a prepararte para resolverlo mejor.

# %% [markdown]
# ## Fecha
#
# Completa la información de la sesión:
#
# - **Fecha:** `____ / ____ / 2026`
# - **Instructor/a:** `____________________________`
# - **Grupo / Cohorte:** `____________________________`
# - **Tema central:** `Proyecto Final RappiPlus`

# %% [markdown]
# ## Objetivos de la sesión
#
# Al finalizar esta sesión, deberías poder:
#
# 1. Explicar el **contexto de negocio** del proyecto RappiPlus.
# 2. Identificar los **6 pasos del proyecto** y el propósito de cada uno.
# 3. Reconocer qué datasets usarás y qué aporta cada fuente.
# 4. Anticipar qué análisis, métricas y entregables se esperan.
# 5. Preparar un plan personal para resolver el proyecto de forma ordenada.
#
# ### Antes de empezar
# Escribe con tus palabras:
#
# - **¿Qué esperas aprender hoy?**
#   `_______________________________________________________________`
#
# - **¿Qué parte del proyecto crees que será más difícil para ti?**
#   `_______________________________________________________________`

# %% [markdown]
# ## Agenda sugerida (40 minutos)
#
# | Tiempo | Bloque | Contenido | Lo entendí / dudas |
# |---:|---|---|---|
# | 0–5 | Contexto | Objetivo de negocio de RappiPlus | `__` |
# | 5–10 | Datasets | Fuentes de datos y relaciones | `__` |
# | 10–15 | Paso 1 | Calidad de datos con Python | `__` |
# | 15–20 | Paso 2 | Rentabilidad con Python | `__` |
# | 20–25 | Paso 3 | Funnel con SQL | `__` |
# | 25–30 | Paso 4 | Cohortes con SQL | `__` |
# | 30–35 | Paso 5 | Test A/B con Python | `__` |
# | 35–38 | Paso 6 | Dashboard y comunicación | `__` |
# | 38–40 | Cierre | Hoja de ruta final | `__` |
#
# ### Meta personal
# Hoy quiero salir de clase teniendo claro:
# `_______________________________________________________________`

# %% [markdown]
# ---
#
# # Bloque 1 · Contexto del proyecto (5 min) 🎯
#
# ## ¿Qué entiendes por RappiPlus?
# Lee o escucha la explicación del docente y luego completa:
#
# - **RappiPlus es:**
#   `_______________________________________________________________`
#
# - **El objetivo de negocio de una suscripción como esta podría ser:**
#   `_______________________________________________________________`
#
# - **¿Por qué una empresa necesita analizar si la suscripción funciona o no?**
#   `_______________________________________________________________`
#
# ## Preguntas de negocio
# Completa la tabla con una posible interpretación:
#
# | # | Pregunta de negocio | ¿Qué crees que busca entender el negocio? |
# |---|---|---|
# | 1 | ¿El servicio genera valor? | `__________________________` |
# | 2 | ¿Los usuarios compran más? | `__________________________` |
# | 3 | ¿Hay etapas donde abandonan? | `__________________________` |
# | 4 | ¿Los usuarios regresan? | `__________________________` |
# | 5 | ¿Un cambio de producto mejora resultados? | `__________________________` |
#
# > **Checkpoint**
# > El problema central del proyecto, en una sola frase, es:
# > `_______________________________________________________________`

# %% [markdown]
# ## Flujo del proyecto — visión general
#
# Observa el flujo y completa con tus palabras qué ocurre en cada etapa.
#
# ```text
# Datos crudos → Limpieza → KPIs → Funnel → Cohortes → A/B test → Dashboard → Recomendación
# ```
#
# ### Completa la ruta de trabajo
#
# | Paso | ¿Qué se hace? | ¿Qué sale de ese paso? |
# |---|---|---|
# | Paso 1 | `__________________________` | `__________________________` |
# | Paso 2 | `__________________________` | `__________________________` |
# | Paso 3 | `__________________________` | `__________________________` |
# | Paso 4 | `__________________________` | `__________________________` |
# | Paso 5 | `__________________________` | `__________________________` |
# | Paso 6 | `__________________________` | `__________________________` |
#
# ### Reflexión
# - **¿Qué pasos dependen claramente de pasos anteriores?**
#   `_______________________________________________________________`
#
# - **¿Cuál paso te parece más “de negocio” y cuál más “técnico”?**
#   `_______________________________________________________________`

# %% [markdown]
# ---
#
# # Bloque 2 · Los datasets del proyecto (5 min) 📁
#
# ## Fuentes de datos — panorama general
#
# Completa esta tabla durante la explicación del docente.
#
# ### Archivos CSV
#
# | Dataset | ¿Qué representa? | Columnas que esperas encontrar | ¿En qué parte del proyecto se usa? |
# |---|---|---|---|
# | `rappiplus_orders_raw.csv` | `________________` | `________________` | `________________` |
# | `rappiplus_catalog_raw.csv` | `________________` | `________________` | `________________` |
# | `rappiplus_marketing_raw.csv` | `________________` | `________________` | `________________` |
#
# ### Tablas SQL
#
# | Tabla | ¿Qué representa? | Campo clave | ¿En qué análisis ayuda? |
# |---|---|---|---|
# | `events` | `________________` | `________________` | `________________` |
# | `users` | `________________` | `________________` | `________________` |
# | `user_activity` | `________________` | `________________` | `________________` |

# %% [markdown]
# ## Tips sobre los datasets
#
# ### Registro de observaciones
# Anota aquí ideas importantes que no quieres olvidar:
#
# - **Ruta o forma de carga de los CSVs:**
#   `_______________________________________________________________`
#
# - **Campos que podrían requerir limpieza:**
#   `_______________________________________________________________`
#
# - **Posibles relaciones entre tablas/datasets:**
#   `_______________________________________________________________`
#
# ### Mini ejercicio
# Relaciona cada necesidad con la fuente que probablemente usarías:
#
# | Necesidad | Fuente que usarías | ¿Por qué? |
# |---|---|---|
# | Medir ingresos o costos | `______________` | `______________` |
# | Analizar navegación o eventos | `______________` | `______________` |
# | Revisar retención | `______________` | `______________` |
# | Evaluar campañas | `______________` | `______________` |
#
# > **Checkpoint**
# > La diferencia entre trabajar con CSVs y trabajar con tablas SQL, en este proyecto, es:
# > `_______________________________________________________________`

# %% [markdown]
# ---
#
# # Bloque 3 · Paso 1: Preparación y calidad de datos con Python (5 min) 🧹
#
# ## ¿Qué debe ocurrir en este paso?
#
# Escribe con tus palabras qué harías antes de confiar en los datos:
#
# 1. `_______________________________________________________________`
# 2. `_______________________________________________________________`
# 3. `_______________________________________________________________`
#
# ## Checklist de limpieza
# Marca lo que recuerdes que debe revisarse:
#
# - [ ] tipos de datos
# - [ ] nulos
# - [ ] duplicados
# - [ ] formatos de fecha
# - [ ] categorías inconsistentes
# - [ ] valores imposibles
# - [ ] nombres de columnas
# - [ ] otros: `__________________________`
#
# ## Tu criterio
# - **¿Por qué limpiar datos no es un paso opcional?**
#   `_______________________________________________________________`

# %% [markdown]
# ## Tips para el Paso 1
#
# ### Ejercicio guiado
# Completa la siguiente tabla como plan de trabajo:
#
# | Dataset | Qué revisar primero | Problema que podrías encontrar | Cómo lo corregirías |
# |---|---|---|---|
# | Orders | `______________` | `______________` | `______________` |
# | Catalog | `______________` | `______________` | `______________` |
# | Marketing | `______________` | `______________` | `______________` |
#
# ### Preguntas de comprensión
# - **¿Qué método usarías para revisar estructura y tipos?**
#   `_______________________________________________________________`
#
# - **¿Cómo detectarías valores faltantes?**
#   `_______________________________________________________________`
#
# - **¿Qué dejarías documentado al terminar la limpieza?**
#   `_______________________________________________________________`

# %% [markdown]
# ---
#
# # Bloque 4 · Paso 2: Análisis de rentabilidad con Python (5 min) 💰
#
# ## Pregunta central
# ¿Qué significa para ti que un negocio sea rentable?
#
# `_______________________________________________________________`
#
# ## KPIs del paso
# Completa esta tabla con la lógica de cálculo, no necesariamente con código.
#
# | KPI | ¿Cómo se calcularía? | ¿Qué interpreta el negocio? |
# |---|---|---|
# | Revenue total | `________________` | `________________` |
# | Costo total | `________________` | `________________` |
# | Gross profit | `________________` | `________________` |
# | Margen (%) | `________________` | `________________` |
#
# ## Reflexión
# - **¿Por qué no basta con mirar solo revenue?**
#   `_______________________________________________________________`

# %% [markdown]
# ## Tips para el Paso 2
#
# ### Antes de resolver
# Piensa y responde:
#
# - **¿Qué datasets probablemente necesitas unir?**
#   `_______________________________________________________________`
#
# - **¿Qué campo podría servir para unirlos?**
#   `_______________________________________________________________`
#
# - **¿Qué error podría alterar fuertemente el costo total?**
#   `_______________________________________________________________`
#
# ### Interpretación de negocio
# Imagina estos resultados y escribe una posible lectura:
#
# - Revenue alto + margen bajo:
#   `_______________________________________________________________`
#
# - Revenue moderado + margen alto:
#   `_______________________________________________________________`
#
# - Un segmento vende mucho pero deja poca ganancia:
#   `_______________________________________________________________`

# %% [markdown]
# ---
#
# # Bloque 5 · Paso 3: Funnel de conversión con SQL (5 min) 🔄
#
# ## Objetivo del análisis
# Completa:
#
# - Un **funnel de conversión** sirve para:
#   `_______________________________________________________________`
#
# - En un funnel, cada etapa representa:
#   `_______________________________________________________________`
#
# ## Posibles etapas
# Escribe una secuencia lógica de eventos de compra:
#
# `__________________` → `__________________` → `__________________` → `__________________`
#
# ## Tu interpretación
# - **Si una etapa tiene una caída muy fuerte, eso podría indicar:**
#   `_______________________________________________________________`

# %% [markdown]
# ## Tips para el Paso 3
#
# ### Ejercicio guiado
# Completa la tabla del funnel:
#
# | Etapa | Qué representa | Métrica principal |
# |---|---|---|
# | Etapa 1 | `______________` | `______________` |
# | Etapa 2 | `______________` | `______________` |
# | Etapa 3 | `______________` | `______________` |
# | Etapa 4 | `______________` | `______________` |
#
# ### Preguntas clave
# - **¿Por qué usar `COUNT(DISTINCT id_usuario)` y no `COUNT(*)`?**
#   `_______________________________________________________________`
#
# - **¿Qué diferencia hay entre volumen de eventos y volumen de usuarios?**
#   `_______________________________________________________________`
#
# - **¿Qué acción de negocio podrías recomendar si detectas abandono en add_to_cart?**
#   `_______________________________________________________________`

# %% [markdown]
# ---
#
# # Bloque 6 · Paso 4: Retención por cohortes con SQL (5 min) 📊
#
# ## Idea principal
# Explica con tus palabras:
#
# - **Una cohorte es:**
#   `_______________________________________________________________`
#
# - **La retención busca medir:**
#   `_______________________________________________________________`
#
# ## Construcción conceptual
# Ordena mentalmente estos pasos y toma nota:
#
# 1. identificar fecha de registro
# 2. agrupar usuarios en cohortes
# 3. medir actividad posterior
# 4. comparar semanas o meses desde el alta
#
# ### Lo escribo con mis palabras
# `_______________________________________________________________`

# %% [markdown]
# ## Tips para el Paso 4
#
# ### Tabla para completar
#
# | Elemento | ¿Qué papel cumple? |
# |---|---|
# | `users` | `______________________________` |
# | `user_activity` | `______________________________` |
# | fecha de registro | `______________________________` |
# | semana o período de actividad | `______________________________` |
# | tasa de retención | `______________________________` |
#
# ### Preguntas de análisis
# - **¿Qué te indicaría una cohorte que cae muy rápido?**
#   `_______________________________________________________________`
#
# - **¿Qué te indicaría una cohorte más estable que las demás?**
#   `_______________________________________________________________`
#
# - **¿Por qué este análisis es útil para suscripciones o plataformas?**
#   `_______________________________________________________________`

# %% [markdown]
# ---
#
# # Bloque 7 · Paso 5: Experimentación A/B con Python (5 min) 🧪
#
# ## Contexto del experimento
# Completa:
#
# - **Grupo control:** `____________________________________________`
# - **Grupo tratamiento:** `________________________________________`
# - **Métrica principal del experimento:** `_________________________`
#
# ## Antes de mirar resultados
# Responde:
#
# - **¿Qué tendría que pasar para decir que el cambio funcionó?**
#   `_______________________________________________________________`
#
# - **¿Qué significa que una diferencia sea estadísticamente significativa?**
#   `_______________________________________________________________`

# %% [markdown]
# ## Tips para el Paso 5
#
# ### Registro de ideas
# Completa:
#
# - **Hipótesis nula (H0):**
#   `_______________________________________________________________`
#
# - **Hipótesis alternativa (H1):**
#   `_______________________________________________________________`
#
# - **¿Qué compararías entre ambos grupos?**
#   `_______________________________________________________________`
#
# - **Además del p-value, también revisaría:**
#   `_______________________________________________________________`
#
# ### Criterio de negocio
# Aunque el resultado sea “significativo”, ¿qué más revisarías antes de recomendar implementar el cambio?
#
# `_______________________________________________________________`

# %% [markdown]
# ---
#
# # Bloque 8 · Paso 6: Dashboard y comunicación (3 min) 📈
#
# ## Objetivo del dashboard
# El dashboard debe ayudar a que otra persona entienda el proyecto sin revisar todo el detalle técnico.
#
# ### Completa
# - **Audiencia principal:** `________________________________________`
# - **Decisiones que debería facilitar:** `___________________________`
# - **3 elementos que no deberían faltar:**
#   1. `__________________________`
#   2. `__________________________`
#   3. `__________________________`
#
# ## Diseño y comunicación
# - **¿Qué diferencia hay entre visualizar datos y comunicar una recomendación?**
#   `_______________________________________________________________`

# %% [markdown]
# ## Tips para el Paso 6
#
# ### Checklist de dashboard
# Marca lo que consideres importante:
#
# - [ ] KPIs visibles al inicio
# - [ ] filtros útiles
# - [ ] títulos claros
# - [ ] orden visual
# - [ ] consistencia de métricas
# - [ ] visuales fáciles de interpretar
# - [ ] conclusión o insight principal
# - [ ] fuente de datos limpia
#
# ### Mini ejercicio
# Piensa en una página de dashboard final. ¿Qué visual pondrías para cada objetivo?
#
# | Objetivo | Visual sugerido | ¿Por qué? |
# |---|---|---|
# | Rentabilidad | `______________` | `______________` |
# | Funnel | `______________` | `______________` |
# | Cohortes | `______________` | `______________` |
# | Experimento A/B | `______________` | `______________` |

# %% [markdown]
# ---
#
# # Cierre y recomendaciones finales (2 min) 🚀
#
# ## Lo más importante que me llevo de esta sesión
#
# Completa cada idea con tus palabras:
#
# 1. **Sin datos limpios no hay análisis confiable porque...**
#    `_______________________________________________________________`
#
# 2. **Un KPI sin interpretación de negocio sirve poco porque...**
#    `_______________________________________________________________`
#
# 3. **El funnel ayuda a detectar...**
#    `_______________________________________________________________`
#
# 4. **Las cohortes permiten entender...**
#    `_______________________________________________________________`
#
# 5. **Un test A/B sirve para decidir...**
#    `_______________________________________________________________`
#
# 6. **El dashboard debe cerrar el proyecto mostrando...**
#    `_______________________________________________________________`

# %% [markdown]
# ## Recomendaciones para completar el proyecto
#
# ### Plan personal de trabajo
#
# | Paso | Qué tan seguro/a me siento (1-5) | Tiempo que creo necesitar | Duda principal |
# |---|---:|---|---|
# | Paso 1 — Calidad de datos | `__` | `________` | `________` |
# | Paso 2 — Rentabilidad | `__` | `________` | `________` |
# | Paso 3 — Funnel | `__` | `________` | `________` |
# | Paso 4 — Cohortes | `__` | `________` | `________` |
# | Paso 5 — A/B test | `__` | `________` | `________` |
# | Paso 6 — Dashboard | `__` | `________` | `________` |
#
# ### Mis próximos pasos
# 1. `_______________________________________________________________`
# 2. `_______________________________________________________________`
# 3. `_______________________________________________________________`

# %% [markdown]
# ## Recursos de apoyo
#
# Completa o ajusta esta lista durante la clase:
#
# - **Notebook del estudiante:** `________________________________________`
# - **Descripción del proyecto / PDF guía:** `___________________________`
# - **Sprints o notebooks previos que me pueden servir:**
#   `_______________________________________________________________`
#
# ### Caja de apoyo personal
# - Tema que necesito repasar en Python: `____________________________`
# - Tema que necesito repasar en SQL: `_______________________________`
# - Tema que necesito repasar en visualización/dashboard: `___________`
#
# > **Autoevaluación final**
# > Hoy termino la sesión con un nivel de claridad de: `1  2  3  4  5`
# > Porque: `___________________________________________________________`

# %% [markdown]
# ---

# %% [markdown]
# ### ¿Necesitas ayuda?
# Recuerda los canales de ayuda que tenemos disponibles:
# - `DATA-CO-LEARNING`: Revisa los horarios de atencion en la guia dele studiante. Recuerda que tenemos horarios de apoyo todos los días para tus dudas puntuales!
# - `DA_CONSULTA`: Uuedes publicar tus preguntas sobre el contenido de la plataforma o el proyecto 24/7. Recuerda que en tu pregunta debes de agregar el tag @Dataconsulta.
# - `SPRINT FOCUS`: Para los Sprints 1 al 5 tenemos sesiones extra donde abordamos temáticas de cada sprint a rpofundidad. Revisa la guia del estudiante para conocer los horarios!
# - `SESIONES 1:1`: Recuerda que puedes agendar sesiones 1:1 con un tutor. Agendalas con antelación y resuelve todas tus dudas, desde temás del proyecto, curso, carrera hasta problemas técnicos.
# - `CANAL DE DISCORD DE COMMUNITY`: Recuerda que tu cohorte tiene un canal especial donde puedes compartir cualquier item interesante que quieras mostrar a tus compañeros de curso.
