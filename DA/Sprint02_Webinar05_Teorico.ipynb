# %% [markdown]
# # Sprint 2 - Webinar 5: Formulación de Preguntas de Negocio y Preparación de Datos en Excel/Sheets
#
# **Dataset base:** `almacen_ventas.xlsx`
#
# ---
#
# > 💬 **Pregunta de entrada:** En el Sprint anterior trabajamos con Taylor Swift. Ahora cambiamos de dominio. ¿Qué preguntas de negocio te imaginarías haciéndole a un dataset de ventas de almacén?
#
# _Escribe 2 preguntas (sin restricciones, lo que se te ocurra):_
#
# 1. _______________________________________________
# 2. _______________________________________________

# %% [markdown]
# ---
# ## Objetivos de Aprendizaje
#
# Completa la columna "en mis palabras" al final de la sesión:
#
# | Objetivo | ¿Lo logré? | En mis palabras (cierre) |
# |---|---|---|
# | Traducir escenarios de negocio en preguntas analíticas claras y métricas medibles | ☐ | |
# | Diferenciar métricas absolutas vs relativas e identificar KPI/OKR y guardrail metrics | ☐ | |
# | Distinguir leading vs lagging indicators y redactar preguntas enfocadas | ☐ | |
# | Preparar y combinar datasets con XLOOKUP/VLOOKUP y limpieza categórica | ☐ | |
# | Resumir datos con SUMIF/SUMIFS/COUNTIF/AVERAGEIF | ☐ | |
# | Usar un LLM para refinar stakeholders, métricas y fórmulas con criterio | ☐ | |
#
# > **Tiempo total:** 85 minutos — trabajamos sobre `almacen_ventas.xlsx`.

# %% [markdown]
# ---
# ## Agenda (85 min)
#
# | Bloque | Tiempo | Contenido |
# |---|---|---|
# | Introducción al contexto analítico | 10 min | Kahoot de activación |
# | Preguntas de negocio y métricas | 25 min | Ejercicios 1–5 |
# | Preparación y exploración del dataset | 25 min | Ejercicios 6–8 |
# | Resumen y ejercicios de cierre | 20 min | Ejercicios 9–12 |
# | Kahoot de repaso + Q&A | 5 min | Cierre |

# %% [markdown]
# ---
# ## 0. Setup
#
# Antes de empezar, verifica:
#
# - ☐ Tengo el archivo `almacen_ventas.xlsx` abierto en Excel o Google Sheets.
#
# **Exploración inicial rápida (2 min):**
#
# | Pregunta | Tu respuesta |
# |---|---|
# | ¿Cuántas hojas tiene el archivo? | |
# | ¿Cuáles son los nombres de las hojas? | |
# | ¿Cuántas columnas tiene `Raw Data`? | |
# | ¿Qué columnas hay en `Raw Data`? | |
# | ¿Qué columnas hay en `Customers`? | |

# %%
# Celda de demostración del docente — no necesitas ejecutar esto
# Solo observa la estructura del dataset

import pandas as pd
from pathlib import Path

xlsx_path = Path('/mnt/data/almacen_ventas.xlsx')
raw = pd.read_excel(xlsx_path, sheet_name='Raw Data')
customers = pd.read_excel(xlsx_path, sheet_name='Customers')

raw.head(3), customers.head(3)

# %% [markdown]
# ---
# # 1) Preguntas analíticas en un contexto de negocio (10 + 25 min)
#
# ### 1.1 Cómo convertir necesidades del negocio en preguntas analíticas (5 min)
#
# **Idea clave:** una buena pregunta analítica tiene tres elementos. Completa:
#
# | Elemento | ¿Qué significa? | Ejemplo del dataset |
# |---|---|---|
# | Stakeholder | | |
# | Decisión + horizonte temporal | | |
# | Campos disponibles | | |
#
# ---
#
# **Ejercicio 1 (5 min, en parejas):**
# Para cada escenario, completa las tres columnas:
#
# **a) "Necesito saber qué producto impulsar en el próximo mes en la región West."**
#
# | Elemento | Tu respuesta |
# |---|---|
# | Stakeholder | |
# | Pregunta clave (1 línea) | |
# | Campos del dataset que usaría | |
#
# ---
#
# **b) "Quiero entender el desempeño mensual por vendedor."**
#
# | Elemento | Tu respuesta |
# |---|---|
# | Stakeholder | |
# | Pregunta clave (1 línea) | |
# | Campos del dataset que usaría | |
#
# ---
#
# **c) "¿Qué categoría sostiene el crecimiento del trimestre?"**
#
# | Elemento | Tu respuesta |
# |---|---|
# | Stakeholder | |
# | Pregunta clave (1 línea) | |
# | Campos del dataset que usaría | |

# %% [markdown]
# ### 1.2 Métricas correctas para cada pregunta (10 min)
#
# **Completa las definiciones durante la explicación:**
#
# | Concepto | Definición en tus palabras | Ejemplo con el dataset |
# |---|---|---|
# | Métrica absoluta | | |
# | Métrica relativa | | |
# | KPI | | |
# | OKR | | |
# | Guardrail metric | | |
#
# > 💬 ¿Cuál es la diferencia clave entre un KPI y un OKR? Escríbela en una sola oración:
#
# _Tu respuesta:_ _______________________________________________
#
# ---
#
# **Ejercicio 2 (10 min, en Excel/Sheets):**
#
# **Paso 1 — Crear columna `Month` en `Raw Data`:**
#
# | Herramienta | Fórmula | ¿Funcionó? |
# |---|---|---|
# | Excel | `=TEXT([@Date],"mmm-yyyy")` | ☐ |
# | Sheets | `=TEXT(A2,"mmm-yyyy")` | ☐ |
#
# **Paso 2 — Responde con fórmulas:**
#
# 1) Total de ventas por producto (`SUMIF` o `SUMIFS`):
#
# ```
# =SUMIF( _______________ , _______________ , _______________ )
# ```
# Resultado para el producto _______________ : _______________
#
# 2) Promedio de ventas por región (`AVERAGEIF`):
#
# ```
# =AVERAGEIF( _______________ , _______________ , _______________ )
# ```
# Resultado para la región _______________ : _______________
#
# 3) Crecimiento % Mes a Mes (MoM) de `Total_Sales`:
# - Fórmula de crecimiento: `( _______________ - _______________ ) / _______________`
# - Mes de mayor crecimiento encontrado: _______________
# - Mes de mayor caída encontrado: _______________

# %% [markdown]
# ### 1.3 Leading vs. Lagging Indicators (5 min)
#
# **Completa las definiciones:**
#
# | Tipo | ¿Qué hace? | Ejemplo general |
# |---|---|---|
# | **Leading** | _______________ el resultado | visitas al sitio, leads... |
# | **Lagging** | _______________ el resultado | ingresos, margen... |
#
# ---
#
# **Ejercicio 3 (3–5 min):**
# Clasifica cada campo y justifica en 1 oración:
#
# | Campo | Leading / Lagging / Dimensión | Justificación (1 oración) |
# |---|---|---|
# | `Units_Sold` | | |
# | `Total_Sales` | | |
# | `Date` (período consolidado) | | |
# | `Region` | | |
#
# > 💬 ¿Por qué `Region` no es una métrica sino una dimensión? ¿Cómo la usarías para construir indicadores?
#
# _Tu respuesta:_ _______________________________________________

# %% [markdown]
# ### 1.4 Preguntas analíticas enfocadas (3 min)
#
# **Estructura:** `[Métrica]` para `[grupo/segmento]` en `[tiempo]`
#
# | Versión | Ejemplo |
# |---|---|
# | ❌ Vaga | "¿Cómo vamos en ventas?" |
# | ✅ Enfocada | "`Total_Sales` por `Product` en **West** durante **jun-2024** (vs. may-2024)" |
#
# ---
#
# **Ejercicio 4 (5 min):**
# Reescribe cada pregunta vaga al formato `[Métrica] para [grupo] en [tiempo]`:
#
# | Pregunta vaga | Tu versión enfocada |
# |---|---|
# | "Quiero saber qué tan bien vende Sofía." | |
# | "Quiero entender a los clientes." | |
# | "¿Qué región es la mejor?" | |
#
# > 💬 ¿Por qué una pregunta vaga es peligrosa para un analista? (Reflexión rápida — 1 oración)
#
# _Tu respuesta:_ _______________________________________________

# %% [markdown]
# ### 1.5 🤖 IA: usar un LLM para stakeholders y métricas (2 min)
#
# El docente ejecutará este prompt en vivo. Observa y anota:
#
# **Prompt sugerido:**
# > *Tengo un dataset con columnas Date, Region, Product, Units_Sold, Unit_Price, Salesperson, Total_Sales. Soy el Gerente de Ventas. Necesito priorizar presupuesto por región para el próximo trimestre. Sugiere: (1) objetivo y pregunta clave, (2) métricas y cálculos (incluye crecimiento y tasas), (3) qué tablas/resúmenes construirías para decidir.*
#
# **Anota la respuesta del LLM (puntos clave):**
#
# | Elemento | Lo que sugirió el LLM | ¿Lo aceptarías? ¿Por qué? |
# |---|---|---|
# | Objetivo / pregunta clave | | |
# | Métricas sugeridas | | |
# | Tablas/resúmenes propuestos | | |
#
# > 💬 **Discusión:** ¿Qué aceptarías del LLM sin validar? ¿Qué verificarías manualmente y cómo?
#
# _Tu respuesta:_ _______________________________________________

# %% [markdown]
# ---
# # 2) Preparación y exploración del dataset (25 min)
#
# ### 2.1 Explorar un nuevo dataset (5 min)
#
# **Abre la hoja `Customers` y completa:**
#
# | Pregunta | Tu respuesta |
# |---|---|
# | ¿Qué columnas tiene? | |
# | ¿Cuál podría ser la clave para unirla con `Raw Data`? | |
# | ¿Qué es `Customer_Type`? ¿Qué valores tiene? | |
#
# ---
#
# **Ejercicio 5 (5 min):**
# Lista las posibles conexiones entre las dos hojas y qué análisis habilitaría cada una:
#
# | Campo de conexión | ¿Qué análisis nuevo permite? | ¿Qué problema podría haber? |
# |---|---|---|
# | `Region` | | |
# | `Customer_ID` (futuro) | | |
# | `Month` (segmentación) | | |
# | `Customer_Type` (Retail/Wholesale) | | |

# %% [markdown]
# ### 2.2 Combinar dos datasets relacionados (8 min)
#
# **Conceptos clave — completa durante la explicación:**
#
# | Concepto | Definición |
# |---|---|
# | Lookup exacto | |
# | Lookup aproximado | |
# | Tabla de dimensiones | |
# | Tabla transaccional | |
#
# ---
#
# **Ejercicio 6 (8–10 min):**
#
# **Paso 1 — Escribe la fórmula de lookup para traer `Customer_Type` a `Raw Data`:**
#
# | Herramienta | Fórmula (completa los huecos) | ¿Funcionó? |
# |---|---|---|
# | XLOOKUP (Excel/Sheets) | `=XLOOKUP( ___ , Customers!B:B, Customers!C:C, "NoMatch", ___ )` | ☐ |
# | VLOOKUP (alternativa) | `=VLOOKUP( ___ , Customers!B:C, ___ , FALSE)` | ☐ |
#
# **Paso 2 — Verificación de errores:**
# - Fórmula para contar `#N/A`: `=COUNTIF( _______________ , "#N/A")` → Resultado: ___
# - ¿Encontraste errores? → ☐ Sí / ☐ No
#
# **Paso 3 — Introduce un error tipográfico intencional:**
# - Cambié el valor _______________ por _______________ en la celda ___
# - ¿Qué devuelve XLOOKUP ahora? → _______________
# - ¿Por qué ocurre esto? → _______________________________________________
#
# **Paso 4 — Documenta en una hoja `JOIN_DOC`:**
#
# | Campo a documentar | Tu respuesta |
# |---|---|
# | Clave usada para el join | |
# | Cardinalidad (¿cuántos registros por clave?) | |
# | ¿Se requiere exactitud? | |
# | Limitaciones detectadas | |
#
# - ☐ Hoja `JOIN_DOC` creada y completada

# %% [markdown]
# ### 2.3 Organizar el libro para análisis (5 min)
#
# **Buenas prácticas — marca las que ya aplicaste y completa las que faltan:**
#
# | Práctica | ¿Aplicada? | Notas |
# |---|---|---|
# | Renombrar y usar color en tabs (Datos / Dimensiones / Resúmenes / README) | ☐ | |
# | Congelar encabezados, ajustar anchos | ☐ | |
# | Formato de miles y porcentajes | ☐ | |
# | Nombres declarativos en columnas (`Total_Sales`, no "col1") | ☐ | |
# | Validación de datos (`Region` en lista válida) | ☐ | |
# | Helper columns: `Month`, `Quarter`, `Product_Category` | ☐ | |
#
# ---
#
# **Ejercicio 7 (5 min):**
#
# 1. ☐ Renombra las hojas: `Sales_Raw`, `Customers`, `README`, `Cleaned_Data`, `Summary`.
# 2. ☐ Crea validación de datos (lista) para `Region`. ¿Qué valores incluiste? → _______________
# 3. ☐ Crea validación de datos para `Product`. ¿Cuántos valores distintos hay? → _______________
# 4. ☐ En `README`, documenta (anota aquí lo que escribiste):
#
# | Sección del README | Contenido |
# |---|---|
# | Estructura del libro | |
# | Pestañas y su rol | |
# | Convenciones usadas | |

# %% [markdown]
# ### 2.4 Preparar datos categóricos para agrupar (5 min)
#
# **Funciones de limpieza — completa la ficha de cada una:**
#
# | Función | Problema que resuelve | Sintaxis | Cuándo usarla |
# |---|---|---|---|
# | `TRIM` | | `=TRIM( ___ )` | |
# | `PROPER` | | `=PROPER( ___ )` | |
# | `CLEAN` | | `=CLEAN( ___ )` | |
# | `IF + ISBLANK` | | `=IF(ISBLANK( ___ ),"Missing","OK")` | |
#
# ---
#
# **Ejercicio 8 (5 min):**
# Construye la plantilla de limpieza en `Cleaned_Data`.
#
# Diseño de la plantilla (anota los encabezados que usarás):
#
# | Original | Trimmed | Proper | Check | Issue_Flag |
# |---|---|---|---|---|
# | *(referencia a Sales_Raw)* | `=TRIM(...)` | `=PROPER(...)` | `=IF(ISBLANK(...))` | `=IF(... "Invalid Region", "OK")` |
#
# - ☐ Plantilla creada en `Cleaned_Data`
# - ¿Cuántos `Invalid Region` aparecieron? → ___
# - ¿Cuántos `Missing` aparecieron? → ___
#
# > 💬 ¿Por qué referenciamos `Sales_Raw` en lugar de copiar y pegar los valores?
#
# _Tu respuesta:_ _______________________________________________

# %% [markdown]
# ### 2.5 🤖 IA para fórmulas y errores (2 min)
#
# El docente muestra cómo usar un LLM para depurar fórmulas. Observa y completa:
#
# **Prompt de ejemplo:**
# > *Tengo esta fórmula que devuelve #N/A en Excel/Sheets: `=XLOOKUP(C2,Customers!B:B,Customers!C:C)`. Mi objetivo es traer Customer_Type por Region. ¿Qué revisaría y cómo la reescribirías? Dame 2 alternativas y cómo validar el resultado.*
#
# **Lo que sugirió el LLM para diagnosticar el error:**
# _Tu anotación:_ _______________________________________________
#
# **Dos alternativas de fórmula que propuso:**
# 1. _______________________________________________
# 2. _______________________________________________
#
# > 💬 ¿Cuándo es útil pedirle al LLM que depure una fórmula vs. resolverlo tú mismo?
#
# _Tu respuesta:_ _______________________________________________

# %% [markdown]
# ---
# # 3) Resumir datos con funciones y filtros
#
# ### 3.1 Filtrar y explorar patrones (5 min)
#
# **Técnica:** filtros combinados (`Region` + `Month`) para aislar subconjuntos.
#
# **Ejercicio 9 (5 min):**
# Filtra un mes específico y responde:
#
# - Mes que elegí para filtrar: _______________
# - Región filtrada: **South**
# - ¿Qué `Product` tuvo mayor `Total_Sales` en **South** ese mes? → _______________
# - ¿Cómo lo encontraste (orden, filtro visual, otro)? → _______________________________________________
#
# > 💬 ¿Qué limitación tiene este método de "filtrar + ver" comparado con una fórmula?
#
# _Tu respuesta:_ _______________________________________________

# %% [markdown]
# ### 3.2 Funciones de agregación condicional (8 min)
#
# **Diferencia clave — completa:**
#
# | Función | ¿Cuántas condiciones acepta? | Sintaxis básica |
# |---|---|---|
# | `SUMIF` | ___ condición | `=SUMIF( ___ , ___ , ___ )` |
# | `SUMIFS` | ___ condiciones | `=SUMIFS( ___ , ___ , ___ , ___ , ___ )` |
# | `COUNTIF` | ___ condición | `=COUNTIF( ___ , ___ )` |
# | `AVERAGEIF` | ___ condición | `=AVERAGEIF( ___ , ___ , ___ )` |
#
# > 💡 Tip: en Excel, usa F4 para fijar referencias absolutas. ¿Cuándo lo necesitas? → _______________________________________________
#
# ---
#
# **Ejercicio 10 (8 min):**
#
# 1) Total de ventas por **Region** con `SUMIF`:
#
# | Region | Fórmula | Resultado |
# |---|---|---|
# | North | | |
# | South | | |
# | East | | |
# | West | | |
#
# 2) Promedio de `Units_Sold` por **Product** con `AVERAGEIF`:
#
# | Product | Fórmula | Resultado |
# |---|---|---|
# | | | |
# | | | |
#
# 3) Formato condicional aplicado para resaltar:
# - ☐ Duplicados
# - ☐ Outliers (valores > _______________ )

# %% [markdown]
# ### 3.3 Comparar segmentos con múltiples condiciones (7–8 min)
#
# **Ejercicio 11 (7–8 min):**
# Construye una tabla de resumen con `SUMIFS`:
#
# - Filas = `Month`
# - Columnas = `West` y `East`
# - Valores = ventas totales por mes y región
#
# **Fórmula modelo para West:**
# ```
# =SUMIFS( _______________ , Region, "West", Month, _______________ )
# ```
#
# **Completa la tabla con tus resultados:**
#
# | Month | West | East | Diferencia (W-E) | ¿Cuál creció más? |
# |---|---|---|---|---|
# | | | | | |
# | | | | | |
# | | | | | |
#
# > 💬 **Pregunta:** ¿Cuál región creció más en el último trimestre? Apoya tu respuesta con los números.
#
# _Tu respuesta:_ _______________________________________________

# %% [markdown]
# ### 3.4 Crear hojas de resumen con KPIs clave (7–8 min)
#
# **Ejercicio 12 (7–8 min):**
# Diseña la hoja `Summary` con los siguientes elementos:
#
# **KPIs (completa la fórmula y el resultado):**
#
# | KPI | Fórmula | Resultado |
# |---|---|---|
# | Ventas totales | `=SUM(...)` | |
# | Ticket promedio (`Total_Sales / Units_Sold`) | `=...` | |
# | % crecimiento último mes | `=(... - ...) / ...` | |
#
# **Gráfico:**
# - Tipo de gráfico elegido: _______________
# - Ejes: X = _______________ / Y = _______________
# - ☐ Gráfico creado en `Summary`
#
# **2 bullets de insight** (estructura: contexto → hallazgo → implicación):
#
# 1. _______________________________________________
# 2. _______________________________________________

# %% [markdown]
# ---
# ## 4) Mini-Caso de Cierre (15–20 min)
#
# **Stakeholder:** CEO
# **Pregunta de negocio:** ¿Cómo evolucionaron las ventas de *Laptop* y *Smartphone* en el último trimestre por región?
#
# ---
#
# **Antes de empezar: formula la pregunta en el formato enfocado visto en 1.4:**
#
# _Tu versión enfocada:_ _______________________________________________
#
# ---
#
# **Tareas — marca al completar:**
#
# | Tarea | ¿Lista? | Observación |
# |---|---|---|
# | 1. Verificar que la columna `Month` es correcta | ☐ | |
# | 2. Calcular `Total_Sales` por `Month`, `Region`, `Product` (filtro Laptop/Smartphone) | ☐ | |
# | 3. Crear gráfico comparativo | ☐ | |
# | 4. Redactar 2–3 insights accionables | ☐ | |
#
# **Tus 2–3 insights para el CEO:**
#
# 1. _______________________________________________
# 2. _______________________________________________
# 3. _______________________________________________
#
# > ✅ **Entrega:** hoja `Summary` con KPIs, tabla, gráfico y sección "Insights".

# %% [markdown]
# ---
# ## Cierre
#
# ### Reflexión final (completa sin mirar las notas)
#
# | Pregunta | Tu respuesta |
# |---|---|
# | ¿Por qué una pregunta vaga ("¿cómo vamos?") es peligrosa para un analista? | |
# | ¿Qué ventaja tiene definir los KPIs **antes** de empezar a analizar? | |
# | ¿En qué situación usarías SUMIFS en lugar de SUMIF? | |
# | ¿Cuál fue el concepto más nuevo o difícil de hoy? | |
#
# ### ¿Necesitas ayuda?
# Recuerda los canales de ayuda que tenemos disponibles:
# - `DATA-CO-LEARNING`: Revisa los horarios de atencion en la guia dele studiante. Recuerda que tenemos horarios de apoyo todos los días para tus dudas puntuales!
# - `DA_CONSULTA`: Uuedes publicar tus preguntas sobre el contenido de la plataforma o el proyecto 24/7. Recuerda que en tu pregunta debes de agregar el tag @Dataconsulta.
# - `SPRINT FOCUS`: Para los Sprints 1 al 5 tenemos sesiones extra donde abordamos temáticas de cada sprint a rpofundidad. Revisa la guia del estudiante para conocer los horarios!
# - `SESIONES 1:1`: Recuerda que puedes agendar sesiones 1:1 con un tutor. Agendalas con antelación y resuelve todas tus dudas, desde temás del proyecto, curso, carrera hasta problemas técnicos.
# - `CANAL DE DISCORD DE COMMUNITY`: Recuerda que tu cohorte tiene un canal especial donde puedes compartir cualquier item interesante que quieras mostrar a tus compañeros de curso.
#
# ---
#
# ## Siguientes Pasos
#
# - **Próxima sesión:** Sprint 2 — Limpieza avanzada y KPIs en el proyecto Walmart.
# - **Tarea Discord:** Comparte una pregunta de negocio en formato `[Métrica] para [grupo] en [tiempo]`.
# - **Recordatorio:** Revisa las lecturas sobre KPIs sugeridas antes de la próxima sesión.
#
# > 💬 **Pregunta de salida:** De los 12 ejercicios de hoy, ¿cuál te generó más dudas? Anótalo para el Q&A o Discord:
#
# _Tu respuesta:_ _______________________________________________
