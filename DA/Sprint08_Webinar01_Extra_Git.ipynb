# %% [markdown]
# # Sprint 08 · Webinar 01 Extra · Student Version
# ## Funciones, ciclos y setup en VS Code + mini-proyecto con pandas
#
# **Duración sugerida:** 100 minutos
# **Modalidad:** práctica guiada / cuaderno de trabajo
#
# Este notebook está pensado para que el estudiante **complete notas, código, resultados e interpretaciones** durante la sesión.
#
# ### En esta sesión vas a practicar
# - **Funciones en Python** aplicadas a tareas de analítica con `pandas`
# - **Bucles `for` y `while`** y control de flujo
# - **Uso de VS Code** + instalación de **Python global**
# - Un mini-proyecto de analítica con un dataset sintético de retail
#
# > **Instrucción general:** evita borrar las consignas. Completa debajo de cada bloque con tus apuntes, respuestas y código.

# %% [markdown]
# ## Datos de la sesión
#
# Completa esta sección al iniciar la clase:
#
# - **Fecha:**
# - **Instructor/a:**
# - **Duración real:**
# - **Tema principal de hoy:**
# - **¿Qué espero aprender al final de la sesión?:**

# %% [markdown]
# ## Objetivos de aprendizaje
#
# Al finalizar esta sesión, deberías poder:
#
# 1. Instalar y verificar **Python** en Windows usando una instalación global.
# 2. Configurar **VS Code** para trabajar con Python y notebooks.
# 3. Cargar y explorar un dataset con `pandas`.
# 4. Escribir **funciones** reutilizables para limpieza, features y KPIs.
# 5. Usar **bucles `for`** para automatizar cálculos repetitivos.
# 6. Entender en qué escenarios un **`while`** tiene sentido y cuándo no.
#
# ### Antes de empezar
# Responde brevemente:
#
# - ¿Qué diferencia recuerdas entre una **función** y un **bucle**?
# - ¿Qué te cuesta más hoy: setup, lógica o interpretación de resultados?

# %% [markdown]
# ## Preparación del entorno (VS Code + Python + librerías)
#
# Usa esta sección como checklist de instalación.
#
# ### 1) Instalar Python (instalación global)
# Marca cuando lo hayas hecho:
#
# - [ ] Descargué Python desde el sitio oficial.
# - [ ] Marqué **Add python.exe to PATH**.
# - [ ] Verifiqué `python --version` o `py -V`.
# - [ ] Verifiqué `python -m pip --version`.
#
# ### 2) Instalar VS Code
# - [ ] Instalé VS Code.
# - [ ] Abrí una carpeta de trabajo para la clase.
# - [ ] Puedo abrir notebooks `.ipynb`.
#
# ### 3) Extensiones necesarias
# - [ ] Python (Microsoft)
# - [ ] Jupyter (Microsoft)
# - [ ] Pylance (opcional)
#
# ### 4) Abrir el proyecto
# Registra aquí tu carpeta de trabajo:
#
# - **Ruta o nombre de la carpeta:**
# - **Archivos que guardaste dentro:**
#
# ### 5) Seleccionar intérprete y kernel
# Completa:
#
# - **Intérprete seleccionado:**
# - **Kernel seleccionado:**
#
# ### 6) Instalación de librerías
# Escribe aquí el comando que ejecutaste:
#
# ```bash
# python -m pip install --upgrade pip
# python -m pip install numpy pandas scipy matplotlib
# ```
#
# ### 7) Nota conceptual
# Escribe con tus palabras:
#
# - ¿Qué significa “instalación global” de Python?
# - ¿Qué ventaja tiene para una clase de introducción?
# - ¿Qué riesgo tiene en proyectos reales?

# %%
# Verificación rápida del entorno
# Instrucción:
# 1) Ejecuta esta celda después de instalar Python y las librerías.
# 2) Si algo falla, anota el error en la celda markdown siguiente o al lado de tu cuaderno.

import sys
import numpy as np
import pandas as pd
import scipy
import matplotlib

print("Python:", sys.version.split()[0])
print("NumPy:", np.__version__)
print("pandas:", pd.__version__)
print("SciPy:", scipy.__version__)
print("matplotlib:", matplotlib.__version__)

# Reflexión rápida:
# ¿Tu entorno quedó listo? Escribe abajo:
# - Sí / No
# - Qué problema encontraste

# %% [markdown]
# ## Metodología de trabajo
#
# Durante esta sesión vamos a seguir un flujo similar al de un proyecto real de analítica:
#
# 1. **Generar o cargar datos**
# 2. **Revisar calidad**
# 3. **Transformar variables**
# 4. **Construir métricas**
# 5. **Automatizar tareas con funciones y ciclos**
# 6. **Interpretar resultados**
#
# ### Notas del estudiante
# Completa:
#
# - ¿Qué parte del flujo te parece más familiar?
# - ¿Qué parte te parece más nueva o difícil?

# %% [markdown]
# ## Agenda sugerida (100 minutos)
#
# | Tiempo | Bloque | Lo que harás tú |
# |---:|---|---|
# | 10 min | Setup | Verificar Python, VS Code y librerías |
# | 10 min | Kickoff | Formular hipótesis de negocio |
# | 15 min | Datos | Generar y guardar un CSV sintético |
# | 15 min | EDA rápido | Revisar calidad y estructura |
# | 20 min | Funciones | Crear un mini pipeline analítico |
# | 20 min | Ciclos | Automatizar reportes y validaciones |
# | 10 min | Cierre | Resumir hallazgos y próximos pasos |
#
# ### Planeación personal
# - **Bloque en el que debo poner más atención:**
# - **Meta personal para esta clase:**

# %% [markdown]
# ## Ejercicio 0 · Kickoff del mini-proyecto
#
# ### Contexto
# Eres analista en una empresa de retail que vende por **tienda** y **canal online**.
#
# El área comercial quiere entender:
# - cómo evolucionan las ventas por mes,
# - qué categorías y canales generan más ingresos,
# - y si hay señales de fricción logística.
#
# ### Preguntas guía
# Responde antes de programar:
#
# 1. ¿Qué fórmula usarías para calcular **ingresos por transacción**?
#    **Tu respuesta:**
#
# 2. ¿Qué variables podrían influir en las **devoluciones**?
#    **Tu respuesta:**
#
# 3. ¿Qué KPI usarías para monitorear una señal de **experiencia del cliente**?
#    **Tu respuesta:**
#
# 4. ¿Qué hipótesis inicial tienes sobre el canal **Online**?
#    **Tu respuesta:**

# %% [markdown]
# ## Proyecto práctico: “Retail Pulse”
#
# En este mini-proyecto vas a construir un flujo analítico básico con `pandas`.
#
# ### Etapas del proyecto
# 1. Generar un dataset sintético de transacciones.
# 2. Hacer una revisión rápida de calidad.
# 3. Construir funciones para limpieza, features y KPIs.
# 4. Usar ciclos para automatizar reportes.
# 5. Redactar hallazgos de negocio.
#
# ### Entregables esperados
# Al final de la sesión deberías tener:
#
# - [ ] Un CSV guardado en `data/retail_pulse_transactions.csv`
# - [ ] Un DataFrame listo para análisis
# - [ ] Un reporte mensual de KPIs
# - [ ] 3 a 5 insights escritos en markdown
#
# ### Espacio de apuntes
# - ¿Qué variable crees que será la más importante para el análisis?
# - ¿Qué validación no deberías olvidar?

# %% [markdown]
# ## Diccionario de datos (CSV)
#
# Cada fila representa una **transacción**.
#
# | Columna | Tipo esperado | ¿Qué representa? | Observaciones tuyas |
# |---|---|---|---|
# | `transaction_id` | int | Identificador de la transacción | |
# | `date` | datetime | Fecha de la compra | |
# | `customer_id` | int | Identificador del cliente | |
# | `region` | category | Región (Norte, Centro, Sur) | |
# | `channel` | category | Canal (Store / Online) | |
# | `category` | category | Categoría de producto | |
# | `product_id` | int | Identificador del producto | |
# | `units` | int | Unidades compradas | |
# | `unit_price` | float | Precio por unidad | |
# | `discount_pct` | float | Descuento entre 0 y 0.30 | |
# | `payment_method` | category | Método de pago | |
# | `delivery_days` | int | Días de entrega | |
# | `returned` | bool | Si la compra fue devuelta | |
# | `satisfaction_score` | float | Satisfacción (0–10) | |
#
# ### Pregunta rápida
# ¿Cuáles de estas columnas usarías para construir un KPI de logística?

# %%
# Setup básico: imports y configuración
# Ejecuta esta celda al comenzar el trabajo práctico.

import numpy as np
import pandas as pd
from pathlib import Path
from IPython.display import display

pd.set_option("display.max_columns", 50)
pd.set_option("display.width", 120)

DATA_DIR = Path("data")
DATA_DIR.mkdir(exist_ok=True)

# Escribe aquí cualquier nota sobre tu setup:
# - ¿La carpeta data se creó correctamente?
# - ¿Tu notebook reconoce pandas y numpy?

# %% [markdown]
# ## Ejercicio 1 · Generar el dataset sintético
#
# Vas a crear un dataset con transacciones de los últimos 12 meses.
#
# ### Objetivo
# Practicar generación de datos, estructura tabular y guardado en CSV.
#
# ### Qué debe incluir el dataset
# - Transacciones de retail
# - Algunas imperfecciones realistas:
#   - nulos en `satisfaction_score`
#   - outliers en `delivery_days`
# - Variables útiles para luego analizar revenue, devoluciones y satisfacción
#
# ### Antes de codificar
# Completa:
#
# - **Número de filas que planeas generar:**
# - **Categorías que esperas usar:**
# - **Qué columnas crees que podrían tener problemas de calidad:**

# %%
# Ejercicio 1: generar el dataset sintético
# Instrucción:
# Completa este bloque paso a paso. No necesitas copiar una solución exacta;
# lo importante es que el dataset final tenga la estructura pedida.

rng = np.random.default_rng(seed=42)

# 1) Parámetros base
N = 12000
start_date = pd.Timestamp.today().normalize() - pd.Timedelta(days=365)

regions = ["Norte", "Centro", "Sur"]
channels = ["Store", "Online"]
categories = ["Grocery", "Electronics", "Home", "Beauty", "Sports"]
payment_methods = ["Card", "Cash", "Transfer", "Wallet"]

# 2) Genera columnas básicas
# TODO: crea fechas aleatorias dentro de los últimos 12 meses
# dates = ...

# TODO: crea identificadores de cliente
# customer_id = ...

# TODO: asigna región, canal y categoría con probabilidades razonables
# region = ...
# channel = ...
# category = ...

# 3) Crea product_id a partir de la categoría
# Pista: puedes mapear cada categoría a un prefijo numérico y luego sumar un número aleatorio.
# product_id = ...

# 4) Genera variables numéricas
# TODO:
# units = ...
# base_price = ...
# unit_price = ...
# discount_pct = ...
# payment_method = ...

# 5) Delivery days
# Regla sugerida:
# - Store = 0
# - Online = entre 1 y 7 días normalmente
# - agrega algunos outliers altos en online
# delivery_days = ...

# 6) Returned
# Crea una probabilidad de devolución que aumente si:
# - el canal es Online
# - delivery_days es alto
# - la categoría es Electronics
# returned = ...

# 7) Satisfaction
# Crea un score base alto y redúcelo si:
# - delivery_days es alto
# - hubo devolución
# Luego agrega algunos nulos.
# satisfaction = ...

# 8) Construye el DataFrame final
# df_raw = pd.DataFrame({
#     "transaction_id": ...,
#     "date": ...,
#     "customer_id": ...,
#     "region": ...,
#     "channel": ...,
#     "category": ...,
#     "product_id": ...,
#     "units": ...,
#     "unit_price": ...,
#     "discount_pct": ...,
#     "payment_method": ...,
#     "delivery_days": ...,
#     "returned": ...,
#     "satisfaction_score": ...,
# })

# 9) Muestra una vista previa
# display(df_raw.head())

# Apuntes:
# - ¿Qué parte te costó más generar?
# - ¿Qué decisión tomaste para simular datos "realistas"?

# %%
# Guardar CSV
# Completa esta celda cuando ya tengas listo tu DataFrame df_raw.

# csv_path = DATA_DIR / "retail_pulse_transactions.csv"
# df_raw.to_csv(csv_path, index=False)
# csv_path

# Verificación sugerida:
# - ¿El archivo se guardó en la ruta correcta?
# - ¿Puedes volverlo a abrir sin error?

# %% [markdown]
# ## Ejercicio 2 · Cargar el CSV y revisar calidad de datos (EDA rápido)
#
# ### Checklist mínimo
# - [ ] ¿Cuántas filas y columnas tiene el dataset?
# - [ ] ¿Qué tipos de datos detectó pandas?
# - [ ] ¿Cuántos nulos hay por columna?
# - [ ] ¿Hay duplicados?
# - [ ] ¿Los rangos de `discount_pct`, `units` y `delivery_days` tienen sentido?
#
# ### Antes de ejecutar
# Escribe tu hipótesis:
#
# - ¿En qué columna esperas más nulos?
# - ¿Qué rango esperas para `discount_pct`?
# - ¿Qué anomalía podría aparecer en `delivery_days`?

# %%
# Carga del CSV y revisión inicial
# Completa este bloque con tu código.

# df = pd.read_csv(csv_path, parse_dates=["date"])
# print("Shape:", ...)
# display(...)
# display(...)

# Preguntas para responder después de ejecutar:
# 1) ¿Cuántas filas y columnas hay?
# 2) ¿Qué columnas quedaron como object y cuáles deberían revisarse?

# %%
# Calidad de datos: nulos, duplicados y rangos
# Completa este bloque con tu análisis.

# missing = ...
# display(...)

# dup_count = ...
# print("Duplicados en transaction_id:", ...)

# print("discount_pct min/max:", ...)
# print("units min/max:", ...)
# print("delivery_days min/max:", ...)

# Conclusiones rápidas:
# - Principal problema de calidad detectado:
# - ¿Necesitas limpiar algo antes de analizar?

# %% [markdown]
# ### Mini-ejercicio
#
# Resuelve con código:
#
# 1. Crea una columna `revenue_raw = units * unit_price`
# 2. Calcula el porcentaje de transacciones `Online`
# 3. Identifica la categoría con mayor `revenue_raw` promedio
#
# ### Antes de programar
# Anota la lógica que vas a usar:
#
# - Para crear `revenue_raw` usaré:
# - Para calcular porcentaje online usaré:
# - Para encontrar la categoría top usaré:

# %%
# Mini-ejercicio: escribe tu solución aquí

# TODO 1: crear revenue_raw

# TODO 2: calcular porcentaje de transacciones online

# TODO 3: encontrar la categoría con mayor revenue promedio

# Sugerencia:
# usa operaciones columna a columna + groupby + sort_values

# Al terminar, deja aquí una breve interpretación:
# - ¿Qué tan importante parece el canal online?
# - ¿Qué categoría salió arriba y por qué crees que pasa?

# %% [markdown]
# ## Repaso · Funciones en Python para analítica con pandas
#
# ### Idea clave
# Las funciones permiten:
#
# - reutilizar lógica,
# - reducir errores por copiar/pegar,
# - documentar cada paso del pipeline,
# - separar mejor la limpieza, el feature engineering y el cálculo de métricas.
#
# ### Tu objetivo
# Construir un mini pipeline con estas funciones:
#
# 1. `clean_transactions(df)`
# 2. `add_features(df)`
# 3. `compute_kpis(df)`
#
# ### Antes de codificar
# Completa:
#
# - ¿Qué debería hacer una función de **limpieza**?
# - ¿Qué nueva variable te gustaría crear en **features**?
# - ¿Qué KPI no debería faltar en el reporte mensual?

# %%
def clean_transactions(df: pd.DataFrame) -> pd.DataFrame:
    """Limpia el dataset de transacciones.

    Ideas para completar:
    - Asegurar tipos básicos
    - Imputar satisfacción faltante
    - Crear una bandera is_online
    """
    out = df.copy()

    # TODO 1: convertir columnas apropiadas a category
    # TODO 2: imputar satisfaction_score (por ejemplo, con mediana por canal)
    # TODO 3: crear una columna booleana is_online

    return out


def add_features(df: pd.DataFrame) -> pd.DataFrame:
    """Agrega variables útiles para análisis.

    Ideas para completar:
    - month
    - revenue
    - is_weekend
    - delayed_delivery
    """
    out = df.copy()

    # TODO 1: crear month
    # TODO 2: crear revenue aplicando descuento
    # TODO 3: crear is_weekend
    # TODO 4: crear delayed_delivery

    return out


def compute_kpis(df: pd.DataFrame) -> pd.DataFrame:
    """Calcula KPIs agregados por mes.

    KPIs sugeridos:
    - revenue_total
    - orders
    - avg_revenue_per_order
    - return_rate
    - avg_delivery_days_online
    - avg_satisfaction
    """

    # TODO:
    # 1) agrupa por month
    # 2) calcula los KPIs
    # 3) devuelve una tabla ordenada cronológicamente

    # kpis = ...
    # return kpis
    pass


# Cuando termines las funciones, prueba tu pipeline aquí:
# df_clean = clean_transactions(df)
# df_feat = add_features(df_clean)
# kpis_month = compute_kpis(df_feat)
# display(kpis_month.head())

# Nota:
# Si una función no te sale completa, deja al menos el esqueleto y anota qué te faltó.

# %% [markdown]
# ### Mini-ejercicio
#
# Crea una función `top_categories(df, n=3)` que retorne las `n` categorías con mayor revenue total.
#
# **Pista:** `groupby("category")["revenue"].sum()`
#
# ### Responde antes de programar
# - ¿La función debería devolver una Serie o un DataFrame?
# - ¿Qué parámetro te permite hacerla reutilizable?

# %%
def top_categories(df: pd.DataFrame, n: int = 3) -> pd.DataFrame:
    """Retorna las n categorías con mayor revenue total."""

    # TODO:
    # 1) agrupa por category
    # 2) suma revenue
    # 3) ordena de mayor a menor
    # 4) devuelve las primeras n filas

    # out = ...
    # return out
    pass


# Prueba tu función aquí cuando termines:
# display(top_categories(df_feat, n=3))

# %% [markdown]
# ## Repaso · Bucles `for`
#
# ### ¿Para qué usar `for` en analítica?
# - construir reportes por mes, región o categoría,
# - ejecutar validaciones repetitivas,
# - aplicar una misma lógica a varias particiones.
#
# ### Idea importante
# Aunque `for` es muy útil, en `pandas` muchas tareas se resuelven mejor con:
# - `groupby`
# - `agg`
# - `merge`
# - operaciones vectorizadas
#
# ### Pregunta de reflexión
# ¿Cuándo preferirías un `for` y cuándo preferirías `groupby`?

# %%
# Reporte mensual por región usando un bucle for
# Objetivo:
# construir una tabla con revenue_total, orders y return_rate por month y region

# months = ...
# rows = []

# for m in months:
#     df_m = ...
#
#     by_region = ...
#     by_region = by_region.reset_index()
#     by_region["month"] = m
#     rows.append(by_region)

# report_region_month = ...
# display(report_region_month.head(10))

# Escribe aquí tu conclusión:
# ¿Te resultó claro usar for para este caso?

# %%
# Alternativa con pandas: groupby sin bucle for
# Repite el reporte anterior usando groupby y compáralo con la versión del for.

# report_region_month_fast = ...

# Si lograste ambas versiones, compara resultados:
# check = ...
# display(...)

# Reflexión:
# ¿Cuál de las dos soluciones te parece más limpia?
# ¿Cuál sería más fácil de mantener?

# %% [markdown]
# ### Mini-ejercicio
#
# Usa un `for` para construir una lista de resultados con:
#
# - `category`
# - `avg_satisfaction`
#
# Al final, conviértela en un DataFrame.
#
# ### Antes de escribir código
# - ¿Qué lista vas a inicializar?
# - ¿Qué valor vas a agregar en cada iteración?

# %%
# Mini-ejercicio con for
# Completa tu solución aquí.

# results = []
# for cat in ...:
#     avg_sat = ...
#     results.append(...)

# df_avg_sat = ...
# display(df_avg_sat)

# Interpretación:
# - ¿Qué categoría quedó con mejor satisfacción promedio?
# - ¿Crees que eso se relaciona con devoluciones o con delivery?

# %% [markdown]
# ## Repaso · Bucles `while`
#
# ### ¿Cuándo usar `while`?
# Cuando no sabes de antemano cuántas iteraciones necesitas y repites un proceso hasta cumplir una condición.
#
# ### Ejemplo de hoy
# Aplicar una regla de tratamiento de outliers sobre `delivery_days` hasta que el número de outliers deje de ser problemático o hasta llegar a un máximo de iteraciones.
#
# ### Cuidado
# Un `while` mal definido puede generar un ciclo infinito.
#
# ### Antes de codificar
# Escribe con tus palabras:
#
# - ¿Cuál será tu condición de parada?
# - ¿Qué variable vas a actualizar en cada iteración?

# %%
def count_delivery_outliers_iqr(df: pd.DataFrame) -> int:
    """Cuenta outliers en delivery_days (solo online) usando IQR."""

    # TODO:
    # 1) filtra solo online
    # 2) calcula Q1, Q3 e IQR
    # 3) cuenta observaciones fuera de los límites
    pass


def cap_delivery_outliers_iqr(df: pd.DataFrame) -> pd.DataFrame:
    """Aplica capping a delivery_days usando límites IQR."""

    out = df.copy()

    # TODO:
    # 1) calcula límites IQR en delivery_days para online
    # 2) aplica clip/capping solo a online
    # 3) retorna el DataFrame transformado

    return out


# Esqueleto del while
# df_loop = df_feat.copy()
# max_iter = 5
# iter_count = 0
#
# outliers = count_delivery_outliers_iqr(df_loop)
# print("Outliers iniciales:", outliers)
#
# while (...condición...):
#     df_loop = ...
#     outliers = ...
#     iter_count += 1
#     print(f"Iteración {iter_count}: outliers = {outliers}")
#
# print("Iteraciones ejecutadas:", iter_count)

# Reflexión:
# ¿Por qué este caso sí tiene sentido para while?

# %% [markdown]
# ### Nota
#
# Si tu `while` no funciona a la primera, documenta el problema:
#
# - ¿La condición de parada estaba bien definida?
# - ¿El número de outliers realmente cambiaba en cada iteración?
# - ¿Qué riesgo habría de dejar este bucle sin `max_iter`?

# %% [markdown]
# ## VS Code + Python global (sin entornos virtuales)
#
# Usa este bloque como resumen técnico de apoyo.
#
# ### Completa la guía con tus propias palabras
# 1. **¿Qué es instalar Python globalmente?**
# 2. **¿Qué extensiones necesita VS Code para esta clase?**
# 3. **¿Cómo seleccionas el intérprete?**
# 4. **¿Cómo ejecutas un script `.py`?**
# 5. **¿Cómo trabajas con notebooks en VS Code?**
#
# ### Comandos importantes
# ```bash
# python --version
# python -m pip install numpy pandas scipy matplotlib
# python hello.py
# ```
#
# ### Nota personal
# ¿Qué paso del setup sueles olvidar más?

# %% [markdown]
# ## ¿Qué es un entorno virtual (`venv`) y por qué existe?
#
# Escribe una explicación breve con tus palabras:
#
# - **Definición:**
# - **Problema que resuelve:**
# - **Cuándo conviene usarlo:**
# - **Por qué hoy no lo usamos en esta clase:**
#
# ### Comparación rápida
# Completa la tabla:
#
# | Tema | Python global | Entorno virtual |
# |---|---|---|
# | Facilidad para empezar | | |
# | Aislamiento de dependencias | | |
# | Riesgo de conflictos | | |
# | Conveniencia para clase introductoria | | |

# %% [markdown]
# ## Takeaways
#
# Completa al final de la sesión:
#
# 1. Una idea importante sobre **funciones**:
# 2. Una idea importante sobre **`for`**:
# 3. Una idea importante sobre **`while`**:
# 4. Una idea importante sobre **VS Code / setup**:
# 5. Algo que todavía necesito practicar:

# %% [markdown]
# ## Cierre
#
# ### Checklist de salida
# Marca lo que completaste:
#
# - [ ] Generé el CSV en `data/retail_pulse_transactions.csv`
# - [ ] Cargué el dataset y revisé calidad
# - [ ] Construí o avancé funciones de limpieza, features y KPIs
# - [ ] Armé un reporte por mes y región
# - [ ] Practiqué un `while` con condición de parada
# - [ ] Escribí al menos 3 hallazgos o dudas
#
# ### Reflexión final
# Responde:
#
# - ¿Qué parte te pareció más útil para tu día a día: funciones, `for` o `while`?
# - ¿Qué concepto necesitas reforzar antes de seguir?
# - ¿Qué error cometiste hoy y qué aprendiste de él?

# %% [markdown]
# ## Siguientes pasos
#
# 1. Convierte este notebook en un mini proyecto más ordenado:
#    - carpeta `data/`
#    - carpeta `notebooks/`
#    - `README.md` con objetivo y hallazgos
#
# 2. Redacta entre **3 y 5 insights** sobre:
#    - revenue por canal y categoría
#    - relación entre `delivery_days` y `returned`
#    - satisfacción por canal o por categoría
#
# 3. Opcional:
#    - crea una visualización mensual de revenue
#    - crea un gráfico por categoría
#    - compara una solución con `for` frente a otra con `groupby`
#
# ### Registro personal
# - **Próximo paso que haré después de clase:**
# - **Duda que quiero resolver en tutoría o Discord:**
#
# ### ¿Necesitas ayuda?
# - `DATA-CO-LEARNING`: revisa los horarios de apoyo en la guía del estudiante.
# - `DA_CONSULTA`: publica dudas de contenido o del proyecto usando el tag correspondiente.
# - `SPRINT FOCUS`: sesiones extra para profundizar temas clave del sprint.
# - `SESIONES 1:1`: agenda con anticipación si necesitas apoyo individual.
