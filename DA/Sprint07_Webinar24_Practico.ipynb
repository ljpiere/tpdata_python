# %% [markdown]
# # Sprint 7 · Webinar 24 · Data Analytics práctico — Student Version
# ## Proyecto: outliers, segmentación y publicación en GitHub
#
# **Duración:** 100 minutos
# **Nivel:** principiante–intermedio
# **Formato:** práctica guiada con proyecto aplicado
# **Caso:** *Clínica Agendada*
#
# > En este notebook vas a trabajar como analista. La idea no es copiar una solución terminada, sino **construirla paso a paso**, registrar decisiones y dejar evidencia de tu trabajo.

# %% [markdown]
# ## Datos de la sesión
#
# Completa esta información al inicio o durante la clase:
#
# - **Fecha:** `____ / ____ / 2026`
# - **Estudiante:** `__________________________________________________`
# - **Instructor/a:** `__________________________________________________`
# - **Cohorte / grupo:** `__________________________________________________`
# - **Dataset utilizado:** `__________________________________________________`
# - **Link del repositorio GitHub:** `___________________________________________`

# %% [markdown]
# ## Objetivos de la sesión práctica
#
# Al finalizar esta práctica, deberías poder:
#
# 1. Cargar y explorar un dataset de transacciones con `pandas`.
# 2. Revisar calidad de datos: tipos, nulos, duplicados y rangos sospechosos.
# 3. Construir métricas por cliente usando `groupby()` y `agg()`.
# 4. Detectar outliers con reglas como **IQR** y **Z-score**.
# 5. Tomar decisiones de limpieza o tratamiento con criterio de negocio.
# 6. Crear segmentos de clientes con `if/elif/else` y con `apply()`.
# 7. Redactar un **Statistical Summary** corto y accionable.
# 8. Organizar el proyecto para compartirlo en GitHub.

# %% [markdown]
# ## Ruta de trabajo
#
# | Bloque | Qué harás | Evidencia esperada |
# |---|---|---|
# | 1 | Cargar datos y revisar estructura | `shape`, `head()`, tipos, observaciones |
# | 2 | Validar calidad | nulos, duplicados, columnas problemáticas |
# | 3 | Crear métricas por cliente | dataframe agregado |
# | 4 | Detectar outliers | columnas flag y observaciones |
# | 5 | Tratar outliers | reglas de limpieza documentadas |
# | 6 | Segmentar clientes | nuevas columnas y tabla resumen |
# | 7 | Redactar hallazgos | summary en bullets o markdown |
# | 8 | Publicar proyecto | checklist de repo y archivos |

# %% [markdown]
# ## Ejercicio 0 · Kickoff del proyecto
#
# Antes de programar, responde brevemente:
#
# 1. ¿Qué preguntas de negocio te gustaría responder con este dataset?
# 2. ¿Qué variables crees que podrían tener valores atípicos?
# 3. ¿Qué señales usarías para detectar clientes valiosos o clientes en riesgo?
# 4. ¿Qué hallazgo sería útil para presentar a una persona no técnica?
#
# ### Mis hipótesis iniciales
# - `______________________________________________________________`
# - `______________________________________________________________`
# - `______________________________________________________________`
# - `______________________________________________________________`

# %% [markdown]
# ## Contexto del caso: Clínica Agendada
#
# Trabajas como analista en una empresa de salud con citas por agenda. El negocio quiere entender:
#
# - cómo se comportan los clientes por plan, ciudad y canal,
# - cuánto impactan los reembolsos,
# - si existen valores atípicos que distorsionen el análisis,
# - y cómo segmentar clientes para acciones de seguimiento.
#
# ### Entregables del proyecto
#
# - Un notebook reproducible.
# - Un dataset en CSV.
# - Un archivo de métricas por cliente.
# - Un resumen estadístico con hallazgos.
# - Un repositorio en GitHub con estructura clara.

# %% [markdown]
# ## Diccionario de datos resumido
#
# Completa o comenta este diccionario mientras avanzas:
#
# | Columna | ¿Qué representa? | Tipo esperado | ¿Puede tener problemas? |
# |---|---|---|---|
# | `transaction_id` | | | |
# | `customer_id` | | | |
# | `appointment_date` | | | |
# | `amount_net` | | | |
# | `is_refund` | | | |
# | `wait_time_min` | | | |
# | `service_duration_min` | | | |
# | `satisfaction_score` | | | |
# | `age` | | | |
# | `plan` | | | |
# | `city` | | | |
# | `acquisition_channel` | | | |

# %% [markdown]
# ## 1. Preparación del entorno
#
# Usa esta celda para importar librerías y preparar rutas.
#
# **Sugerencia:** si el archivo ya existe en la carpeta del curso, apunta `csv_file` a esa ruta. Si estás trabajando en Colab, ajusta la ruta a tu Drive o a la carpeta local del notebook.

# %%
# Setup del proyecto
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

pd.set_option('display.max_columns', 200)

# TODO: ajusta esta ruta según tu entorno
# Ejemplo: csv_file = Path('datasets/sprint7_webinar24_clinic_transactions.csv')
csv_file = Path('REEMPLAZA_CON_LA_RUTA_DEL_CSV')

print('Ruta configurada:', csv_file)

# %% [markdown]
# ## Ejercicio 1 · Cargar el CSV y hacer un primer reconocimiento
#
# ### Tu tarea
#
# 1. Carga el archivo CSV.
# 2. Observa tamaño, primeras filas y nombres de columnas.
# 3. Escribe una primera impresión del dataset.

# %%
# TODO: carga el dataset
# df = pd.read_csv(csv_file)

# TODO: explora tamaño y primeras filas
# print(df.shape)
# display(df.head())
# print(df.columns.tolist())

# %% [markdown]
# ### Registro rápido
#
# | Pregunta | Mi respuesta |
# |---|---|
# | Número de filas | |
# | Número de columnas | |
# | Columna que más me llama la atención | |
# | Columna que necesito revisar con cuidado | |
# | Hipótesis sobre el negocio | |

# %% [markdown]
# ## Ejercicio 2 · Revisión de calidad de datos
#
# Ahora valida la calidad básica del dataset.
#
# ### Revisa como mínimo
#
# - tipos de datos,
# - porcentaje de nulos,
# - duplicados,
# - fechas inválidas,
# - valores sospechosos en columnas numéricas.

# %%
# TODO: revisar tipos de datos
# df.dtypes

# TODO: porcentaje de nulos por columna
# missing = df.isna().mean().sort_values(ascending=False)
# display(missing)

# TODO: revisar duplicados
# print(df.duplicated().sum())
# print(df['transaction_id'].duplicated().sum())

# TODO: convertir fechas si hace falta
# df['appointment_date'] = pd.to_datetime(df['appointment_date'], errors='coerce')
# df['signup_date'] = pd.to_datetime(df['signup_date'], errors='coerce')

# %% [markdown]
# ### Hallazgos de calidad
#
# Completa esta tabla después de revisar el dataset:
#
# | Revisión | Qué encontré | Qué decisión tomaré |
# |---|---|---|
# | Nulos | | |
# | Duplicados | | |
# | Fechas | | |
# | Tipos de datos | | |
# | Rangos extraños | | |

# %% [markdown]
# ## Ejercicio 3 · Crear métricas por cliente
#
# En este bloque vas a construir una tabla agregada por cliente. Algunas variables útiles:
#
# - `num_visits`
# - `total_spend`
# - `refund_count`
# - `avg_ticket`
# - `max_ticket`
# - `last_visit_date`
# - `recency_days`
# - `avg_wait_time`
# - `avg_duration`
# - `avg_satisfaction`
#
# ### Antes de programar
#
# ¿Qué métrica crees que será más útil para segmentar clientes y por qué?
#
# `__________________________________________________________________________`

# %%
# TODO: si hace falta, separa ingresos vs reembolsos
# df_revenue = df[df['amount_net'] > 0].copy()
# df_refunds = df[df['amount_net'] < 0].copy()

# TODO: define fecha de corte del análisis
# as_of_date = df['appointment_date'].max()

# TODO: construye el dataframe customer_metrics
# customer_metrics = (
#     df.groupby('customer_id')
#       .agg(
#           num_visits=('transaction_id', 'nunique'),
#           total_spend=('amount_net', lambda s: s[s > 0].sum()),
#           refund_count=('is_refund', 'sum'),
#           avg_ticket=('amount_net', lambda s: s[s > 0].mean()),
#           max_ticket=('amount_net', lambda s: s[s > 0].max()),
#           last_visit_date=('appointment_date', 'max'),
#           avg_wait_time=('wait_time_min', 'mean'),
#           avg_duration=('service_duration_min', 'mean'),
#           avg_satisfaction=('satisfaction_score', 'mean')
#       )
#       .reset_index()
# )

# TODO: crear recency y refund_rate
# customer_metrics['recency_days'] = (as_of_date - customer_metrics['last_visit_date']).dt.days
# customer_metrics['refund_rate'] = customer_metrics['refund_count'] / customer_metrics['num_visits']

# TODO: muestra resultados
# display(customer_metrics.head())
# customer_metrics.describe()

# %% [markdown]
# ### Registro de métricas
#
# | Métrica | Qué significa en este caso | Qué observaste |
# |---|---|---|
# | `num_visits` | | |
# | `total_spend` | | |
# | `refund_rate` | | |
# | `avg_ticket` | | |
# | `recency_days` | | |

# %% [markdown]
# ## Mini-ejercicio · Top spenders
#
# 1. Calcula el **percentil 90** de `total_spend`.
# 2. Crea una columna `is_top_spender`.
# 3. Cuenta cuántos clientes quedan marcados.
# 4. Escribe una interpretación de negocio.

# %%
# TODO: percentil 90 de total_spend
# p90 = customer_metrics['total_spend'].quantile(0.90)

# TODO: flag top spender
# customer_metrics['is_top_spender'] = (customer_metrics['total_spend'] >= p90).astype(int)

# TODO: validar resultado
# print(p90)
# customer_metrics['is_top_spender'].value_counts()

# %% [markdown]
# ### Interpretación
#
# - ¿Qué significa pertenecer al top 10% en este dataset?
#   `_______________________________________________________________`
# - ¿Qué acción comercial tendría sentido para este grupo?
#   `_______________________________________________________________`

# %% [markdown]
# ## Ejercicio 4 · Detección de outliers
#
# Analiza outliers al menos en estas variables:
#
# - `total_spend` (a nivel cliente)
# - `wait_time_min` (a nivel transacción)
# - `age` o `satisfaction_score` (calidad de datos)
#
# ### Recomendación
#
# - Usa **IQR** para variables sesgadas como montos.
# - Usa **Z-score** si la variable es más estable o si quieres una regla rápida.

# %%
# TODO: IQR para total_spend
# metric = 'total_spend'
# q1 = customer_metrics[metric].quantile(0.25)
# q3 = customer_metrics[metric].quantile(0.75)
# iqr = q3 - q1
# lower = q1 - 1.5 * iqr
# upper = q3 + 1.5 * iqr
# customer_metrics['outlier_iqr_total_spend'] = ((customer_metrics[metric] < lower) | (customer_metrics[metric] > upper)).astype(int)

# TODO: revisar ejemplos de outliers
# display(customer_metrics[customer_metrics['outlier_iqr_total_spend'] == 1].sort_values('total_spend', ascending=False).head(10))

# TODO: Z-score para wait_time_min
# wait = df['wait_time_min'].dropna()
# mean_w = wait.mean()
# std_w = wait.std(ddof=0)
# z = (df['wait_time_min'] - mean_w) / std_w
# df['outlier_z_wait_time'] = (z.abs() > 3).astype(int)
# df['outlier_z_wait_time'].value_counts()

# %%
# TODO: crea al menos 2 visualizaciones para apoyar tu análisis
# Sugerencia 1: histograma de amount_net o total_spend
# Sugerencia 2: histograma o boxplot de wait_time_min

# plt.figure(figsize=(10, 4))
# plt.hist(...)
# plt.title('...')
# plt.show()

# %% [markdown]
# ### Bitácora de outliers
#
# | Variable | Método usado | Qué encontré | ¿Error, caso extremo o comportamiento real? |
# |---|---|---|---|
# | `total_spend` | | | |
# | `wait_time_min` | | | |
# | `age` | | | |
# | `satisfaction_score` | | | |

# %% [markdown]
# ## Ejercicio 5 · Tratamiento de outliers y limpieza con criterio de negocio
#
# No todos los outliers se eliminan. En este bloque decide qué hacer y documenta por qué.
#
# ### Posibles reglas
#
# - Edad válida entre 18 y 90.
# - Satisfacción válida entre 1 y 10.
# - Capping de montos en p99 para análisis agregado.
# - Reembolsos tratados aparte, no como simple "error".

# %%
# TODO: crear una copia limpia
# df_clean = df.copy()

# TODO: limpiar edad y satisfacción
# df_clean['age_clean'] = df_clean['age'].where(df_clean['age'].between(18, 90), np.nan)
# df_clean['satisfaction_clean'] = df_clean['satisfaction_score'].where(df_clean['satisfaction_score'].between(1, 10), np.nan)

# TODO: aplicar capping en p99 solo a ingresos
# p99 = df_clean.loc[df_clean['amount_net'] > 0, 'amount_net'].quantile(0.99)
# df_clean['amount_net_capped'] = df_clean['amount_net']
# mask_revenue = df_clean['amount_net_capped'] > 0
# df_clean.loc[mask_revenue, 'amount_net_capped'] = df_clean.loc[mask_revenue, 'amount_net_capped'].clip(upper=p99)

# TODO: valida cuántos valores cambiaron

# %% [markdown]
# ### Registro de decisiones
#
# | Regla aplicada | ¿Por qué la aplicaste? | Impacto esperado |
# |---|---|---|
# | Edad fuera de rango → `NaN` | | |
# | Satisfacción fuera de rango → `NaN` | | |
# | Capping de montos | | |
# | Reembolsos aparte | | |

# %% [markdown]
# ## Ejercicio 6 · Segmentación de clientes con `if/elif/else`
#
# Vas a crear una segmentación simple y explicable. Una posible lógica usa:
#
# - **Recency** → días desde la última visita
# - **Frequency** → número de visitas
# - **Monetary** → gasto total
#
# ### Segmentos sugeridos
#
# - `VIP`
# - `Leal`
# - `Prometedor`
# - `En riesgo`
# - `Bajo valor`
#
# Antes de escribir la función, define tus reglas en lenguaje natural.
#
# `__________________________________________________________________________`

# %%
# TODO: reconstruir métricas usando df_clean si es necesario
# as_of_date = df_clean['appointment_date'].max()
# customer_metrics2 = (...)

# TODO: calcula umbrales que te ayuden a segmentar
# p75_spend = customer_metrics2['total_spend'].quantile(0.75)
# p75_visits = customer_metrics2['num_visits'].quantile(0.75)

# TODO: crea una función con if/elif/else
# def segment_customer_if(row):
#     recency = row['recency_days']
#     freq = row['num_visits']
#     spend = row['total_spend']
#
#     # Escribe tus reglas aquí
#     # if ...:
#     #     return 'VIP'
#     # elif ...:
#     #     return 'Leal'
#     # ...
#     # else:
#     #     return 'Bajo valor'
#
# customer_metrics2['segment_if'] = customer_metrics2.apply(segment_customer_if, axis=1)
# customer_metrics2['segment_if'].value_counts()

# %% [markdown]
# ### Validación de segmentos
#
# | Segmento | Qué características debería tener | ¿Tus resultados tienen sentido? |
# |---|---|---|
# | VIP | | |
# | Leal | | |
# | Prometedor | | |
# | En riesgo | | |
# | Bajo valor | | |

# %% [markdown]
# ## Ejercicio 7 · Enriquecimiento con `apply()`
#
# Ahora crea columnas adicionales útiles para activar acciones:
#
# - `needs_follow_up`
# - `discount_eligible`
# - `recommended_channel`
#
# Piensa en reglas simples, claras y reproducibles.

# %%
# TODO: crear una función que devuelva varias columnas
# def enrichment_rules(row):
#     # Ejemplo de variables disponibles:
#     # recency = row['recency_days']
#     # seg = row['segment_if']
#     # sat = row['avg_satisfaction']
#     # ...
#
#     # return pd.Series({
#     #     'needs_follow_up': ...,
#     #     'discount_eligible': ...,
#     #     'recommended_channel': ...
#     # })
#     pass
#
# customer_metrics2[['needs_follow_up', 'discount_eligible', 'recommended_channel']] = customer_metrics2.apply(enrichment_rules, axis=1)
# display(customer_metrics2.head())

# %% [markdown]
# ## Mini-ejercicio · Prioridad comercial
#
# Crea una columna `priority` con esta lógica:
#
# - `Alta` si necesita seguimiento **y** es elegible a descuento.
# - `Media` si necesita seguimiento pero no descuento.
# - `Baja` en los demás casos.
#
# Hazlo de dos maneras:
#
# 1. con `if/elif/else` dentro de una función,
# 2. con `np.select`.
#
# Luego compara cuál te parece más legible.

# %%
# TODO A: resolver con función
# def priority_if(row):
#     ...
#
# customer_metrics2['priority_if'] = customer_metrics2.apply(priority_if, axis=1)

# TODO B: resolver con np.select
# conditions = [
#     ...,
#     ...,
# ]
# choices = ['Alta', 'Media']
# customer_metrics2['priority_npselect'] = np.select(conditions, choices, default='Baja')

# TODO C: comparar resultados
# customer_metrics2[['priority_if', 'priority_npselect']].head()

# %% [markdown]
# ## Ejercicio 8 · Redactar un Statistical Summary
#
# Tu summary debe incluir:
#
# 1. tamaño y ventana temporal del dataset,
# 2. principales problemas de calidad detectados,
# 3. hallazgos de negocio,
# 4. decisiones sobre outliers,
# 5. segmentos y acciones recomendadas.
#
# ### Plantilla sugerida
#
# ```markdown
# # Statistical Summary · Clínica Agendada
#
# ## Dataset
# - Número de filas:
# - Número de clientes:
# - Ventana temporal:
#
# ## Calidad de datos
# -
# -
#
# ## KPIs / Hallazgos
# -
# -
#
# ## Outliers y tratamiento
# -
# -
#
# ## Segmentación
# -
# -
#
# ## Recomendaciones
# -
# -
# ```

# %%
# TODO: si quieres, automatiza parte del summary con variables calculadas
# n_rows = ...
# n_customers = ...
# date_min = ...
# date_max = ...
# refund_rate_global = ...
# avg_ticket_global = ...

# TODO: construye un texto markdown y guárdalo en outputs/statistical_summary.md

# %% [markdown]
# ## Ejercicio 9 · Organización del proyecto y GitHub
#
# Marca lo que ya dejaste listo:
#
# - [ ] Tengo el CSV del proyecto en una carpeta clara (`data/` o similar).
# - [ ] Guardé el notebook con nombre entendible.
# - [ ] Exporté métricas o tablas relevantes a `outputs/`.
# - [ ] Redacté un `README.md`.
# - [ ] El repo en GitHub ya existe.
# - [ ] Hice al menos un commit con mensaje descriptivo.
# - [ ] Tengo el enlace del repositorio listo para entregar.

# %%
# TODO: guarda tus outputs principales
# Ejemplos:
# output_dir = Path('outputs')
# output_dir.mkdir(exist_ok=True)
# customer_metrics2.to_csv(output_dir / 'customer_metrics.csv', index=False)

# README / requirements / figuras: crea los archivos mínimos que tu proyecto necesite

# %% [markdown]
# ### Comandos de referencia para Git
#
# No necesitas ejecutarlos aquí si no estás en terminal, pero úsalos como guía:
#
# ```bash
# git init
# git add .
# git commit -m "Primer commit del proyecto"
# git branch -M main
# git remote add origin https://github.com/TU_USUARIO/TU_REPO.git
# git push -u origin main
# ```
#
# ### Preguntas de cierre técnico
#
# 1. ¿Qué archivos sí deben ir al repo?
#    `_______________________________________________________________`
# 2. ¿Qué archivos no convendría subir?
#    `_______________________________________________________________`
# 3. ¿Cómo explicarías este proyecto en 3 líneas dentro del `README`?
#    `_______________________________________________________________`

# %% [markdown]
# ## Take aways
#
# Marca lo que ya puedes hacer con más confianza:
#
# - [ ] Puedo cargar y revisar un dataset con `pandas`.
# - [ ] Puedo identificar nulos, duplicados y tipos incorrectos.
# - [ ] Puedo construir métricas por cliente con `groupby()` y `agg()`.
# - [ ] Puedo detectar outliers con IQR y/o Z-score.
# - [ ] Puedo justificar decisiones de limpieza con criterio de negocio.
# - [ ] Puedo segmentar clientes con reglas simples y explicables.
# - [ ] Puedo organizar mi trabajo para publicarlo en GitHub.

# %% [markdown]
# ## Cierre
#
# ### Reflexión final
#
# 1. ¿Qué parte del proyecto te pareció más clara?
#    `_______________________________________________________________`
# 2. ¿Qué parte te costó más trabajo?
#    `_______________________________________________________________`
# 3. ¿Qué hallazgo mostrarías primero a una persona del negocio?
#    `_______________________________________________________________`
# 4. Si repitieras este proyecto, ¿qué mejorarías?
#    `_______________________________________________________________`

# %% [markdown]
# ## Siguientes pasos
#
# - Revisa tu notebook y agrega comentarios en las celdas de código.
# - Deja tu `README` con objetivo, dataset, pasos y hallazgos.
# - Si puedes, agrega una figura exportada al repo.
# - Lleva este caso como base para proyectos similares de segmentación o customer analytics.
#
# ### ¿Necesitas ayuda?
# - `DATA-CO-LEARNING`: revisa los horarios de apoyo en la guía del estudiante.
# - `DA_CONSULTA`: publica dudas de contenido o del proyecto usando el tag correspondiente.
# - `SPRINT FOCUS`: sesiones extra para profundizar temas clave del sprint.
# - `SESIONES 1:1`: agenda con anticipación si necesitas apoyo individual.
