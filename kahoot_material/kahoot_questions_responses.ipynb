# %% [markdown]
# # Kahoots – Preguntas y Respuestas
# Notebook consolidado con todas las preguntas y respuestas.

# %% [markdown]
# # W00_Sprint1_Begin
# **¿Con qué palabras describirías a un Data Analytics?**
# - ✔ Respuesta abierta
#
# **¿Cómo te sientes iniciando el bootcamp respecto al contenido?**
# - ✔ Respuesta abierta
#
# **¿Qué esperas aprender de esta sesión?**
# - ✔ Respuesta abierta

# %% [markdown]
# # W00_Sprint1_End
# **¿Con qué palabras describirías a un Data Analytics?**
# - ✔ Respuesta abierta
#
# **¿Cómo te sientes iniciando el bootcamp respecto al contenido?**
# - ✔ Respuesta abierta
#
# **¿Qué canal usar para obtener respuestas inmediatas?**
# - ✔ Data-CO-Learning

# %% [markdown]
# # WO1_Sprint1
# **¿Cuál es la responsabilidad principal de un Data Analyst (DA)?**
# - ✔ Transformar preguntas de negocio en respuestas basadas en datos
#
# **En OSEMN, ¿qué etapa corresponde a limpiar y estandarizar fechas/booleanos?**
# - ✔ Scrub
#
# **Para el caso Taylor Swift, ¿qué entregable típico apoya decisiones?**
# - ✔ Métricas y documentación con guía cercana

# %% [markdown]
# # WO2_Sprint1
# **Con outliers en Spotify Streams (M), ¿qué medida es más robusta?**
# - ✔ Mediana y Rango
#
# **¿Qué secuencia refleja buenas prácticas de limpieza?**
# - ✔ Duplicados → Normalizar formatos → Corregir valores → Documentar
#
# **Para Writers con separadores mixtos, ¿combo adecuado?**
# - ✔ LEFT + RIGHT
#
# **Buena práctica con LLM para sugerir visualizaciones**
# - ✔ Compartir estructura sin datos sensibles

# %% [markdown]
# # WO3_Sprint1
# **La función AVERAGE nos permite:**
# - ✔ Calcular promedio
#
# **¿Por qué es importante documentar los cambios?**
# - ✔ Asegura trazabilidad
#
# **Con SUMIF podemos**
# - ✔ Hacer sumatorias a partir de un condicional

# %% [markdown]
# # WO4_Sprint1
# **La limpieza minima involucra:**
# - ✔ Eliminar espacios extra
#
# **¿Como podemos sustituir valores extraños/caracteres extraños?**
# - ✔ Opción buscar y reemplazar
#
# **Con la función PROPER podemos**
# - ✔ Estandarizar nombres de personas

# %% [markdown]
# # W05_Sprint2
# **¿Qué preguntas analíticas claras generaste?**
# - ✔ Respuesta abierta

# %% [markdown]
# # W06_Sprint2
# **La limpieza de los datos ocurre después del modelado**
# - ✔ False
#
# **En distribución normal, media=mediana=moda**
# - ✔ True
#
# **Un outlier sigue el mismo patrón que el resto**
# - ✔ False

# %% [markdown]
# # W07_Sprint2
# **Objetivo principal de una PivotTable**
# - ✔ Agrupar y resumir información
#
# **¿Qué cálculos se pueden aplicar en pivot?**
# - ✔ SUM, COUNT, AVG, MAX, MIN
#
# **Buena práctica usando IA en PivotTables**
# - ✔ Usarla como apoyo revisando resultados

# %% [markdown]
# # W08_Sprint2
# **Propósito del taller Warm-Up Walmart**
# - ✔ Practicar pasos similares sin solución final
#
# **¿Qué significa enriquecer datos?**
# - ✔ Unir tablas para añadir información
#
# **¿Cómo se calcula KPI eficiencia en ventas?**
# - ✔ Ventas totales / semanas
#
# **¿Qué debe incluir el archivo final?**
# - ✔ clean_sales, kpi*, README, change_log

# %% [markdown]
# # W09_Sprint3
# **¿Qué caracteriza a SQL como lenguaje?**
# - ✔ Es declarativo
#
# **Relación entre llaves primarias y foráneas**
# - ✔ Foráneas referencian llaves primarias
#
# **Propósito de GROUP BY**
# - ✔ Agrupar registros para agregaciones
#
# **Uso de agregaciones en análisis financiero**
# - ✔ Calcular ingresos, costos, márgenes

# %% [markdown]
# # W10_Sprint3
# **¿Qué significa DDL?**
# - ✔ Data Definition Language
#
# **¿Qué operaciones son DML?**
# - ✔ Insertar, actualizar, eliminar
#
# **Comando para combinar varias tablas**
# - ✔ JOIN
#
# **Objetivo ejercicios KPI**
# - ✔ Crear gráficos en RunSQL

# %% [markdown]
# # W11_Sprint3
# **¿Qué representa gross profit?**
# - ✔ Diferencia entre revenue y cost
#
# **Fórmula de margin_pct**
# - ✔ (revenue - cost)/revenue
#
# **Propósito del ROI**
# - ✔ Evaluar eficiencia de campañas
#
# **Ventaja de CTEs en SQL financiero**
# - ✔ Mejorar legibilidad y reutilización

# %% [markdown]
# # W12_Sprint3
# **¿Qué es una window function?**
# - ✔ Función que calcula valores sobre filas sin agrupar
#
# **Propósito de LAG()**
# - ✔ Acceder al valor anterior
#
# **Validación y verificación busca**
# - ✔ Confirmar coherencia de totales y relaciones
#
# **Rol de CASE en KPIs**
# - ✔ Condiciones para clasificar resultados

# %% [markdown]
# # W13_Sprint4
# **Mejor definición de user journey**
# - ✔ Proceso multi-etapa de interacciones hacia conversión
#
# **¿Por qué usamos CTEs en funnels?**
# - ✔ Dividir análisis y reutilizar subconsultas
#
# **Definición de cohort retention**
# - ✔ True

# %% [markdown]
# # W14_Sprint4
# **¿Qué representa cada CTE en un funnel?**
# - ✔ Tabla temporal con usuarios por etapa
#
# **¿Por qué usar mediana y no promedio?**
# - ✔ Menos sensible a outliers
#
# **Usuario retenido definición semanal**
# - ✔ True

# %% [markdown]
# # W15_Sprint4
# **Objetivo principal de un funnel**
# - ✔ Entender cómo avanzan usuarios en un proceso
#
# **Uso correcto de SQLite Online**
# - ✔ Permite ejecutar SQL pegando tablas
#
# **Objetivo del Webinar 13 Práctico**
# - ✔ Construir un funnel completo y analizar retención

# %% [markdown]
# # W16_Sprint4
# **Objetivo principal del Webinar 14**
# - ✔ Medir retención por país con eventos
#
# **Definición de retención**
# - ✔ Activos acumulados / usuarios únicos
#
# **Por qué usar SQLiteOnline**
# - ✔ Permite ejecutar SQL en navegador

# %% [markdown]
# # W17_Sprint5_Teorico
# **¿Qué es un DataFrame en Pandas?**
# - ✔ Estructura tabular con filas y columnas
#
# **Método para leer CSV**
# - ✔ pd.read_csv()
#
# **Diferencia entre loc e iloc**
# - ✔ loc usa etiquetas, iloc índices numéricos
#
# **Uso de df.info()**
# - ✔ Ver tipos de datos y nulos

# %% [markdown]
# # W18_Sprint5_Practico
# **Operador para filtrado múltiple**
# - ✔ & y |
#
# **df.sort_values() permite**
# - ✔ Ordenar columnas
#
# **Sintaxis para edad > 30**
# - ✔ df[df['edad']>30]
#
# **df.head(10) hace**
# - ✔ Muestra primeras 10 filas

# %% [markdown]
# # W19_Sprint5_Teorico
# **Método que elimina nulos**
# - ✔ dropna()
#
# **Imputación menos sensible a outliers**
# - ✔ Mediana
#
# **Función de groupby()**
# - ✔ Agrupar filas por columnas
#
# **Uso de agg()**
# - ✔ Aplicar múltiples agregaciones

# %% [markdown]
# # W20_Sprint5_Practico
# **Reemplazar nulos con media**
# - ✔ df['col'].fillna(df['col'].mean(),inplace=True)
#
# **Detectar outliers con IQR**
# - ✔ Filtrar fuera de Q1-1.5IQR o Q3+1.5IQR
#
# **groupby().size()**
# - ✔ Número de filas por grupo
#
# **df.describe()**
# - ✔ Estadísticas resumen

# %% [markdown]
# # W21_Sprint7_Teorico
# **¿Cuál opción es una forma común de manejar valores ausentes en un DataFrame?**
# - ✔ fillna()
#
# **¿Qué gráfica es más usada para ver la distribución de una variable numérica?**
# - ✔ Histograma
#
# **¿Qué hace un git commit?**
# - ✔ Número de filas por grupo

# %% [markdown]
# # W22_Sprint7_Practico
# **¿Qué método te ayuda a detectar valores faltantes en una columna?**
# - ✔ fillna()
#
# **Si quieres aplicar una limpieza a toda una columna (por ejemplo strip() a texto), ¿qué opción es más típica?**
# - ✔ .str.strip()
#
# **¿Qué hace un git commit?**
# - ✔ Número de filas por grupo

# %% [markdown]
# # W23_Sprint7_Teorico
# **¿Cuál de estas columnas suele ser categórica?**
# - ✔ fillna()
#
# **¿Qué significa una correlación cercana a 0 entre dos variables numéricas?**
# - ✔ No hay relación lineal clara
#
# **¿Para qué sirve principalmente un boxplot?**
# - ✔ Número de filas por grupo

# %% [markdown]
# # W24_Sprint7_Practico
# **¿Qué medida es más robusta frente a outliers?**
# - ✔ Mediana
#
# **Para crear una columna de “segmento” con reglas (por ejemplo: alto/medio/bajo), ¿qué estructura es la más típica en Python?**
# - ✔ if / elif / else
#
# **¿Cuál es el orden correcto para publicar tus cambios en GitHub?**
# - ✔ git add → git commit → git push

# %% [markdown]
# # W25_Sprint8_Teórico
# **¿Qué es un KPI?**
# - ✔ Una medida para evaluar un objetivo
#
# **En analítica, ¿cuál suele ser una métrica?**
# - ✔ ventas
#
# **¿Qué significa segmentar clientes?**
# - ✔ Agrupar clientes por características similares

# %% [markdown]
# # W26_Sprint8_Práctico
# **Si quieres calcular el promedio de ventas por categoría, ¿qué operación es la más adecuada?**
# - ✔ Agrupar por categoría y calcular mean()
#
# **Si 200 personas visitan una página y 20 compran, ¿cuál es la tasa de conversión?**
# - ✔ 10%
#
# **¿Cuál regla es un ejemplo válido de segmentación?**
# - ✔ “Clientes con compras ≥ 3 son ‘frecuentes’”

# %% [markdown]
# # W27_Sprint9_Teórico
# **¿Para qué se usa principalmente una prueba de hipótesis en negocio/analítica?**
# - ✔ Para tomar una decisión con evidencia usando una muestra
#
# **El p-value te ayuda a…**
# - ✔ Decidir si la diferencia observada podría ser por azar
#
# **Si α = 0.05, eso significa que aceptamos un 5% de riesgo de…**
# - ✔ Error tipo I (falso positivo)

# %% [markdown]
# # W28_Sprint9_Extra
# **¿Qué es web scraping?**
# - ✔ Extraer datos de páginas web
#
# **¿Qué librería de Python se usa para parsear HTML en esta clase?**
# - ✔ BeautifulSoup
#
# **¿Cuál es una tarea típica del EDA básico?**
# - ✔

# %% [markdown]
# # W29_Sprint9_Practico
# **En un experimento A/B, ¿qué se comparan normalmente?**
# - ✔ Dos versiones de una misma página
#
# **¿Qué variable indica si un usuario convirtió o no?**
# - ✔ converted
#
# **Antes de comparar resultados entre A y B, ¿qué conviene revisar?**
# - ✔ La calidad de los datos

# %% [markdown]
# # W30_Sprint10_Extra
# **¿Qué parte del error te dice qué tipo de problema ocurrió?**
# - ✔ La última línea del traceback
#
# **¿Cuál error aparece cuando una columna no existe en un DataFrame?**
# - ✔ KeyError
#
# **¿Qué conviene revisar primero cuando aparece un error en pandas?**
# - ✔ Los nombres de columnas y tipos de datos

# %% [markdown]
# # W31_Sprint10_Extra
# **¿Qué significa ETL?**
# - ✔ Extract, Transform, Load
#
# **¿Para qué sirve la etapa de Transform?**
# - ✔ Para limpiar y preparar los datos
#
# **¿Por qué SQLite es útil para principiantes?**
# - ✔ Porque es ligera y usa un archivo .db

# %% [markdown]
# # W32_Sprint10_Teorico
# **¿En qué parte de Power BI se limpian y transforman datos?**
# - ✔ Power Query
#
# **¿Cuál es una buena regla de diseño visual para dashboards?**
# - ✔ Claridad antes que decoración
#
# **¿Qué permite la interactividad en un dashboard?**
# - ✔ Filtrar y explorar la información

# %% [markdown]
# # W33_Sprint10_Practico
# **En el dataset del proyecto, ¿qué representa una fila?**
# - ✔ Una transacción
#
# **Antes de crear visualizaciones, ¿qué se debe revisar primero?**
# - ✔ El grano, los tipos y la calidad de los datos
#
# **¿Para qué sirve la narrativa SCQA en el proyecto?**
# - ✔ Para contar la historia del dashboard con lógica de negocio

# %% [markdown]
# # W34_Sprint11_Practico
# **¿Cuál es el objetivo principal del bootstrap?**
# - ✔ Estimar la distribución de una métrica a partir de remuestreos
#
# **¿Para qué se usa una simulación de Monte Carlo en análisis de datos?**
# - ✔ Para estimar probabilidades bajo muchos escenarios aleatorios
#
# **¿Qué hace un test de permutaciones?**
# - ✔ Evalúa diferencias entre grupos sin depender de supuestos fuertes de distribución

# %% [markdown]
# # W35_Sprint11_Practico
# **¿Cuál es la ventaja principal de un modelo en estrella en BI?**
# - ✔ Facilita el análisis al separar hechos y dimensiones
#
# **En DAX, la función CALCULATE se usa principalmente para:**
# - ✔ Modificar el contexto de filtro de un cálculo
#
# **En Tableau, una expresión LOD sirve para:**
# - ✔ Definir el nivel de detalle al que se calcula una métrica

# %% [markdown]
# # W36_Sprint11_Practico
# **¿Qué tabla se marca como tabla de fechas en Power BI para habilitar análisis temporales correctos?**
# - ✔ dim_fecha
#
# **¿Qué tipo de tabla contiene normalmente las métricas transaccionales principales en un esquema estrella?**
# - ✔ Tabla de hechos
#
# **Una métrica como YTD (Year to Date) pertenece a qué tipo de análisis?**
# - ✔ Inteligencia de tiempo

# %% [markdown]
# # W37_Sprint11_Practico
# **¿Cuál es el propósito del Paso 1 del proyecto RappiPlus?**
# - ✔ Validar la calidad y preparación de los datos
#
# **Para calcular la rentabilidad de los pedidos en Python, el notebook sugiere unir orders con:**
# - ✔ catalog
#
# **Cuando se comparan tasas de conversión entre dos grupos en el proyecto, el test sugerido es:**
# - ✔ Test Z de proporciones
